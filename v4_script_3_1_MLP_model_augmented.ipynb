# %% [markdown]
# ## header

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
from os.path import exists

project_path = '/content/drive/MyDrive/Gproject/MIT_glyco'
os.chdir(project_path)

os.getcwd() # current working directory
# Out:
# Mounted at /content/drive
# '/content/drive/MyDrive/Gproject/MIT_glyco'

# %%
import pandas as pd
import numpy as np

import time

version = 'v4'
update = False

# %%
load_name = "v4_augmented_dataset_all.csv"
dataset = pd.read_csv(load_name)
protein_list = list(dataset.protein.unique())
pass_list = ['A2ABU4', 'P26039', 'P70670', 'P83741', 'Q5DTJ9', 'Q66L42', 'Q6GQX2', 
             'Q6ZPS6', 'Q76LL6', 'Q80TE4', 'Q80VP0', 'Q8CDG3', 'Q8CG79', 'A2AQ25', 'P07756']

for name in pass_list:
    protein_list.remove(name)

dataset = dataset[dataset['protein'].apply(lambda x: x in protein_list)]

ST_dataset = dataset[(dataset['SEQ']=='S') | (dataset['SEQ']=='T')].reset_index(drop=True)
ST_positive = ST_dataset[ST_dataset['positivity']==1]
ST_negative = ST_dataset[ST_dataset['positivity']==0]

print("total number of proteins:      ", len(ST_dataset.protein.unique()))
print("total number of samples:       ", len(ST_dataset))
print("total number of positive sites:", len(ST_positive))
print("total number of negative sites:", len(ST_negative))
display(ST_dataset)
# Out:
# total number of proteins:       73
# total number of samples:        6606
# total number of positive sites: 157
# total number of negative sites: 6449
#         # SEQ SS   ASA    Phi    Psi  Theta(i-1=>i+1)  Tau(i-2=>i+2)  \
# 0       6   T  C  80.6  -78.9  -11.1            102.8         -160.6
# 1      22   S  C  60.8  -97.4   -6.6            102.2           44.8
# 2      28   S  H   5.4  -65.8  -43.4             94.1           50.8
# 3      56   S  C  36.4 -108.0  166.7            129.9         -153.7
# 4      90   S  C  66.2  -83.6   -0.5             98.6           58.6
# ...   ...  .. ..   ...    ...    ...              ...            ...
# 6601  708   S  C  36.8  -97.3  126.1            113.9         -121.0
# 6602  714   S  C  39.8  -91.4  135.9            117.7          137.8
# 6603  719   T  H  57.4 -100.2  132.7            115.6          137.2
# 6604  725   S  H  29.2 -101.3  139.3            117.9         -173.0
# 6605  727   S  H  36.3  -71.0  -37.4             98.1           56.8
#
#       HSE_alpha_up  HSE_alpha_down  ...  \
# 0              7.7            15.9  ...
# 1              7.3            20.5  ...
# 2             22.0            21.5  ...
# 3              7.5            24.6  ...
# 4              6.5            17.8  ...
# ...            ...             ...  ...
# 6601          13.1            19.9  ...
# 6602          14.5            12.2  ...
# 6603          10.1            20.3  ...
# 6604          12.6            23.0  ...
# 6605          10.4            22.2  ...
#
#       exposed_positive_charge_all_with_around_target_ser_thr  \
# 0                                                  2.04
# 1                                                  2.06
# 2                                                  3.06
# 3                                                  4.59
# 4                                                  4.59
# ...                                                 ...
# 6601                                               2.69
# 6602                                               3.57
# 6603                                               4.66
# 6604                                               6.53
# 6605                                               5.51
#
#       exposed_positive_charge_all_backbone_around_target_ser_thr  \
# 0                                                  7.96
# 1                                                 11.60
# 2                                                 11.84
# 3                                                 17.35
# 4                                                 14.06
# ...                                                 ...
# 6601                                               3.60
# 6602                                               8.33
# 6603                                               8.61
# 6604                                               9.23
# 6605                                               9.05
#
#       exposed_positive_charge_all_sidechain_around_target_ser_thr  \
# 0                                                  2.04
# 1                                                  2.57
# 2                                                  3.06
# 3                                                  4.59
# 4                                                  5.10
# ...                                                 ...
# 6601                                               3.20
# 6602                                               4.08
# 6603                                               5.17
# 6604                                               7.04
# 6605                                               6.02
#
#       exposed_positive_charge_all_backbone_with_around_target_ser_thr  \
# 0                                                  8.75
# 1                                                 12.26
# 2                                                 12.41
# 3                                                 18.01
# 4                                                 14.29
# ...                                                 ...
# 6601                                               4.26
# 6602                                               8.99
# 6603                                               9.40
# 6604                                               9.89
# 6605                                               9.71
#
#      exposed_positive_charge_all_sidechain_with_around_target_ser_thr  \
# 0                                                -15.91
# 1                                                -16.75
# 2                                                -17.65
# 3                                                -24.79
# 4                                                -25.49
# ...                                                 ...
# 6601                                             -10.19
# 6602                                             -14.73
# 6603                                             -19.52
# 6604                                             -21.40
# 6605                                             -19.41
#
#      exposed_negative_charge_all_around_target_ser_thr  \
# 0                                               -16.18
# 1                                               -17.92
# 2                                               -19.29
# 3                                               -25.92
# 4                                               -27.13
# ...                                                ...
# 6601                                            -11.83
# 6602                                            -16.37
# 6603                                            -21.43
# 6604                                            -22.57
# 6605                                            -20.58
#
#      exposed_negative_charge_all_with_around_target_ser_thr  \
# 0                                                 -6.80
# 1                                                 -7.58
# 2                                                 -7.21
# 3                                                 -8.43
# 4                                                -10.59
# ...                                                 ...
# 6601                                              -4.92
# 6602                                              -5.74
# 6603                                              -8.68
# 6604                                             -11.71
# 6605                                             -10.26
#
#      exposed_negative_charge_all_backbone_around_target_ser_thr  \
# 0                                                 -9.11
# 1                                                 -9.17
# 2                                                -10.44
# 3                                                -16.36
# 4                                                -14.90
# ...                                                 ...
# 6601                                              -5.27
# 6602                                              -8.99
# 6603                                             -10.84
# 6604                                              -9.69
# 6605                                              -9.15
#
#      exposed_negative_charge_all_sidechain_around_target_ser_thr  \
# 0                                                 -6.80
# 1                                                 -8.09
# 2                                                 -8.19
# 3                                                 -8.90
# 4                                                -11.57
# ...                                                 ...
# 6601                                              -5.90
# 6602                                              -6.72
# 6603                                              -9.66
# 6604                                             -12.22
# 6605                                             -10.77
#
#      exposed_negative_charge_all_backbone_with_around_target_ser_thr
# 0                                                 -9.38
# 1                                                 -9.83
# 2                                                -11.10
# 3                                                -17.02
# 4                                                -15.56
# ...                                                 ...
# 6601                                              -5.93
# 6602                                              -9.65
# 6603                                             -11.77
# 6604                                             -10.35
# 6605                                              -9.81
#
# [6606 rows x 184 columns]

# %%
display(dict(zip(range(len(ST_dataset.columns)), ST_dataset.columns)))
# Out:
# {0: '#',
#  1: 'SEQ',
#  2: 'SS',
#  3: 'ASA',
#  4: 'Phi',
#  5: 'Psi',
#  6: 'Theta(i-1=>i+1)',
#  7: 'Tau(i-2=>i+2)',
#  8: 'HSE_alpha_up',
#  9: 'HSE_alpha_down',
#  10: 'P(C)',
#  11: 'P(H)',
#  12: 'P(E)',
#  13: 'flexibility',
#  14: 'side_-1',
#  15: 'side_1',
#  16: 'side_2',
#  17: 'side_3',
#  18: 'side_4',
#  19: 'side_5',
#  20: 'nAli',
#  21: 'nPos',
#  22: 'nS/nT',
#  23: 'Proline',
#  24: 'phi_psi',
#  25: 'positivity',
#  26: 'protein',
#  27: '#.1',
#  28: 'residue_SER_THR',
#  29: 'number_of_hydrophobic',
#  30: 'number_of_hydrophilic',
#  31: 'number_of_polar',
#  32: 'number_of_aromatic',
#  33: 'number_of_aliphatic',
#  34: 'number_of_charged',
#  35: 'number_of_positive',
#  36: 'number_of_negative',
#  37: 'number_of_g',
#  38: 'number_of_v',
#  39: 'number_of_s',
#  40: 'number_of_n',
#  41: 'number_of_l',
#  42: 'number_of_p',
#  43: 'number_of_A',
#  44: 'number_of_b',
#  45: 'number_of_d',
#  46: 'number_of_e',
#  47: 'number_of_f',
#  48: 'number_of_ala',
#  49: 'number_of_cys',
#  50: 'number_of_asp',
#  51: 'number_of_glu',
#  52: 'number_of_phe',
#  53: 'number_of_his',
#  54: 'number_of_ile',
#  55: 'number_of_lys',
#  56: 'number_of_leu',
#  57: 'number_of_met',
#  58: 'number_of_asn',
#  59: 'number_of_gln',
#  60: 'number_of_arg',
#  61: 'number_of_ser',
#  62: 'number_of_thr',
#  63: 'number_of_val',
#  64: 'number_of_trp',
#  65: 'number_of_tyr',
#  66: 'sasa_hydrophobic',
#  67: 'sasa_hydrophilic',
#  68: 'sasa_polar',
#  69: 'sasa_aromatic',
#  70: 'sasa_aliphatic',
#  71: 'sasa_charged',
#  72: 'sasa_positive',
#  73: 'sasa_negative',
#  74: 'sasa_g',
#  75: 'sasa_v',
#  76: 'sasa_s',
#  77: 'sasa_n',
#  78: 'sasa_l',
#  79: 'sasa_p',
#  80: 'sasa_A',
#  81: 'sasa_b',
#  82: 'sasa_d',
#  83: 'sasa_e',
#  84: 'sasa_f',
#  85: 'sasa_ala',
#  86: 'sasa_cys',
#  87: 'sasa_asp',
#  88: 'sasa_glu',
#  89: 'sasa_phe',
#  90: 'sasa_his',
#  91: 'sasa_ile',
#  92: 'sasa_lys',
#  93: 'sasa_leu',
#  94: 'sasa_met',
#  95: 'sasa_asn',
#  96: 'sasa_gln',
#  97: 'sasa_arg',
#  98: 'sasa_ser',
#  99: 'sasa_thr',
#  100: 'sasa_val',
#  101: 'sasa_trp',
#  102: 'sasa_tyr',
#  103: 'all_sasa_hydrophobic',
#  104: 'all_sasa_hydrophilic',
#  105: 'all_sasa_polar',
#  106: 'all_sasa_aromatic',
#  107: 'all_sasa_aliphatic',
#  108: 'all_sasa_charged',
#  109: 'all_sasa_positive',
#  110: 'all_sasa_negative',
#  111: 'all_sasa_g',
#  112: 'all_sasa_v',
#  113: 'all_sasa_s',
#  114: 'all_sasa_n',
#  115: 'all_sasa_l',
#  116: 'all_sasa_p',
#  117: 'all_sasa_A',
#  118: 'all_sasa_b',
#  119: 'all_sasa_d',
#  120: 'all_sasa_e',
#  121: 'all_sasa_f',
#  122: 'all_sasa_ala',
#  123: 'all_sasa_cys',
#  124: 'all_sasa_asp',
#  125: 'all_sasa_glu',
#  126: 'all_sasa_phe',
#  127: 'all_sasa_his',
#  128: 'all_sasa_ile',
#  129: 'all_sasa_lys',
#  130: 'all_sasa_leu',
#  131: 'all_sasa_met',
#  132: 'all_sasa_asn',
#  133: 'all_sasa_gln',
#  134: 'all_sasa_arg',
#  135: 'all_sasa_ser',
#  136: 'all_sasa_thr',
#  137: 'all_sasa_val',
#  138: 'all_sasa_trp',
#  139: 'all_sasa_tyr',
#  140: 'sasa_back',
#  141: 'all_sasa_back',
#  142: 'sasa_side',
#  143: 'all_sasa_side',
#  144: 'all_sasa_back_with_whole_target',
#  145: 'all_sasa_side_with_whole_target',
#  146: 'sasa_target_ser_thr',
#  147: 'sasa_all_around_target_ser_thr',
#  148: 'sasa_all_with_around_target_ser_thr',
#  149: 'net_charge_all_around_target_ser_thr',
#  150: 'net_charge_all_with_around_target_ser_thr',
#  151: 'net_charge_all_backbone_around_target_ser_thr',
#  152: 'net_charge_all_sidechain_around_target_ser_thr',
#  153: 'net_charge_all_backbone_with_around_target_ser_thr',
#  154: 'net_charge_all_sidechain_with_around_target_ser_thr',
#  155: 'all_atom_positive_charge_all_around_target_ser_thr',
#  156: 'all_atom_positive_charge_all_with_around_target_ser_thr',
#  157: 'all_atom_positive_charge_all_backbone_around_target_ser_thr',
#  158: 'all_atom_positive_charge_all_sidechain_around_target_ser_thr',
#  159: 'all_atom_positive_charge_all_backbone_with_around_target_ser_thr',
#  160: 'all_atom_positive_charge_all_sidechain_with_around_target_ser_thr',
#  161: 'all_atom_negative_charge_all_around_target_ser_thr',
#  162: 'all_atom_negative_charge_all_with_around_target_ser_thr',
#  163: 'all_atom_negative_charge_all_backbone_around_target_ser_thr',
#  164: 'all_atom_negative_charge_all_sidechain_around_target_ser_thr',
#  165: 'all_atom_negative_charge_all_backbone_with_around_target_ser_thr',
#  166: 'all_atom_negative_charge_all_sidechain_with_around_target_ser_thr',
#  167: 'exposed_charge_all_around_target_ser_thr',
#  168: 'exposed_charge_all_with_around_target_ser_thr',
#  169: 'exposed_charge_all_backbone_around_target_ser_thr',
#  170: 'exposed_charge_all_sidechain_around_target_ser_thr',
#  171: 'exposed_charge_all_backbone_with_around_target_ser_thr',
#  172: 'exposed_charge_all_sidechain_with_around_target_ser_thr',
#  173: 'exposed_positive_charge_all_around_target_ser_thr',
#  174: 'exposed_positive_charge_all_with_around_target_ser_thr',
#  175: 'exposed_positive_charge_all_backbone_around_target_ser_thr',
#  176: 'exposed_positive_charge_all_sidechain_around_target_ser_thr',
#  177: 'exposed_positive_charge_all_backbone_with_around_target_ser_thr',
#  178: 'exposed_positive_charge_all_sidechain_with_around_target_ser_thr',
#  179: 'exposed_negative_charge_all_around_target_ser_thr',
#  180: 'exposed_negative_charge_all_with_around_target_ser_thr',
#  181: 'exposed_negative_charge_all_backbone_around_target_ser_thr',
#  182: 'exposed_negative_charge_all_sidechain_around_target_ser_thr',
#  183: 'exposed_negative_charge_all_backbone_with_around_target_ser_thr'}

# %% [markdown]
# # Case 1: without window

# %%
x_cat = ['SEQ', 'SS']
x_cts = ['ASA', 'Phi', 'Psi', 'Theta(i-1=>i+1)', 'Tau(i-2=>i+2)', 'HSE_alpha_up', 'HSE_alpha_down', 
         'P(C)', 'P(H)', 'P(E)', 'flexibility']
x_aug = [ST_dataset.columns[x] for x in range(len(ST_dataset.columns)) if x >= 28]
y_label = ['positivity']

data_x = pd.get_dummies(ST_dataset[x_cts+x_aug+x_cat], columns=x_cat)
data_y = ST_dataset[y_label]

print(data_x.shape)
print(data_y.shape)

print("\nx columns:")
display(pd.Series(data_x.columns))
# Out:
# (6606, 172)
# (6606, 1)
#
# x columns:
# 0                  ASA
# 1                  Phi
# 2                  Psi
# 3      Theta(i-1=>i+1)
# 4        Tau(i-2=>i+2)
#             ...
# 167              SEQ_S
# 168              SEQ_T
# 169               SS_C
# 170               SS_E
# 171               SS_H
# Length: 172, dtype: object

# %%
from sklearn.model_selection import StratifiedShuffleSplit

def stratified_split(data_x, data_y, test_size=0.2, n_splits=1, random_state=1, dtype='arr'):

    split = StratifiedShuffleSplit(n_splits=n_splits, test_size=test_size, random_state=random_state)
    
    train_x, train_y, test_x, test_y  = [], [], [], []
    if dtype=='df':
        data_x = data_x.values
        data_y = data_y.values
    
    for train_index, test_index in split.split(data_x, data_y):
        train_x.append(data_x[train_index])
        train_y.append(data_y[train_index])

        test_x.append(data_x[test_index])
        test_y.append(data_y[test_index])
        
    print("train/test dataset")
    print("train:", train_x[0].shape, train_y[0].shape)
    print("test:", test_x[0].shape, test_y[0].shape)
    
    if n_splits == 1:
        return train_x[0],train_y[0], test_x[0], test_y[0]
    else:
        return train_x, train_y, test_x, test_y

# %%
### split data into train/test dataset ###
test_size = 0.2
n_splits = 10
random_state = 1

split = StratifiedShuffleSplit(n_splits=n_splits, test_size=test_size, random_state=random_state)
arr_x, arr_y = data_x.values, data_y.values # convert dataframe to nd-array 

i=1
train_idx_list, train_x_list, train_y_list, test_idx_list, test_x_list, test_y_list = [], [], [], [], [], []
for train_index, test_index in split.split(arr_x, arr_y):
    train_x = arr_x[train_index]
    train_y = arr_y[train_index]
    test_x = arr_x[test_index]
    test_y = arr_y[test_index]
    
    train_cts = train_x[:,:len(x_cts)]
    test_cts  = test_x[:,:len(x_cts)]
    
    x_min = train_cts.min(axis=0)
    x_max = train_cts.max(axis=0)
    
    train_x[:,:len(x_cts)] = (train_cts-x_min)/(x_max-x_min)
    test_x[:,:len(x_cts)] = (test_cts-x_min)/(x_max-x_min)
    
    print(f"{i}th iteration")
    print("train:", train_x.shape, train_y.shape, "check scale:", train_x.min(), train_x.max())
    print("test: ", test_x.shape, test_y.shape, "check scale:", test_x.min(), test_x.max())
    
    train_idx_list.append(train_index)
    train_x_list.append(train_x)
    train_y_list.append(train_y)
    
    test_idx_list.append(test_index)
    test_x_list.append(test_x)
    test_y_list.append(test_y)
    
    i += 1
# Out:
# 1th iteration
# train: (5284, 172) (5284, 1) check scale: -92.34 1896.2816162109373
# test:  (1322, 172) (1322, 1) check scale: -89.59 1948.8858642578125
# 2th iteration
# train: (5284, 172) (5284, 1) check scale: -92.34 1948.8858642578125
# test:  (1322, 172) (1322, 1) check scale: -92.08 1878.1199951171875
# 3th iteration
# train: (5284, 172) (5284, 1) check scale: -92.34 1948.8858642578125
# test:  (1322, 172) (1322, 1) check scale: -89.59 1931.7716064453125
# 4th iteration
# train: (5284, 172) (5284, 1) check scale: -92.34 1948.8858642578125
# test:  (1322, 172) (1322, 1) check scale: -89.27 1861.9886474609373
# 5th iteration
# train: (5284, 172) (5284, 1) check scale: -92.34 1896.2816162109373
# test:  (1322, 172) (1322, 1) check scale: -86.46 1948.8858642578125
# 6th iteration
# train: (5284, 172) (5284, 1) check scale: -90.39 1948.8858642578125
# test:  (1322, 172) (1322, 1) check scale: -92.34 1878.1199951171875
# 7th iteration
# train: (5284, 172) (5284, 1) check scale: -92.34 1948.8858642578125
# test:  (1322, 172) (1322, 1) check scale: -90.39 1847.023193359375
# 8th iteration
# train: (5284, 172) (5284, 1) check scale: -92.34 1931.7716064453125
# test:  (1322, 172) (1322, 1) check scale: -90.02 1948.8858642578125
# 9th iteration
# train: (5284, 172) (5284, 1) check scale: -92.34 1948.8858642578125
# test:  (1322, 172) (1322, 1) check scale: -90.02 1931.7716064453125
# 10th iteration
# train: (5284, 172) (5284, 1) check scale: -92.08 1948.8858642578125
# test:  (1322, 172) (1322, 1) check scale: -92.34 1931.7716064453125

# %%
## upsampling dataset 
import random
random_state = random_state

upsample_x_list, upsample_y_list = [], []
for train_x, train_y in zip(train_x_list, train_y_list):
    index_pos = np.where(train_y == 1)[0]
    index_neg = np.where(train_y == 0)[0]

    random.seed(random_state)
    up_index = [random.choice(index_pos) for _ in range(len(index_neg))] # get samples from positive sites as much as the number of negative sites

    upsample_pos_x = train_x[up_index]
    upsample_pos_y = train_y[up_index]
    sample_neg_x = train_x[index_neg]
    sample_neg_y = train_y[index_neg]

    sample_x = np.concatenate([upsample_pos_x, sample_neg_x], axis=0)
    sample_y = np.concatenate([upsample_pos_y, sample_neg_y], axis=0)

    shuffle_index = np.arange(len(sample_x))
    np.random.seed(random_state)
    np.random.shuffle(shuffle_index)
    sample_x = sample_x[shuffle_index]
    sample_y = sample_y[shuffle_index]
    
    upsample_x_list.append(sample_x)
    upsample_y_list.append(sample_y)

print("up-sampled train dataset:", sample_x.shape, sample_y.shape)
print("test dataset:", test_x.shape, test_y.shape)
# Out:
# up-sampled train dataset: (10316, 172) (10316, 1)
# test dataset: (1322, 172) (1322, 1)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import *
from keras.models import Model
from keras.callbacks import ModelCheckpoint, EarlyStopping

def basicMLP(x_dim, y_dim, n_layers, n_neurons):
    mlp_input = Input(shape=(x_dim,), name='dense_input')
    
    # MLP module
    for i in range(n_layers):
        if i==0:
            dense_output = Dense(n_neurons, name=f"dense_{i+1}")(mlp_input)
        else: 
            dense_output = Dense(n_neurons, name=f"dense_{i+1}")(dense_output)
    mlp_output = Dense(y_dim, name=f"dense_output", activation='sigmoid')(dense_output)
    
    model = Model(mlp_input, mlp_output)
    optimizer = keras.optimizers.Adam(learning_rate = 0.001, beta_1=0.9, beta_2=0.999)
    model.compile(loss='binary_crossentropy',optimizer = optimizer, metrics=['accuracy'])
    
    return model

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from seaborn import heatmap
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def scores(y_real, y_pred, rounding=4):
    
    accuracy  = 100*np.array(accuracy_score(y_real, y_pred)).round(rounding)
    precision = 100*np.array(precision_score(y_real, y_pred, average=None)).round(rounding)[1]
    recall    = 100*np.array(recall_score(y_real, y_pred, average=None)).round(rounding)[1]
    f1        = 100*np.array(f1_score(y_real, y_pred, average=None)).round(rounding)[1]
    
    return accuracy, precision, recall, f1

# %%
## hyper-parameter optimization
model_type = 'augmented_MLP_without_window'

valid_size = test_size/(1-test_size)
patience = 30
monitor = 'val_loss'
random_state = random_state
early_stopping_cb = EarlyStopping(patience=patience, restore_best_weights=True, monitor=monitor)

parameter_config = {
    "n_layers" : range(1,11),
    "n_neurons" : [16, 32, 64, 128, 256]
}

method = "random"
counts = 30
metrics = ['time', 'n_layers', 'n_neurons', 'loss', 'val_loss', 'test_loss', 'accuracy', 'precision', 'recall', 'f1']


train_x = upsample_x_list[0]
train_y = upsample_y_list[0]
test_x = test_x_list[0]
test_y = test_y_list[0]

hpo_result = pd.DataFrame([], columns=metrics)
for i in range(counts):
    random.seed(i+1)
    n_layers = random.choice(parameter_config["n_layers"])
    n_neurons = random.choice(parameter_config["n_neurons"])
    print(f"random, {i+1} of {counts}: {n_layers} layers, {n_neurons} neurons")
    
    model_name = f'{version}_{model_type}_hpo_{i+1}of{counts}'
    save_path  = f'./model/{model_name}.h5'
    score_path = f"./score/{model_name}.csv"
    
    x_dim = train_x.shape[1]
    y_dim = train_y.shape[1]
    model = basicMLP(x_dim, y_dim, n_layers, n_neurons)
    
    if not exists(save_path) or update:
        tf.random.set_seed(i+1)
        
        time_start = time.time()
        history = model.fit(train_x, train_y, verbose=0,
                            epochs=10000, callbacks=[early_stopping_cb], validation_split= valid_size)
        time_end = time.time()
        time_elapse = round((time_end - time_start)/60, 3)
        
        model.save_weights(save_path)
        print(f"model is saved to: {save_path}")
        
        idx = np.array(history.history[monitor]).argmin()
        val_loss = history.history['val_loss'][idx]
        loss = history.history['loss'][idx]
        test_loss = model.evaluate(test_x, test_y, verbose=0)[0]
        prediction = model.predict(test_x, verbose=0)
        prediction = prediction.round(0).astype(int)
        y_real = test_y
        y_pred = prediction
        accuracy, precision, recall, f1 = scores(y_real, y_pred)
        scores_df = pd.DataFrame([[time_elapse, n_layers, n_neurons, loss, val_loss, test_loss, accuracy, precision, recall, f1]], 
                                  columns=metrics)

        scores_df.to_csv(score_path)
        print(f"history is saved to: {score_path}")

    else:
        scores_df = pd.read_csv(score_path, index_col=0, header=0)
        print(f"history is loaded from: {score_path}")
        
    hpo_result = pd.concat([hpo_result, scores_df], axis=0)

hpo_result = hpo_result.reset_index(drop=True)
# Out:
# random, 1 of 30: 3 layers, 256 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_1of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_1of30.csv
# random, 2 of 30: 1 layers, 16 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_2of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_2of30.csv
# random, 3 of 30: 4 layers, 256 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_3of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_3of30.csv
# random, 4 of 30: 4 layers, 64 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_4of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_4of30.csv
# random, 5 of 30: 10 layers, 64 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_5of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_5of30.csv
# random, 6 of 30: 10 layers, 16 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_6of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_6of30.csv
# random, 7 of 30: 6 layers, 32 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_7of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_7of30.csv
# random, 8 of 30: 4 layers, 64 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_8of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_8of30.csv
# random, 9 of 30: 8 layers, 256 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_9of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_9of30.csv
# random, 10 of 30: 10 layers, 16 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_10of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_10of30.csv
# random, 11 of 30: 8 layers, 256 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_11of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_11of30.csv
# random, 12 of 30: 8 layers, 64 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_12of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_12of30.csv
# random, 13 of 30: 5 layers, 64 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_13of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_13of30.csv
# random, 14 of 30: 2 layers, 256 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_14of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_14of30.csv
# random, 15 of 30: 4 layers, 16 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_15of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_15of30.csv
# random, 16 of 30: 6 layers, 128 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_16of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_16of30.csv
# random, 17 of 30: 9 layers, 128 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_17of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_17of30.csv
# random, 18 of 30: 3 layers, 16 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_18of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_18of30.csv
# random, 19 of 30: 1 layers, 256 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_19of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_19of30.csv
# random, 20 of 30: 3 layers, 64 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_20of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_20of30.csv
# random, 21 of 30: 3 layers, 128 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_21of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_21of30.csv
# random, 22 of 30: 3 layers, 32 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_22of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_22of30.csv
# random, 23 of 30: 5 layers, 16 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_23of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_23of30.csv
# random, 24 of 30: 7 layers, 256 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_24of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_24of30.csv
# random, 25 of 30: 7 layers, 16 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_25of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_25of30.csv
# random, 26 of 30: 4 layers, 32 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_26of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_26of30.csv
# random, 27 of 30: 8 layers, 64 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_27of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_27of30.csv
# random, 28 of 30: 2 layers, 32 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_28of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_28of30.csv
# random, 29 of 30: 9 layers, 16 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_29of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_29of30.csv
# random, 30 of 30: 9 layers, 64 neurons
# model is saved to: ./model/v4_augmented_MLP_without_window_hpo_30of30.h5
# history is saved to: ./score/v4_augmented_MLP_without_window_hpo_30of30.csv

# %%
# show the HPO result
target_metric = 'f1'
best_idx = hpo_result[target_metric].argmax()
best_parameters = hpo_result.iloc[best_idx]
print(f'best hyperparamerter: index {best_idx}')
display(best_parameters)

display(hpo_result.describe())
# Out:
# best hyperparamerter: index 1
# time            1.217
# n_layers            1
# n_neurons          16
# loss         0.607082
# val_loss     0.583232
# test_loss    0.502401
# accuracy        73.15
# precision        4.49
# recall          51.61
# f1               8.27
# Name: 1, dtype: object
#             time       loss   val_loss  test_loss   accuracy  precision  \
# count  30.000000  30.000000  30.000000  30.000000  30.000000  30.000000
# mean    2.253300   0.584558   0.572141   0.586679  65.153667   3.387667
# std     1.113065   0.024414   0.005854   0.028058   2.555646   0.298036
# min     0.923000   0.565787   0.565510   0.502401  61.500000   2.820000
# 25%     1.364500   0.573219   0.567879   0.571555  63.410000   3.230000
# 50%     2.037000   0.576738   0.571561   0.585400  64.865000   3.355000
# 75%     2.850500   0.585754   0.573617   0.607407  66.410000   3.450000
# max     5.582000   0.687262   0.590699   0.633821  73.150000   4.490000
#
#           recall         f1
# count  30.000000  30.000000
# mean   50.108000   6.343333
# std     2.900369   0.529283
# min    41.940000   5.280000
# 25%    48.390000   6.070000
# 50%    50.000000   6.305000
# 75%    51.610000   6.455000
# max    54.840000   8.270000

# %%
# train the models for cross validation
n_layers = best_parameters['n_layers']
n_neurons = best_parameters['n_neurons']

i=1
for train_x, train_y in zip(upsample_x_list, upsample_y_list):
    print(f"{i}th iteration")
    model_name = f'{version}_{model_type}_{n_layers}_{n_neurons}_cv_{i}of{n_splits}'
    save_path  = f'./model/{model_name}.h5'
    
    if not exists(save_path) or update:
        x_dim = train_x.shape[1]
        y_dim = train_y.shape[1]
        model = basicMLP(x_dim, y_dim, n_layers, n_neurons)

        if not exists(save_path) or update:
            tf.random.set_seed(random_state)
            history = model.fit(train_x, train_y, verbose=0,
                                epochs=10000, callbacks=[early_stopping_cb], validation_split= valid_size)
            model.save_weights(save_path)
            print(f"model is saved to: {save_path}")
    else:
        print(f"model already exists at: {save_path}")
    i += 1
display(model.summary())
# Out:
# 1th iteration
# model is saved to: ./model/v4_augmented_MLP_without_window_1_16_cv_1of10.h5
# 2th iteration
# model is saved to: ./model/v4_augmented_MLP_without_window_1_16_cv_2of10.h5
# 3th iteration
# model is saved to: ./model/v4_augmented_MLP_without_window_1_16_cv_3of10.h5
# 4th iteration
# model is saved to: ./model/v4_augmented_MLP_without_window_1_16_cv_4of10.h5
# 5th iteration
# model is saved to: ./model/v4_augmented_MLP_without_window_1_16_cv_5of10.h5
# 6th iteration
# model is saved to: ./model/v4_augmented_MLP_without_window_1_16_cv_6of10.h5
# 7th iteration
# model is saved to: ./model/v4_augmented_MLP_without_window_1_16_cv_7of10.h5
# 8th iteration
# model is saved to: ./model/v4_augmented_MLP_without_window_1_16_cv_8of10.h5
# 9th iteration
# model is saved to: ./model/v4_augmented_MLP_without_window_1_16_cv_9of10.h5
# 10th iteration
# model is saved to: ./model/v4_augmented_MLP_without_window_1_16_cv_10of10.h5
# Model: "model_39"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_input (InputLayer)    [(None, 172)]             0
#
#  dense_1 (Dense)             (None, 16)                2768
#
#  dense_output (Dense)        (None, 1)                 17
#
# =================================================================
# Total params: 2,785
# Trainable params: 2,785
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# get the result of cross validation
i=1
accuracy_list, precision_list, recall_list, f1_list = [], [], [], []
for test_x, test_y in zip(test_x_list, test_y_list):
    model_name = f'{version}_{model_type}_{n_layers}_{n_neurons}_cv_{i}of{n_splits}'
    save_path  = f'./model/{model_name}.h5'
    
    model = basicMLP(x_dim, y_dim, n_layers, n_neurons)
    model.load_weights(save_path)
    
    prediction = model.predict(test_x, verbose=0)
    prediction = prediction.round(0).astype(int)

    y_real = test_y
    y_pred = prediction
    
    accuracy  = 100*np.array(accuracy_score(y_real, y_pred)).round(4)
    precision = 100*np.array(precision_score(y_real, y_pred, average=None)).round(4)[1]
    recall    = 100*np.array(recall_score(y_real, y_pred, average=None)).round(4)[1]
    f1        = 100*np.array(f1_score(y_real, y_pred, average=None)).round(4)[1]
    
    accuracy_list.append(accuracy)
    precision_list.append(precision)
    recall_list.append(recall)
    f1_list.append(f1)
    
accuracies = np.array(accuracy_list)
precisions = np.array(precision_list)
recalls = np.array(recall_list)
f1s = np.array(f1_list)

results = pd.DataFrame(np.array([accuracies, precisions, recalls, f1s]).T, columns=['accuracy', 'precision', 'recall', 'f1-score'])
results.describe()
# Out:
#         accuracy  precision     recall   f1-score
# count  10.000000  10.000000  10.000000  10.000000
# mean   69.788000   4.459000  58.388000   8.286000
# std     0.713455   0.768092  11.321975   1.439546
# min    68.530000   3.290000  41.940000   6.100000
# 25%    69.610000   3.912500  50.807500   7.265000
# 50%    69.705000   4.710000  61.290000   8.750000
# 75%    70.025000   4.940000  63.712500   9.172500
# max    71.260000   5.540000  77.420000  10.340000

# %% [markdown]
# # Case 2: with window

# %%
x_cat = ['SEQ', 'nS/nT', 'nAli', 'nPos', 'phi_psi', 'SS', 
         'side_-1', 'side_1', 'side_2', 'side_3','side_4', 'side_5']
x_aug = [ST_dataset.columns[x] for x in range(len(ST_dataset.columns)) if x >= 28]
x_cts = ['Proline', 'flexibility']
y_label = ['positivity']

data_x = pd.get_dummies(ST_dataset[x_cts+x_aug+x_cat], columns=x_cat)
data_y = ST_dataset[y_label]

print(data_x.shape)
print(data_y.shape)

print("\nx columns:")
display(pd.Series(data_x.columns))
# Out:
# (6606, 236)
# (6606, 1)
#
# x columns:
# 0                    Proline
# 1                flexibility
# 2            residue_SER_THR
# 3      number_of_hydrophobic
# 4      number_of_hydrophilic
#                ...
# 231              side_5_long
# 232            side_5_normal
# 233               side_5_pro
# 234             side_5_small
# 235        side_5_very_small
# Length: 236, dtype: object

# %%
### split data into train/test dataset ###
split = StratifiedShuffleSplit(n_splits=n_splits, test_size=test_size, random_state=random_state)
arr_x, arr_y = data_x.values, data_y.values # convert dataframe to nd-array 

i=1
train_idx_list, train_x_list, train_y_list, test_idx_list, test_x_list, test_y_list = [], [], [], [], [], []
for train_index, test_index in split.split(arr_x, arr_y):
    train_x = arr_x[train_index]
    train_y = arr_y[train_index]
    test_x = arr_x[test_index]
    test_y = arr_y[test_index]
    
    train_cts = train_x[:,:len(x_cts)]
    test_cts  = test_x[:,:len(x_cts)]
    
    x_min = train_cts.min(axis=0)
    x_max = train_cts.max(axis=0)
    
    train_x[:,:len(x_cts)] = (train_cts-x_min)/(x_max-x_min)
    test_x[:,:len(x_cts)] = (test_cts-x_min)/(x_max-x_min)
    
    print(f"{i}th iteration")
    print("train:", train_x.shape, train_y.shape, "check scale:", train_x.min(), train_x.max())
    print("test: ", test_x.shape, test_y.shape, "check scale:", test_x.min(), test_x.max())
    
    train_idx_list.append(train_index)
    train_x_list.append(train_x)
    train_y_list.append(train_y)
    
    test_idx_list.append(test_index)
    test_x_list.append(test_x)
    test_y_list.append(test_y)
    
    i += 1
# Out:
# 1th iteration
# train: (5284, 236) (5284, 1) check scale: -92.34 1896.2816162109373
# test:  (1322, 236) (1322, 1) check scale: -89.59 1948.8858642578125
# 2th iteration
# train: (5284, 236) (5284, 1) check scale: -92.34 1948.8858642578125
# test:  (1322, 236) (1322, 1) check scale: -92.08 1878.1199951171875
# 3th iteration
# train: (5284, 236) (5284, 1) check scale: -92.34 1948.8858642578125
# test:  (1322, 236) (1322, 1) check scale: -89.59 1931.7716064453125
# 4th iteration
# train: (5284, 236) (5284, 1) check scale: -92.34 1948.8858642578125
# test:  (1322, 236) (1322, 1) check scale: -89.27 1861.9886474609373
# 5th iteration
# train: (5284, 236) (5284, 1) check scale: -92.34 1896.2816162109373
# test:  (1322, 236) (1322, 1) check scale: -86.46 1948.8858642578125
# 6th iteration
# train: (5284, 236) (5284, 1) check scale: -90.39 1948.8858642578125
# test:  (1322, 236) (1322, 1) check scale: -92.34 1878.1199951171875
# 7th iteration
# train: (5284, 236) (5284, 1) check scale: -92.34 1948.8858642578125
# test:  (1322, 236) (1322, 1) check scale: -90.39 1847.023193359375
# 8th iteration
# train: (5284, 236) (5284, 1) check scale: -92.34 1931.7716064453125
# test:  (1322, 236) (1322, 1) check scale: -90.02 1948.8858642578125
# 9th iteration
# train: (5284, 236) (5284, 1) check scale: -92.34 1948.8858642578125
# test:  (1322, 236) (1322, 1) check scale: -90.02 1931.7716064453125
# 10th iteration
# train: (5284, 236) (5284, 1) check scale: -92.08 1948.8858642578125
# test:  (1322, 236) (1322, 1) check scale: -92.34 1931.7716064453125

# %%
## upsampling dataset 
upsample_x_list, upsample_y_list = [], []
for train_x, train_y in zip(train_x_list, train_y_list):
    index_pos = np.where(train_y == 1)[0]
    index_neg = np.where(train_y == 0)[0]

    random.seed(random_state)
    up_index = [random.choice(index_pos) for _ in range(len(index_neg))] # get samples from positive sites as much as the number of negative sites

    upsample_pos_x = train_x[up_index]
    upsample_pos_y = train_y[up_index]
    sample_neg_x = train_x[index_neg]
    sample_neg_y = train_y[index_neg]

    sample_x = np.concatenate([upsample_pos_x, sample_neg_x], axis=0)
    sample_y = np.concatenate([upsample_pos_y, sample_neg_y], axis=0)

    shuffle_index = np.arange(len(sample_x))
    np.random.seed(random_state)
    np.random.shuffle(shuffle_index)
    sample_x = sample_x[shuffle_index]
    sample_y = sample_y[shuffle_index]
    
    upsample_x_list.append(sample_x)
    upsample_y_list.append(sample_y)

print("up-sampled train dataset:", sample_x.shape, sample_y.shape)
print("test dataset:", test_x.shape, test_y.shape)
# Out:
# up-sampled train dataset: (10316, 236) (10316, 1)
# test dataset: (1322, 236) (1322, 1)

# %%
## hyper-parameter optimization
model_type = 'augmented_MLP_original'

train_x = upsample_x_list[0]
train_y = upsample_y_list[0]
test_x = test_x_list[0]
test_y = test_y_list[0]

hpo_result = pd.DataFrame([], columns=metrics)
for i in range(counts):
    random.seed(i+1)
    n_layers = random.choice(parameter_config["n_layers"])
    n_neurons = random.choice(parameter_config["n_neurons"])
    print(f"random, {i+1} of {counts}: {n_layers} layers, {n_neurons} neurons")
    
    model_name = f'{version}_{model_type}_hpo_{i+1}of{counts}'
    save_path  = f'./model/{model_name}.h5'
    score_path = f"./score/{model_name}.csv"
    
    x_dim = train_x.shape[1]
    y_dim = train_y.shape[1]

    model = basicMLP(x_dim, y_dim, n_layers, n_neurons)
    if not exists(save_path) or update:
        tf.random.set_seed(i+1)
        
        time_start = time.time()
        history = model.fit(train_x, train_y, verbose=0,
                            epochs=10000, callbacks=[early_stopping_cb], validation_split= valid_size)
        time_end = time.time()
        time_elapse = round((time_end - time_start)/60, 3)
        
        model.save_weights(save_path)
        print(f"model is saved to: {save_path}")
        
        idx = np.array(history.history[monitor]).argmin()
        val_loss = history.history['val_loss'][idx]
        loss = history.history['loss'][idx]
        test_loss = model.evaluate(test_x, test_y, verbose=0)[0]
        prediction = model.predict(test_x, verbose=0)
        prediction = prediction.round(0).astype(int)
        y_real = test_y
        y_pred = prediction
        accuracy, precision, recall, f1 = scores(y_real, y_pred)
        scores_df = pd.DataFrame([[time_elapse, n_layers, n_neurons, loss, val_loss, test_loss, accuracy, precision, recall, f1]], 
                                  columns=metrics)

        scores_df.to_csv(score_path)
        print(f"history is saved to: {score_path}")

    else:
        scores_df = pd.read_csv(score_path, index_col=0, header=0)
        print(f"history is loaded from: {score_path}")
        
    hpo_result = pd.concat([hpo_result, scores_df], axis=0)

hpo_result = hpo_result.reset_index(drop=True)
# Out:
# random, 1 of 30: 3 layers, 256 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_1of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_1of30.csv
# random, 2 of 30: 1 layers, 16 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_2of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_2of30.csv
# random, 3 of 30: 4 layers, 256 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_3of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_3of30.csv
# random, 4 of 30: 4 layers, 64 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_4of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_4of30.csv
# random, 5 of 30: 10 layers, 64 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_5of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_5of30.csv
# random, 6 of 30: 10 layers, 16 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_6of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_6of30.csv
# random, 7 of 30: 6 layers, 32 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_7of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_7of30.csv
# random, 8 of 30: 4 layers, 64 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_8of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_8of30.csv
# random, 9 of 30: 8 layers, 256 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_9of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_9of30.csv
# random, 10 of 30: 10 layers, 16 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_10of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_10of30.csv
# random, 11 of 30: 8 layers, 256 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_11of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_11of30.csv
# random, 12 of 30: 8 layers, 64 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_12of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_12of30.csv
# random, 13 of 30: 5 layers, 64 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_13of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_13of30.csv
# random, 14 of 30: 2 layers, 256 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_14of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_14of30.csv
# random, 15 of 30: 4 layers, 16 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_15of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_15of30.csv
# random, 16 of 30: 6 layers, 128 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_16of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_16of30.csv
# random, 17 of 30: 9 layers, 128 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_17of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_17of30.csv
# random, 18 of 30: 3 layers, 16 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_18of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_18of30.csv
# random, 19 of 30: 1 layers, 256 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_19of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_19of30.csv
# random, 20 of 30: 3 layers, 64 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_20of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_20of30.csv
# random, 21 of 30: 3 layers, 128 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_21of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_21of30.csv
# random, 22 of 30: 3 layers, 32 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_22of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_22of30.csv
# random, 23 of 30: 5 layers, 16 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_23of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_23of30.csv
# random, 24 of 30: 7 layers, 256 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_24of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_24of30.csv
# random, 25 of 30: 7 layers, 16 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_25of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_25of30.csv
# random, 26 of 30: 4 layers, 32 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_26of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_26of30.csv
# random, 27 of 30: 8 layers, 64 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_27of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_27of30.csv
# random, 28 of 30: 2 layers, 32 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_28of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_28of30.csv
# random, 29 of 30: 9 layers, 16 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_29of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_29of30.csv
# random, 30 of 30: 9 layers, 64 neurons
# model is saved to: ./model/v4_augmented_MLP_original_hpo_30of30.h5
# history is saved to: ./score/v4_augmented_MLP_original_hpo_30of30.csv

# %%
# show the HPO result
target_metric = 'f1'
best_idx = hpo_result[target_metric].argmax()
best_parameters = hpo_result.iloc[best_idx]
print(f'best hyperparamerter: index {best_idx}')
display(best_parameters)

display(hpo_result.describe())
# Out:
# best hyperparamerter: index 25
# time            1.607
# n_layers            4
# n_neurons          32
# loss         0.498281
# val_loss     0.485832
# test_loss    0.497361
# accuracy        74.81
# precision        4.79
# recall          51.61
# f1               8.77
# Name: 25, dtype: object
#             time       loss   val_loss  test_loss   accuracy  precision  \
# count  30.000000  30.000000  30.000000  30.000000  30.000000  30.000000
# mean    1.829667   0.510184   0.487649   0.538598  72.498333   4.038667
# std     0.749112   0.023358   0.008610   0.031966   2.107262   0.324406
# min     0.711000   0.481340   0.473734   0.454884  68.380000   3.300000
# 25%     1.413500   0.496366   0.481383   0.521505  71.100000   3.855000
# 50%     1.606000   0.503631   0.484957   0.540908  71.975000   3.990000
# 75%     2.183750   0.514476   0.492757   0.560837  74.032500   4.292500
# max     3.416000   0.598136   0.509225   0.600670  77.990000   4.790000
#
#           recall         f1
# count  30.000000  30.000000
# mean   47.097667   7.435667
# std     5.124425   0.593486
# min    38.710000   6.080000
# 25%    42.745000   7.082500
# 50%    46.775000   7.330000
# 75%    51.610000   7.880000
# max    54.840000   8.770000

# %%
# bulid model
n_layers = best_parameters['n_layers']
n_neurons = best_parameters['n_neurons']

i=1
for train_x, train_y in zip(upsample_x_list, upsample_y_list):
    print(f"{i}th iteration")
    model_name = f'{version}_{model_type}_{n_layers}_{n_neurons}_cv_{i}of{n_splits}'
    save_path  = f'./model/{model_name}.h5'
    
    if not exists(save_path) or update:
        x_dim = train_x.shape[1]
        y_dim = train_y.shape[1]
        model = basicMLP(x_dim, y_dim, n_layers, n_neurons)

        if not exists(save_path) or update:
            tf.random.set_seed(random_state)
            history = model.fit(train_x, train_y, verbose=0,
                                epochs=10000, callbacks=[early_stopping_cb], validation_split= valid_size)
            model.save_weights(save_path)
            print(f"model is saved to: {save_path}")
    else:
        print(f"model already exists at: {save_path}")
    i += 1
display(model.summary())
# Out:
# 1th iteration
# model is saved to: ./model/v4_augmented_MLP_original_4_32_cv_1of10.h5
# 2th iteration
# model is saved to: ./model/v4_augmented_MLP_original_4_32_cv_2of10.h5
# 3th iteration
# model is saved to: ./model/v4_augmented_MLP_original_4_32_cv_3of10.h5
# 4th iteration
# model is saved to: ./model/v4_augmented_MLP_original_4_32_cv_4of10.h5
# 5th iteration
# model is saved to: ./model/v4_augmented_MLP_original_4_32_cv_5of10.h5
# 6th iteration
# model is saved to: ./model/v4_augmented_MLP_original_4_32_cv_6of10.h5
# 7th iteration
# model is saved to: ./model/v4_augmented_MLP_original_4_32_cv_7of10.h5
# 8th iteration
# model is saved to: ./model/v4_augmented_MLP_original_4_32_cv_8of10.h5
# 9th iteration
# model is saved to: ./model/v4_augmented_MLP_original_4_32_cv_9of10.h5
# 10th iteration
# model is saved to: ./model/v4_augmented_MLP_original_4_32_cv_10of10.h5
# Model: "model_89"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_input (InputLayer)    [(None, 236)]             0
#
#  dense_1 (Dense)             (None, 32)                7584
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dense_3 (Dense)             (None, 32)                1056
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dense_output (Dense)        (None, 1)                 33
#
# =================================================================
# Total params: 10,785
# Trainable params: 10,785
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# evaluate the trained model
i=1
accuracy_list, precision_list, recall_list, f1_list = [], [], [], []
for test_x, test_y in zip(test_x_list, test_y_list):
    model_name = f'{version}_{model_type}_{n_layers}_{n_neurons}_cv_{i}of{n_splits}'
    save_path  = f'./model/{model_name}.h5'
    
    model = basicMLP(x_dim, y_dim, n_layers, n_neurons)
    model.load_weights(save_path)
    
    prediction = model.predict(test_x, verbose=0)
    prediction = prediction.round(0).astype(int)

    y_real = test_y
    y_pred = prediction
    
    accuracy  = 100*np.array(accuracy_score(y_real, y_pred)).round(4)
    precision = 100*np.array(precision_score(y_real, y_pred, average=None)).round(4)[1]
    recall    = 100*np.array(recall_score(y_real, y_pred, average=None)).round(4)[1]
    f1        = 100*np.array(f1_score(y_real, y_pred, average=None)).round(4)[1]
    
    accuracy_list.append(accuracy)
    precision_list.append(precision)
    recall_list.append(recall)
    f1_list.append(f1)
    
accuracies = np.array(accuracy_list)
precisions = np.array(precision_list)
recalls = np.array(recall_list)
f1s = np.array(f1_list)

results = pd.DataFrame(np.array([accuracies, precisions, recalls, f1s]).T, columns=['accuracy', 'precision', 'recall', 'f1-score'])
results.describe()
# Out:
#         accuracy  precision     recall   f1-score
# count  10.000000  10.000000  10.000000  10.000000
# mean   75.868000   6.714000  72.258000  12.282000
# std     0.838289   1.034399  12.650023   1.909123
# min    74.960000   4.400000  45.160000   8.020000
# 25%    75.280000   6.515000  68.547500  11.920000
# 50%    75.605000   6.955000  72.580000  12.700000
# 75%    76.472500   7.147500  79.842500  13.117500
# max    77.380000   7.900000  90.320000  14.470000
