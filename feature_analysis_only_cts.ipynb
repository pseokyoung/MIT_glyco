# %% [markdown]
# # Header

# %%
import numpy as np
import pandas as pd
import scipy as sp
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from os.path import exists

# %% [markdown]
# ## original dataset

# %%
load_path = f"./data/data_for_ml.csv"
original_data = pd.read_csv(load_path)
original_data = original_data[(original_data['SEQ']=='S') | (original_data['SEQ']=='T')]

original_features = dict(
    zip(range(0, len(original_data.columns)), original_data.columns)
)
display(original_features)
# Out:
# {0: '#',
#  1: 'SEQ',
#  2: 'SS',
#  3: 'ASA',
#  4: 'Phi',
#  5: 'Psi',
#  6: 'Theta(i-1=>i+1)',
#  7: 'Tau(i-2=>i+2)',
#  8: 'HSE_alpha_up',
#  9: 'HSE_alpha_down',
#  10: 'P(C)',
#  11: 'P(H)',
#  12: 'P(E)',
#  13: 'flexibility',
#  14: 'side_-1',
#  15: 'side_1',
#  16: 'side_2',
#  17: 'side_3',
#  18: 'side_4',
#  19: 'side_5',
#  20: 'nAli',
#  21: 'nPos',
#  22: 'nS/nT',
#  23: 'Proline',
#  24: 'phi_psi',
#  25: 'positivity',
#  26: 'protein'}

# %%
original_x = list(original_data.columns[3:14]) + list(original_data.columns[20:24])
original_y = 'positivity'

# %% [markdown]
# ## augmented dataset

# %%
protein_list = list(original_data.protein.unique())
protein_augmented = [name for name in protein_list if exists(f'./data/data_for_ml(augmented)/{name}.csv')]

augmented_data = []
for name in protein_augmented:
    load_path = f'./data/data_for_ml(augmented)/{name}.csv'
    augmented_data.append(pd.read_csv(load_path))
augmented_data = pd.concat(augmented_data, axis=0).reset_index(drop=True)
augmented_data = augmented_data[(augmented_data['SEQ']=='S') | (augmented_data['SEQ']=='T')].reset_index(drop=True)

augmented_features = dict(
    zip(range(0, len(augmented_data.columns)), augmented_data.columns)
)
display(augmented_features)
# Out:
# {0: '#',
#  1: 'SEQ',
#  2: 'SS',
#  3: 'ASA',
#  4: 'Phi',
#  5: 'Psi',
#  6: 'Theta(i-1=>i+1)',
#  7: 'Tau(i-2=>i+2)',
#  8: 'HSE_alpha_up',
#  9: 'HSE_alpha_down',
#  10: 'P(C)',
#  11: 'P(H)',
#  12: 'P(E)',
#  13: 'flexibility',
#  14: 'side_-1',
#  15: 'side_1',
#  16: 'side_2',
#  17: 'side_3',
#  18: 'side_4',
#  19: 'side_5',
#  20: 'nAli',
#  21: 'nPos',
#  22: 'nS/nT',
#  23: 'Proline',
#  24: 'phi_psi',
#  25: 'positivity',
#  26: 'residue_SER_THR',
#  27: 'number_of_hydrophobic',
#  28: 'number_of_hydrophilic',
#  29: 'number_of_polar',
#  30: 'number_of_aromatic',
#  31: 'number_of_aliphatic',
#  32: 'number_of_charged',
#  33: 'number_of_positive',
#  34: 'number_of_negative',
#  35: 'number_of_g',
#  36: 'number_of_v',
#  37: 'number_of_s',
#  38: 'number_of_n',
#  39: 'number_of_l',
#  40: 'number_of_p',
#  41: 'number_of_A',
#  42: 'number_of_b',
#  43: 'number_of_d',
#  44: 'number_of_e',
#  45: 'number_of_f',
#  46: 'number_of_ala',
#  47: 'number_of_cys',
#  48: 'number_of_asp',
#  49: 'number_of_glu',
#  50: 'number_of_phe',
#  51: 'number_of_his',
#  52: 'number_of_ile',
#  53: 'number_of_lys',
#  54: 'number_of_leu',
#  55: 'number_of_met',
#  56: 'number_of_asn',
#  57: 'number_of_gln',
#  58: 'number_of_arg',
#  59: 'number_of_ser',
#  60: 'number_of_thr',
#  61: 'number_of_val',
#  62: 'number_of_trp',
#  63: 'number_of_tyr',
#  64: 'sasa_hydrophobic',
#  65: 'sasa_hydrophilic',
#  66: 'sasa_polar',
#  67: 'sasa_aromatic',
#  68: 'sasa_aliphatic',
#  69: 'sasa_charged',
#  70: 'sasa_positive',
#  71: 'sasa_negative',
#  72: 'sasa_g',
#  73: 'sasa_v',
#  74: 'sasa_s',
#  75: 'sasa_n',
#  76: 'sasa_l',
#  77: 'sasa_p',
#  78: 'sasa_A',
#  79: 'sasa_b',
#  80: 'sasa_d',
#  81: 'sasa_e',
#  82: 'sasa_f',
#  83: 'sasa_ala',
#  84: 'sasa_cys',
#  85: 'sasa_asp',
#  86: 'sasa_glu',
#  87: 'sasa_phe',
#  88: 'sasa_his',
#  89: 'sasa_ile',
#  90: 'sasa_lys',
#  91: 'sasa_leu',
#  92: 'sasa_met',
#  93: 'sasa_asn',
#  94: 'sasa_gln',
#  95: 'sasa_arg',
#  96: 'sasa_ser',
#  97: 'sasa_thr',
#  98: 'sasa_val',
#  99: 'sasa_trp',
#  100: 'sasa_tyr',
#  101: 'all_sasa_hydrophobic',
#  102: 'all_sasa_hydrophilic',
#  103: 'all_sasa_polar',
#  104: 'all_sasa_aromatic',
#  105: 'all_sasa_aliphatic',
#  106: 'all_sasa_charged',
#  107: 'all_sasa_positive',
#  108: 'all_sasa_negative',
#  109: 'all_sasa_g',
#  110: 'all_sasa_v',
#  111: 'all_sasa_s',
#  112: 'all_sasa_n',
#  113: 'all_sasa_l',
#  114: 'all_sasa_p',
#  115: 'all_sasa_A',
#  116: 'all_sasa_b',
#  117: 'all_sasa_d',
#  118: 'all_sasa_e',
#  119: 'all_sasa_f',
#  120: 'all_sasa_ala',
#  121: 'all_sasa_cys',
#  122: 'all_sasa_asp',
#  123: 'all_sasa_glu',
#  124: 'all_sasa_phe',
#  125: 'all_sasa_his',
#  126: 'all_sasa_ile',
#  127: 'all_sasa_lys',
#  128: 'all_sasa_leu',
#  129: 'all_sasa_met',
#  130: 'all_sasa_asn',
#  131: 'all_sasa_gln',
#  132: 'all_sasa_arg',
#  133: 'all_sasa_ser',
#  134: 'all_sasa_thr',
#  135: 'all_sasa_val',
#  136: 'all_sasa_trp',
#  137: 'all_sasa_tyr',
#  138: 'sasa_back',
#  139: 'all_sasa_back',
#  140: 'sasa_side',
#  141: 'all_sasa_side',
#  142: 'all_sasa_back_with_whole_target',
#  143: 'all_sasa_side_with_whole_target',
#  144: 'sasa_target_ser_thr',
#  145: 'sasa_all_around_target_ser_thr',
#  146: 'sasa_all_with_around_target_ser_thr',
#  147: 'net_charge_all_around_target_ser_thr',
#  148: 'net_charge_all_with_around_target_ser_thr',
#  149: 'net_charge_all_backbone_around_target_ser_thr',
#  150: 'net_charge_all_sidechain_around_target_ser_thr',
#  151: 'net_charge_all_backbone_with_around_target_ser_thr',
#  152: 'net_charge_all_sidechain_with_around_target_ser_thr',
#  153: 'all_atom_positive_charge_all_around_target_ser_thr',
#  154: 'all_atom_positive_charge_all_with_around_target_ser_thr',
#  155: 'all_atom_positive_charge_all_backbone_around_target_ser_thr',
#  156: 'all_atom_positive_charge_all_sidechain_around_target_ser_thr',
#  157: 'all_atom_positive_charge_all_backbone_with_around_target_ser_thr',
#  158: 'all_atom_positive_charge_all_sidechain_with_around_target_ser_thr',
#  159: 'all_atom_negative_charge_all_around_target_ser_thr',
#  160: 'all_atom_negative_charge_all_with_around_target_ser_thr',
#  161: 'all_atom_negative_charge_all_backbone_around_target_ser_thr',
#  162: 'all_atom_negative_charge_all_sidechain_around_target_ser_thr',
#  163: 'all_atom_negative_charge_all_backbone_with_around_target_ser_thr',
#  164: 'all_atom_negative_charge_all_sidechain_with_around_target_ser_thr',
#  165: 'exposed_charge_all_around_target_ser_thr',
#  166: 'exposed_charge_all_with_around_target_ser_thr',
#  167: 'exposed_charge_all_backbone_around_target_ser_thr',
#  168: 'exposed_charge_all_sidechain_around_target_ser_thr',
#  169: 'exposed_charge_all_backbone_with_around_target_ser_thr',
#  170: 'exposed_charge_all_sidechain_with_around_target_ser_thr',
#  171: 'exposed_positive_charge_all_around_target_ser_thr',
#  172: 'exposed_positive_charge_all_with_around_target_ser_thr',
#  173: 'exposed_positive_charge_all_backbone_around_target_ser_thr',
#  174: 'exposed_positive_charge_all_sidechain_around_target_ser_thr',
#  175: 'exposed_positive_charge_all_backbone_with_around_target_ser_thr',
#  176: 'exposed_positive_charge_all_sidechain_with_around_target_ser_thr',
#  177: 'exposed_negative_charge_all_around_target_ser_thr',
#  178: 'exposed_negative_charge_all_with_around_target_ser_thr',
#  179: 'exposed_negative_charge_all_backbone_around_target_ser_thr',
#  180: 'exposed_negative_charge_all_sidechain_around_target_ser_thr',
#  181: 'exposed_negative_charge_all_backbone_with_around_target_ser_thr'}

# %%
augmented_x = list(augmented_data.columns[26:])
augmented_y = 'positivity'

# %%
both_x = original_x + augmented_x
both_y = 'positivity'

# %% [markdown]
# # ElasticNet model

# %%
from sklearn.linear_model import ElasticNet

def elasticnet(data, x=[], y='', 
               alpha=0.001, l1_ratio=0.5):
    data_x = data[x]
    data_y = data[y]
    
    x_min = data_x.min(0)
    x_max = data_x.max(0)
    data_x_sc = (data_x - x_min) / (x_max - x_min)
    
    elastic_model = ElasticNet(alpha=alpha, l1_ratio=l1_ratio)
    elastic_model.fit(data_x_sc, data_y)
    
    return elastic_model

def elastic_coeff(model, x, rnd=3, disp=False):
    df = pd.DataFrame(
        zip(x, model.coef_, np.abs(model.coef_)
           ), columns = ['features', 'coefficient', 'absolute'] )
    df = df.sort_values(by='absolute', ascending=False).round(rnd)
    if disp:
        display(df.head(disp))
        
    df_important = df[df['absolute']>0]
    print(f'the number of important features: {len(df_important)} out of {len(x)} \n')
    display(dict(zip(df_important['features'], df_important['coefficient'])))
    
    return list(df_important['features'])

# %% [markdown]
# ## original dataset

# %%
data = original_data
x = original_x
y = original_y

alpha = 0.0001
model = elasticnet(data, x, y, alpha)
features = elastic_coeff(model, x)
# Out:
# the number of important features: 11 out of 15
# {'nS/nT': 0.029,
#  'ASA': 0.019,
#  'nAli': 0.015,
#  'HSE_alpha_down': -0.012,
#  'nPos': 0.011,
#  'flexibility': 0.01,
#  'Proline': -0.009,
#  'Theta(i-1=>i+1)': 0.009,
#  'Tau(i-2=>i+2)': -0.006,
#  'HSE_alpha_up': 0.004,
#  'P(E)': -0.001}

# %% [markdown]
# ## augmented dataset

# %%
data = augmented_data
x = augmented_x
y = augmented_y
alpha = 0.0001

model = elasticnet(data, x, y, alpha)
features = elastic_coeff(model, x)
# Out:
# the number of important features: 38 out of 156
# {'sasa_ala': 0.047,
#  'sasa_g': 0.034,
#  'all_sasa_lys': -0.032,
#  'number_of_asn': -0.025,
#  'number_of_g': -0.023,
#  'sasa_ser': 0.022,
#  'sasa_cys': -0.021,
#  'sasa_p': 0.02,
#  'number_of_ser': 0.018,
#  'number_of_thr': -0.017,
#  'sasa_lys': -0.016,
#  'sasa_val': -0.016,
#  'number_of_leu': -0.014,
#  'sasa_negative': 0.013,
#  'net_charge_all_around_target_ser_thr': 0.012,
#  'sasa_ile': -0.011,
#  'sasa_s': -0.011,
#  'sasa_leu': -0.01,
#  'exposed_charge_all_sidechain_with_around_target_ser_thr': -0.009,
#  'all_sasa_aliphatic': -0.009,
#  'sasa_back': -0.009,
#  'number_of_lys': 0.008,
#  'exposed_charge_all_with_around_target_ser_thr': -0.008,
#  'sasa_polar': -0.008,
#  'sasa_phe': -0.008,
#  'exposed_positive_charge_all_with_around_target_ser_thr': -0.007,
#  'number_of_polar': -0.007,
#  'number_of_charged': -0.007,
#  'number_of_e': -0.007,
#  'sasa_e': -0.007,
#  'all_atom_negative_charge_all_backbone_around_target_ser_thr': 0.005,
#  'number_of_l': -0.004,
#  'sasa_f': 0.004,
#  'all_sasa_met': -0.003,
#  'sasa_met': -0.003,
#  'number_of_n': -0.002,
#  'number_of_negative': -0.002,
#  'all_sasa_glu': -0.002}

# %% [markdown]
# ## both dataset

# %%
data = augmented_data
x = both_x
y = both_y
alpha = 0.0001

model = elasticnet(data, x, y, alpha)
features = elastic_coeff(model, x)
# Out:
# the number of important features: 43 out of 171
# {'sasa_ala': 0.059,
#  'all_sasa_lys': -0.048,
#  'nS/nT': 0.044,
#  'HSE_alpha_down': -0.037,
#  'sasa_ser': 0.029,
#  'sasa_g': 0.026,
#  'sasa_negative': 0.022,
#  'ASA': 0.021,
#  'nAli': 0.02,
#  'number_of_asn': -0.019,
#  'number_of_thr': -0.019,
#  'sasa_val': -0.015,
#  'Theta(i-1=>i+1)': 0.014,
#  'number_of_v': 0.014,
#  'exposed_charge_all_sidechain_with_around_target_ser_thr': -0.014,
#  'net_charge_all_around_target_ser_thr': 0.013,
#  'sasa_ile': -0.013,
#  'Proline': -0.011,
#  'sasa_cys': -0.01,
#  'P(H)': 0.01,
#  'number_of_lys': 0.01,
#  'sasa_back': -0.01,
#  'Tau(i-2=>i+2)': -0.01,
#  'number_of_leu': -0.009,
#  'all_sasa_leu': -0.009,
#  'number_of_ser': 0.009,
#  'number_of_l': -0.007,
#  'all_sasa_cys': -0.007,
#  'all_sasa_phe': -0.007,
#  'P(E)': -0.007,
#  'number_of_g': -0.006,
#  'exposed_charge_all_with_around_target_ser_thr': -0.006,
#  'number_of_arg': -0.005,
#  'sasa_polar': -0.004,
#  'sasa_s': -0.004,
#  'sasa_e': -0.004,
#  'sasa_leu': -0.003,
#  'exposed_positive_charge_all_with_around_target_ser_thr': -0.003,
#  'number_of_n': -0.002,
#  'sasa_lys': -0.002,
#  'all_sasa_met': -0.002,
#  'number_of_e': -0.001,
#  'number_of_polar': -0.001}

# %% [markdown]
# # ANOVA model

# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm

def anova(data, x=[], y='',
          disp=False, rnd=4):
    data = data[x + [y]]

    f_num = [f"f{num}" for num in range(len(x))]
    data.columns =  f_num + [y]

    n_not = len(f_num) # the number of not important features (initialize to the number of features)
    i = 1
    while n_not > 0:
        print(f'{i}th iteration')
        fs = '+'.join(f_num) 
        model = smf.ols(
            y + '~' + fs,
            data).fit()

        result = sm.stats.anova_lm(model, typ=2).round(rnd)
        n_not = len(result[result['PR(>F)'] > 0.05])
        f_num = [fn for fn in result[result['PR(>F)'] <= 0.05].index]

        i += 1

    result = result.sort_values(by='PR(>F)')
    print(f'the number of important features: {len(f_num)} out of {len(x)}')

    if disp:
        n = 10
        i = 0
        while i < len(result):
            print(result.iloc[i:i+n, :])
            i += n

    x_idx = [int(x.removeprefix('f')) for x in result.index[:-1]]
    x_names = [x[idx] for idx in x_idx]

    print('\norder variables by their importance')
    display(dict(zip(x_idx, x_names)))
    
    return x_names

# %% [markdown]
# ## original dataset

# %%
data = original_data
x = original_x
y = original_y

features = anova(data, x, y)
# Out:
# 1th iteration
# 2th iteration
# the number of important features: 10 out of 15
#
# order variables by their importance
# {0: 'ASA',
#  11: 'nAli',
#  12: 'nPos',
#  13: 'nS/nT',
#  14: 'Proline',
#  6: 'HSE_alpha_down',
#  10: 'flexibility',
#  4: 'Tau(i-2=>i+2)',
#  3: 'Theta(i-1=>i+1)',
#  5: 'HSE_alpha_up'}

# %% [markdown]
# ## augmented dataset

# %%
data = augmented_data
x = augmented_x
y = augmented_y

features = anova(data, x, y)
# Out:
# 1th iteration
# 2th iteration
# 3th iteration
# the number of important features: 41 out of 156
#
# order variables by their importance
# {35: 'number_of_val',
#  28: 'number_of_leu',
#  17: 'number_of_d',
#  11: 'number_of_s',
#  27: 'number_of_lys',
#  22: 'number_of_asp',
#  19: 'number_of_f',
#  18: 'number_of_e',
#  12: 'number_of_n',
#  8: 'number_of_negative',
#  3: 'number_of_polar',
#  6: 'number_of_charged',
#  24: 'number_of_phe',
#  124: 'net_charge_all_sidechain_around_target_ser_thr',
#  126: 'net_charge_all_sidechain_with_around_target_ser_thr',
#  123: 'net_charge_all_backbone_around_target_ser_thr',
#  122: 'net_charge_all_with_around_target_ser_thr',
#  121: 'net_charge_all_around_target_ser_thr',
#  120: 'sasa_all_with_around_target_ser_thr',
#  127: 'all_atom_positive_charge_all_around_target_ser_thr',
#  128: 'all_atom_positive_charge_all_with_around_target_ser_thr',
#  129: 'all_atom_positive_charge_all_backbone_around_target_ser_thr',
#  125: 'net_charge_all_backbone_with_around_target_ser_thr',
#  131: 'all_atom_positive_charge_all_backbone_with_around_target_ser_thr',
#  130: 'all_atom_positive_charge_all_sidechain_around_target_ser_thr',
#  2: 'number_of_hydrophilic',
#  34: 'number_of_thr',
#  5: 'number_of_aliphatic',
#  16: 'number_of_b',
#  7: 'number_of_positive',
#  9: 'number_of_g',
#  25: 'number_of_his',
#  13: 'number_of_l',
#  0: 'residue_SER_THR',
#  21: 'number_of_cys',
#  36: 'number_of_trp',
#  14: 'number_of_p',
#  4: 'number_of_aromatic',
#  10: 'number_of_v',
#  23: 'number_of_glu',
#  15: 'number_of_A'}

# %% [markdown]
# ## both dataset

# %%
data = augmented_data
x = both_x
y = both_y

features = anova(data, x, y)
# Out:
# 1th iteration
# 2th iteration
# 3th iteration
# 4th iteration
# 5th iteration
# the number of important features: 50 out of 171
#
# order variables by their importance
# {6: 'HSE_alpha_down',
#  13: 'nS/nT',
#  11: 'nAli',
#  35: 'number_of_ala',
#  48: 'number_of_ser',
#  43: 'number_of_leu',
#  32: 'number_of_d',
#  37: 'number_of_asp',
#  34: 'number_of_f',
#  42: 'number_of_lys',
#  26: 'number_of_s',
#  46: 'number_of_gln',
#  19: 'number_of_aromatic',
#  39: 'number_of_phe',
#  21: 'number_of_charged',
#  144: 'all_atom_positive_charge_all_backbone_around_target_ser_thr',
#  143: 'all_atom_positive_charge_all_with_around_target_ser_thr',
#  135: 'sasa_all_with_around_target_ser_thr',
#  141: 'net_charge_all_sidechain_with_around_target_ser_thr',
#  136: 'net_charge_all_around_target_ser_thr',
#  137: 'net_charge_all_with_around_target_ser_thr',
#  139: 'net_charge_all_sidechain_around_target_ser_thr',
#  140: 'net_charge_all_backbone_with_around_target_ser_thr',
#  142: 'all_atom_positive_charge_all_around_target_ser_thr',
#  138: 'net_charge_all_backbone_around_target_ser_thr',
#  146: 'all_atom_positive_charge_all_backbone_with_around_target_ser_thr',
#  145: 'all_atom_positive_charge_all_sidechain_around_target_ser_thr',
#  27: 'number_of_n',
#  17: 'number_of_hydrophilic',
#  28: 'number_of_l',
#  29: 'number_of_p',
#  18: 'number_of_polar',
#  24: 'number_of_g',
#  16: 'number_of_hydrophobic',
#  33: 'number_of_e',
#  31: 'number_of_b',
#  22: 'number_of_positive',
#  49: 'number_of_thr',
#  20: 'number_of_aliphatic',
#  15: 'residue_SER_THR',
#  41: 'number_of_ile',
#  36: 'number_of_cys',
#  40: 'number_of_his',
#  30: 'number_of_A',
#  23: 'number_of_negative',
#  25: 'number_of_v',
#  47: 'number_of_arg',
#  50: 'number_of_val',
#  38: 'number_of_glu',
#  4: 'Tau(i-2=>i+2)'}

# %% [markdown]
# # Random Forest model

# %%
from sklearn.ensemble import RandomForestClassifier

def randomforest(data, x=[], y='',
                 n_estimators=500, rs=1):
    model = RandomForestClassifier(n_estimators = n_estimators, n_jobs=-1, random_state=rs)
    model.fit(data[x], data[y])
    
    return model

def FI(model, threshold= 0.95, rnd=3, disp=False):
    df = pd.DataFrame(zip(x, model.feature_importances_), columns = ['features', 'score'])
    df = df.sort_values(by='score', ascending=False)

    score_sum = []
    s = 1
    for score in df.score:
        s -= score
        score_sum.append(s)
    df['sum'] = np.array(score_sum)
    df = df.round(rnd)
    
    if disp:
        display(df.head(disp))

    
    df_important = df[df['sum']>= 1-threshold]

    print(f'the number of important features (threshold={threshold}): {len(df_important)} out of {len(df)}')
    display(dict(
        zip(df_important.index, zip(df_important['features'].values, df_important['score'].values, df_important['sum'].values))
    ))
    
    return list(df_important['features'])

# %% [markdown]
# ## original dataset

# %%
data = original_data
x = original_x
y = original_y

model = randomforest(data, x, y)
features = FI(model)
# Out:
# the number of important features (threshold=0.95): 11 out of 15
# {4: ('Tau(i-2=>i+2)', 0.096, 0.904),
#  0: ('ASA', 0.09, 0.814),
#  10: ('flexibility', 0.086, 0.728),
#  2: ('Psi', 0.086, 0.641),
#  1: ('Phi', 0.083, 0.559),
#  7: ('P(C)', 0.081, 0.478),
#  5: ('HSE_alpha_up', 0.079, 0.398),
#  6: ('HSE_alpha_down', 0.078, 0.32),
#  3: ('Theta(i-1=>i+1)', 0.077, 0.243),
#  8: ('P(H)', 0.077, 0.166),
#  9: ('P(E)', 0.073, 0.092)}

# %% [markdown]
# ## augmented dataset

# %%
data = augmented_data
x = augmented_x
y = augmented_y 

model = randomforest(data, x, y)
features = FI(model)
# Out:
# the number of important features (threshold=0.95): 129 out of 156
# {107: ('all_sasa_ser', 0.014, 0.986),
#  83: ('all_sasa_g', 0.013, 0.974),
#  88: ('all_sasa_p', 0.012, 0.961),
#  94: ('all_sasa_ala', 0.012, 0.949),
#  70: ('sasa_ser', 0.011, 0.938),
#  51: ('sasa_p', 0.011, 0.927),
#  82: ('all_sasa_negative', 0.011, 0.916),
#  108: ('all_sasa_thr', 0.011, 0.905),
#  106: ('all_sasa_arg', 0.011, 0.893),
#  78: ('all_sasa_aromatic', 0.01, 0.883),
#  93: ('all_sasa_f', 0.01, 0.873),
#  69: ('sasa_arg', 0.01, 0.863),
#  76: ('all_sasa_hydrophilic', 0.01, 0.852),
#  105: ('all_sasa_gln', 0.01, 0.842),
#  99: ('all_sasa_his', 0.01, 0.832),
#  39: ('sasa_hydrophilic', 0.01, 0.822),
#  121: ('net_charge_all_around_target_ser_thr', 0.009, 0.813),
#  46: ('sasa_g', 0.009, 0.804),
#  117: ('all_sasa_side_with_whole_target', 0.009, 0.794),
#  104: ('all_sasa_asn', 0.009, 0.785),
#  96: ('all_sasa_asp', 0.009, 0.776),
#  74: ('sasa_tyr', 0.009, 0.766),
#  120: ('sasa_all_with_around_target_ser_thr', 0.009, 0.757),
#  86: ('all_sasa_n', 0.009, 0.748),
#  87: ('all_sasa_l', 0.009, 0.74),
#  56: ('sasa_f', 0.009, 0.731),
#  91: ('all_sasa_d', 0.009, 0.722),
#  140: ('exposed_charge_all_with_around_target_ser_thr', 0.009, 0.713),
#  139: ('exposed_charge_all_around_target_ser_thr', 0.009, 0.705),
#  113: ('all_sasa_back', 0.009, 0.696),
#  103: ('all_sasa_met', 0.009, 0.687),
#  112: ('sasa_back', 0.009, 0.679),
#  84: ('all_sasa_v', 0.008, 0.67),
#  47: ('sasa_v', 0.008, 0.662),
#  81: ('all_sasa_positive', 0.008, 0.654),
#  37: ('number_of_tyr', 0.008, 0.645),
#  138: ('all_atom_negative_charge_all_sidechain_with_around_target_ser_thr',
#   0.008,
#   0.637),
#  155: ('exposed_negative_charge_all_backbone_with_around_target_ser_thr',
#   0.008,
#   0.628),
#  38: ('sasa_hydrophobic', 0.008, 0.62),
#  90: ('all_sasa_b', 0.008, 0.612),
#  129: ('all_atom_positive_charge_all_backbone_around_target_ser_thr',
#   0.008,
#   0.603),
#  115: ('all_sasa_side', 0.008, 0.595),
#  142: ('exposed_charge_all_sidechain_around_target_ser_thr', 0.008, 0.587),
#  101: ('all_sasa_lys', 0.008, 0.579),
#  80: ('all_sasa_charged', 0.008, 0.57),
#  89: ('all_sasa_A', 0.008, 0.562),
#  131: ('all_atom_positive_charge_all_backbone_with_around_target_ser_thr',
#   0.008,
#   0.554),
#  141: ('exposed_charge_all_backbone_around_target_ser_thr', 0.008, 0.546),
#  85: ('all_sasa_s', 0.008, 0.538),
#  97: ('all_sasa_glu', 0.008, 0.53),
#  144: ('exposed_charge_all_sidechain_with_around_target_ser_thr',
#   0.008,
#   0.521),
#  79: ('all_sasa_aliphatic', 0.008, 0.513),
#  148: ('exposed_positive_charge_all_sidechain_around_target_ser_thr',
#   0.008,
#   0.505),
#  109: ('all_sasa_val', 0.008, 0.497),
#  98: ('all_sasa_phe', 0.008, 0.489),
#  125: ('net_charge_all_backbone_with_around_target_ser_thr', 0.008, 0.482),
#  41: ('sasa_aromatic', 0.008, 0.474),
#  95: ('all_sasa_cys', 0.008, 0.466),
#  75: ('all_sasa_hydrophobic', 0.008, 0.458),
#  149: ('exposed_positive_charge_all_backbone_with_around_target_ser_thr',
#   0.008,
#   0.45),
#  143: ('exposed_charge_all_backbone_with_around_target_ser_thr', 0.008, 0.442),
#  114: ('sasa_side', 0.008, 0.435),
#  123: ('net_charge_all_backbone_around_target_ser_thr', 0.008, 0.427),
#  119: ('sasa_all_around_target_ser_thr', 0.008, 0.42),
#  126: ('net_charge_all_sidechain_with_around_target_ser_thr', 0.008, 0.412),
#  146: ('exposed_positive_charge_all_with_around_target_ser_thr', 0.008, 0.404),
#  77: ('all_sasa_polar', 0.008, 0.397),
#  100: ('all_sasa_ile', 0.007, 0.389),
#  145: ('exposed_positive_charge_all_around_target_ser_thr', 0.007, 0.382),
#  151: ('exposed_negative_charge_all_around_target_ser_thr', 0.007, 0.374),
#  132: ('all_atom_positive_charge_all_sidechain_with_around_target_ser_thr',
#   0.007,
#   0.367),
#  111: ('all_sasa_tyr', 0.007, 0.36),
#  133: ('all_atom_negative_charge_all_around_target_ser_thr', 0.007, 0.352),
#  116: ('all_sasa_back_with_whole_target', 0.007, 0.345),
#  153: ('exposed_negative_charge_all_backbone_around_target_ser_thr',
#   0.007,
#   0.338),
#  110: ('all_sasa_trp', 0.007, 0.33),
#  150: ('exposed_positive_charge_all_sidechain_with_around_target_ser_thr',
#   0.007,
#   0.323),
#  137: ('all_atom_negative_charge_all_backbone_with_around_target_ser_thr',
#   0.007,
#   0.316),
#  71: ('sasa_thr', 0.007, 0.308),
#  45: ('sasa_negative', 0.007, 0.301),
#  92: ('all_sasa_e', 0.007, 0.294),
#  102: ('all_sasa_leu', 0.007, 0.287),
#  57: ('sasa_ala', 0.007, 0.28),
#  135: ('all_atom_negative_charge_all_backbone_around_target_ser_thr',
#   0.007,
#   0.273),
#  118: ('sasa_target_ser_thr', 0.007, 0.266),
#  152: ('exposed_negative_charge_all_with_around_target_ser_thr', 0.007, 0.26),
#  147: ('exposed_positive_charge_all_backbone_around_target_ser_thr',
#   0.007,
#   0.253),
#  130: ('all_atom_positive_charge_all_sidechain_around_target_ser_thr',
#   0.007,
#   0.246),
#  136: ('all_atom_negative_charge_all_sidechain_around_target_ser_thr',
#   0.007,
#   0.24),
#  124: ('net_charge_all_sidechain_around_target_ser_thr', 0.006, 0.233),
#  42: ('sasa_aliphatic', 0.006, 0.227),
#  127: ('all_atom_positive_charge_all_around_target_ser_thr', 0.006, 0.22),
#  128: ('all_atom_positive_charge_all_with_around_target_ser_thr',
#   0.006,
#   0.214),
#  122: ('net_charge_all_with_around_target_ser_thr', 0.006, 0.208),
#  68: ('sasa_gln', 0.006, 0.202),
#  154: ('exposed_negative_charge_all_sidechain_around_target_ser_thr',
#   0.006,
#   0.195),
#  134: ('all_atom_negative_charge_all_with_around_target_ser_thr',
#   0.006,
#   0.189),
#  48: ('sasa_s', 0.006, 0.183),
#  43: ('sasa_charged', 0.006, 0.177),
#  10: ('number_of_v', 0.006, 0.171),
#  50: ('sasa_l', 0.006, 0.165),
#  52: ('sasa_A', 0.006, 0.16),
#  49: ('sasa_n', 0.006, 0.154),
#  62: ('sasa_his', 0.005, 0.149),
#  59: ('sasa_asp', 0.005, 0.144),
#  0: ('residue_SER_THR', 0.005, 0.139),
#  64: ('sasa_lys', 0.005, 0.135),
#  14: ('number_of_p', 0.005, 0.13),
#  2: ('number_of_hydrophilic', 0.004, 0.126),
#  9: ('number_of_g', 0.004, 0.121),
#  54: ('sasa_d', 0.004, 0.117),
#  67: ('sasa_asn', 0.004, 0.113),
#  44: ('sasa_positive', 0.004, 0.109),
#  1: ('number_of_hydrophobic', 0.004, 0.105),
#  60: ('sasa_glu', 0.004, 0.101),
#  66: ('sasa_met', 0.004, 0.096),
#  53: ('sasa_b', 0.004, 0.092),
#  4: ('number_of_aromatic', 0.004, 0.088),
#  63: ('sasa_ile', 0.004, 0.085),
#  32: ('number_of_arg', 0.004, 0.081),
#  33: ('number_of_ser', 0.004, 0.077),
#  58: ('sasa_cys', 0.004, 0.074),
#  55: ('sasa_e', 0.004, 0.07),
#  11: ('number_of_s', 0.004, 0.066),
#  40: ('sasa_polar', 0.003, 0.063),
#  19: ('number_of_f', 0.003, 0.06),
#  13: ('number_of_l', 0.003, 0.057),
#  31: ('number_of_gln', 0.003, 0.054),
#  5: ('number_of_aliphatic', 0.003, 0.051)}

# %% [markdown]
# ## both dataset

# %%
data = augmented_data
x = both_x
y = both_y

model = randomforest(data, x, y)
features = FI(model)
# Out:
# the number of important features (threshold=0.95): 140 out of 171
# {4: ('Tau(i-2=>i+2)', 0.017, 0.983),
#  5: ('HSE_alpha_up', 0.013, 0.97),
#  122: ('all_sasa_ser', 0.012, 0.958),
#  6: ('HSE_alpha_down', 0.012, 0.947),
#  103: ('all_sasa_p', 0.011, 0.936),
#  121: ('all_sasa_arg', 0.011, 0.925),
#  1: ('Phi', 0.011, 0.914),
#  109: ('all_sasa_ala', 0.011, 0.903),
#  0: ('ASA', 0.01, 0.892),
#  108: ('all_sasa_f', 0.01, 0.882),
#  85: ('sasa_ser', 0.01, 0.872),
#  13: ('nS/nT', 0.01, 0.862),
#  66: ('sasa_p', 0.01, 0.852),
#  97: ('all_sasa_negative', 0.01, 0.842),
#  98: ('all_sasa_g', 0.01, 0.832),
#  123: ('all_sasa_thr', 0.01, 0.822),
#  120: ('all_sasa_gln', 0.01, 0.813),
#  3: ('Theta(i-1=>i+1)', 0.009, 0.803),
#  10: ('flexibility', 0.009, 0.794),
#  91: ('all_sasa_hydrophilic', 0.009, 0.785),
#  102: ('all_sasa_l', 0.009, 0.777),
#  114: ('all_sasa_his', 0.009, 0.768),
#  119: ('all_sasa_asn', 0.008, 0.76),
#  61: ('sasa_g', 0.008, 0.751),
#  106: ('all_sasa_d', 0.008, 0.743),
#  84: ('sasa_arg', 0.008, 0.735),
#  93: ('all_sasa_aromatic', 0.008, 0.726),
#  136: ('net_charge_all_around_target_ser_thr', 0.008, 0.718),
#  135: ('sasa_all_with_around_target_ser_thr', 0.008, 0.71),
#  54: ('sasa_hydrophilic', 0.008, 0.702),
#  7: ('P(C)', 0.008, 0.694),
#  155: ('exposed_charge_all_with_around_target_ser_thr', 0.008, 0.686),
#  104: ('all_sasa_A', 0.008, 0.678),
#  111: ('all_sasa_asp', 0.008, 0.671),
#  132: ('all_sasa_side_with_whole_target', 0.008, 0.663),
#  95: ('all_sasa_charged', 0.008, 0.655),
#  118: ('all_sasa_met', 0.008, 0.647),
#  53: ('sasa_hydrophobic', 0.008, 0.64),
#  2: ('Psi', 0.008, 0.632),
#  168: ('exposed_negative_charge_all_backbone_around_target_ser_thr',
#   0.008,
#   0.624),
#  156: ('exposed_charge_all_backbone_around_target_ser_thr', 0.008, 0.617),
#  9: ('P(E)', 0.008, 0.609),
#  52: ('number_of_tyr', 0.008, 0.602),
#  147: ('all_atom_positive_charge_all_sidechain_with_around_target_ser_thr',
#   0.007,
#   0.594),
#  101: ('all_sasa_n', 0.007, 0.587),
#  127: ('sasa_back', 0.007, 0.579),
#  126: ('all_sasa_tyr', 0.007, 0.572),
#  110: ('all_sasa_cys', 0.007, 0.565),
#  153: ('all_atom_negative_charge_all_sidechain_with_around_target_ser_thr',
#   0.007,
#   0.557),
#  112: ('all_sasa_glu', 0.007, 0.55),
#  140: ('net_charge_all_backbone_with_around_target_ser_thr', 0.007, 0.543),
#  107: ('all_sasa_e', 0.007, 0.536),
#  116: ('all_sasa_lys', 0.007, 0.529),
#  60: ('sasa_negative', 0.007, 0.522),
#  150: ('all_atom_negative_charge_all_backbone_around_target_ser_thr',
#   0.007,
#   0.515),
#  130: ('all_sasa_side', 0.007, 0.508),
#  113: ('all_sasa_phe', 0.007, 0.501),
#  146: ('all_atom_positive_charge_all_backbone_with_around_target_ser_thr',
#   0.007,
#   0.494),
#  105: ('all_sasa_b', 0.007, 0.486),
#  164: ('exposed_positive_charge_all_backbone_with_around_target_ser_thr',
#   0.007,
#   0.48),
#  89: ('sasa_tyr', 0.007, 0.473),
#  90: ('all_sasa_hydrophobic', 0.007, 0.466),
#  71: ('sasa_f', 0.007, 0.459),
#  129: ('sasa_side', 0.007, 0.452),
#  124: ('all_sasa_val', 0.007, 0.445),
#  100: ('all_sasa_s', 0.007, 0.438),
#  94: ('all_sasa_aliphatic', 0.007, 0.431),
#  161: ('exposed_positive_charge_all_with_around_target_ser_thr', 0.007, 0.424),
#  170: ('exposed_negative_charge_all_backbone_with_around_target_ser_thr',
#   0.007,
#   0.417),
#  154: ('exposed_charge_all_around_target_ser_thr', 0.007, 0.41),
#  131: ('all_sasa_back_with_whole_target', 0.007, 0.404),
#  138: ('net_charge_all_backbone_around_target_ser_thr', 0.007, 0.397),
#  125: ('all_sasa_trp', 0.007, 0.39),
#  99: ('all_sasa_v', 0.007, 0.384),
#  159: ('exposed_charge_all_sidechain_with_around_target_ser_thr',
#   0.007,
#   0.377),
#  141: ('net_charge_all_sidechain_with_around_target_ser_thr', 0.007, 0.371),
#  157: ('exposed_charge_all_sidechain_around_target_ser_thr', 0.007, 0.364),
#  148: ('all_atom_negative_charge_all_around_target_ser_thr', 0.007, 0.357),
#  86: ('sasa_thr', 0.007, 0.351),
#  96: ('all_sasa_positive', 0.007, 0.344),
#  152: ('all_atom_negative_charge_all_backbone_with_around_target_ser_thr',
#   0.006,
#   0.338),
#  56: ('sasa_aromatic', 0.006, 0.331),
#  142: ('all_atom_positive_charge_all_around_target_ser_thr', 0.006, 0.325),
#  115: ('all_sasa_ile', 0.006, 0.319),
#  163: ('exposed_positive_charge_all_sidechain_around_target_ser_thr',
#   0.006,
#   0.312),
#  62: ('sasa_v', 0.006, 0.306),
#  158: ('exposed_charge_all_backbone_with_around_target_ser_thr', 0.006, 0.299),
#  128: ('all_sasa_back', 0.006, 0.293),
#  72: ('sasa_ala', 0.006, 0.287),
#  92: ('all_sasa_polar', 0.006, 0.28),
#  144: ('all_atom_positive_charge_all_backbone_around_target_ser_thr',
#   0.006,
#   0.274),
#  134: ('sasa_all_around_target_ser_thr', 0.006, 0.268),
#  133: ('sasa_target_ser_thr', 0.006, 0.262),
#  162: ('exposed_positive_charge_all_backbone_around_target_ser_thr',
#   0.006,
#   0.255),
#  166: ('exposed_negative_charge_all_around_target_ser_thr', 0.006, 0.249),
#  165: ('exposed_positive_charge_all_sidechain_with_around_target_ser_thr',
#   0.006,
#   0.243),
#  57: ('sasa_aliphatic', 0.006, 0.237),
#  8: ('P(H)', 0.006, 0.231),
#  160: ('exposed_positive_charge_all_around_target_ser_thr', 0.006, 0.224),
#  151: ('all_atom_negative_charge_all_sidechain_around_target_ser_thr',
#   0.006,
#   0.219),
#  117: ('all_sasa_leu', 0.006, 0.213),
#  169: ('exposed_negative_charge_all_sidechain_around_target_ser_thr',
#   0.006,
#   0.207),
#  139: ('net_charge_all_sidechain_around_target_ser_thr', 0.006, 0.202),
#  143: ('all_atom_positive_charge_all_with_around_target_ser_thr',
#   0.005,
#   0.197),
#  64: ('sasa_n', 0.005, 0.191),
#  65: ('sasa_l', 0.005, 0.186),
#  145: ('all_atom_positive_charge_all_sidechain_around_target_ser_thr',
#   0.005,
#   0.181),
#  149: ('all_atom_negative_charge_all_with_around_target_ser_thr',
#   0.005,
#   0.175),
#  63: ('sasa_s', 0.005, 0.17),
#  67: ('sasa_A', 0.005, 0.165),
#  58: ('sasa_charged', 0.005, 0.16),
#  167: ('exposed_negative_charge_all_with_around_target_ser_thr', 0.005, 0.155),
#  137: ('net_charge_all_with_around_target_ser_thr', 0.005, 0.15),
#  19: ('number_of_aromatic', 0.005, 0.145),
#  83: ('sasa_gln', 0.005, 0.141),
#  25: ('number_of_v', 0.005, 0.136),
#  74: ('sasa_asp', 0.005, 0.131),
#  77: ('sasa_his', 0.004, 0.127),
#  15: ('residue_SER_THR', 0.004, 0.123),
#  82: ('sasa_asn', 0.004, 0.119),
#  17: ('number_of_hydrophilic', 0.004, 0.115),
#  69: ('sasa_d', 0.004, 0.111),
#  68: ('sasa_b', 0.004, 0.108),
#  75: ('sasa_glu', 0.004, 0.104),
#  79: ('sasa_lys', 0.004, 0.1),
#  47: ('number_of_arg', 0.004, 0.097),
#  24: ('number_of_g', 0.004, 0.093),
#  59: ('sasa_positive', 0.003, 0.09),
#  11: ('nAli', 0.003, 0.086),
#  29: ('number_of_p', 0.003, 0.083),
#  16: ('number_of_hydrophobic', 0.003, 0.08),
#  81: ('sasa_met', 0.003, 0.076),
#  48: ('number_of_ser', 0.003, 0.073),
#  73: ('sasa_cys', 0.003, 0.07),
#  26: ('number_of_s', 0.003, 0.067),
#  78: ('sasa_ile', 0.003, 0.064),
#  70: ('sasa_e', 0.003, 0.061),
#  55: ('sasa_polar', 0.003, 0.058),
#  49: ('number_of_thr', 0.003, 0.055),
#  34: ('number_of_f', 0.003, 0.053)}

# %% [markdown]
# # Result of finding important variables

# %% [markdown]
# ## original dataset

# %%
data = original_data
x = original_x
y = original_y

# ElasticNet
alpha = 0.0001
model = elasticnet(data, x, y, alpha)
EN_features = elastic_coeff(model, x)

# ANOVA
AN_features = anova(data, x, y)

# RandomForest
threshold = 0.95
model = randomforest(data, x, y)
RF_features = FI(model, threshold=threshold)
# Out:
# the number of important features: 11 out of 15
# {'nS/nT': 0.029,
#  'ASA': 0.019,
#  'nAli': 0.015,
#  'HSE_alpha_down': -0.012,
#  'nPos': 0.011,
#  'flexibility': 0.01,
#  'Proline': -0.009,
#  'Theta(i-1=>i+1)': 0.009,
#  'Tau(i-2=>i+2)': -0.006,
#  'HSE_alpha_up': 0.004,
#  'P(E)': -0.001}
# 1th iteration
# 2th iteration
# the number of important features: 10 out of 15
#
# order variables by their importance
# {0: 'ASA',
#  11: 'nAli',
#  12: 'nPos',
#  13: 'nS/nT',
#  14: 'Proline',
#  6: 'HSE_alpha_down',
#  10: 'flexibility',
#  4: 'Tau(i-2=>i+2)',
#  3: 'Theta(i-1=>i+1)',
#  5: 'HSE_alpha_up'}
# the number of important features (threshold=0.95): 11 out of 15
# {4: ('Tau(i-2=>i+2)', 0.096, 0.904),
#  0: ('ASA', 0.09, 0.814),
#  10: ('flexibility', 0.086, 0.728),
#  2: ('Psi', 0.086, 0.641),
#  1: ('Phi', 0.083, 0.559),
#  7: ('P(C)', 0.081, 0.478),
#  5: ('HSE_alpha_up', 0.079, 0.398),
#  6: ('HSE_alpha_down', 0.078, 0.32),
#  3: ('Theta(i-1=>i+1)', 0.077, 0.243),
#  8: ('P(H)', 0.077, 0.166),
#  9: ('P(E)', 0.073, 0.092)}

# %%
importance = pd.DataFrame(np.zeros((len(x), 3)), columns=['ElasticNet', 'ANOVA', 'RandomForest'], index=x)
for feature in EN_features:
    importance.loc[feature,'ElasticNet'] = 1
for feature in AN_features:
    importance.loc[feature,'ANOVA'] = 1
for feature in RF_features:
    importance.loc[feature,'RandomForest'] = 1
    
importance['Score'] = importance.sum(axis=1)
save_path = './result/important_variables_original_only_cts.csv'
if not exists(save_path):
    importance.to_csv(save_path)
importance_original = importance
importance_original
# Out:
#                  ElasticNet  ANOVA  RandomForest  Score
# ASA                     1.0    1.0           1.0    3.0
# Phi                     0.0    0.0           1.0    1.0
# Psi                     0.0    0.0           1.0    1.0
# Theta(i-1=>i+1)         1.0    1.0           1.0    3.0
# Tau(i-2=>i+2)           1.0    1.0           1.0    3.0
# HSE_alpha_up            1.0    1.0           1.0    3.0
# HSE_alpha_down          1.0    1.0           1.0    3.0
# P(C)                    0.0    0.0           1.0    1.0
# P(H)                    0.0    0.0           1.0    1.0
# P(E)                    1.0    0.0           1.0    2.0
# flexibility             1.0    1.0           1.0    3.0
# nAli                    1.0    1.0           0.0    2.0
# nPos                    1.0    1.0           0.0    2.0
# nS/nT                   1.0    1.0           0.0    2.0
# Proline                 1.0    1.0           0.0    2.0

# %% [markdown]
# ## augmented dataset

# %%
data = augmented_data
x = augmented_x
y = augmented_y

# ElasticNet
alpha = 0.0001
model = elasticnet(data, x, y, alpha)
EN_features = elastic_coeff(model, x)

# ANOVA
AN_features = anova(data, x, y)

# RandomForest
threshold = 0.95
model = randomforest(data, x, y)
RF_features = FI(model, threshold=threshold)
# Out:
# the number of important features: 38 out of 156
# {'sasa_ala': 0.047,
#  'sasa_g': 0.034,
#  'all_sasa_lys': -0.032,
#  'number_of_asn': -0.025,
#  'number_of_g': -0.023,
#  'sasa_ser': 0.022,
#  'sasa_cys': -0.021,
#  'sasa_p': 0.02,
#  'number_of_ser': 0.018,
#  'number_of_thr': -0.017,
#  'sasa_lys': -0.016,
#  'sasa_val': -0.016,
#  'number_of_leu': -0.014,
#  'sasa_negative': 0.013,
#  'net_charge_all_around_target_ser_thr': 0.012,
#  'sasa_ile': -0.011,
#  'sasa_s': -0.011,
#  'sasa_leu': -0.01,
#  'exposed_charge_all_sidechain_with_around_target_ser_thr': -0.009,
#  'all_sasa_aliphatic': -0.009,
#  'sasa_back': -0.009,
#  'number_of_lys': 0.008,
#  'exposed_charge_all_with_around_target_ser_thr': -0.008,
#  'sasa_polar': -0.008,
#  'sasa_phe': -0.008,
#  'exposed_positive_charge_all_with_around_target_ser_thr': -0.007,
#  'number_of_polar': -0.007,
#  'number_of_charged': -0.007,
#  'number_of_e': -0.007,
#  'sasa_e': -0.007,
#  'all_atom_negative_charge_all_backbone_around_target_ser_thr': 0.005,
#  'number_of_l': -0.004,
#  'sasa_f': 0.004,
#  'all_sasa_met': -0.003,
#  'sasa_met': -0.003,
#  'number_of_n': -0.002,
#  'number_of_negative': -0.002,
#  'all_sasa_glu': -0.002}
# 1th iteration
# 2th iteration
# 3th iteration
# the number of important features: 41 out of 156
#
# order variables by their importance
# {35: 'number_of_val',
#  28: 'number_of_leu',
#  17: 'number_of_d',
#  11: 'number_of_s',
#  27: 'number_of_lys',
#  22: 'number_of_asp',
#  19: 'number_of_f',
#  18: 'number_of_e',
#  12: 'number_of_n',
#  8: 'number_of_negative',
#  3: 'number_of_polar',
#  6: 'number_of_charged',
#  24: 'number_of_phe',
#  124: 'net_charge_all_sidechain_around_target_ser_thr',
#  126: 'net_charge_all_sidechain_with_around_target_ser_thr',
#  123: 'net_charge_all_backbone_around_target_ser_thr',
#  122: 'net_charge_all_with_around_target_ser_thr',
#  121: 'net_charge_all_around_target_ser_thr',
#  120: 'sasa_all_with_around_target_ser_thr',
#  127: 'all_atom_positive_charge_all_around_target_ser_thr',
#  128: 'all_atom_positive_charge_all_with_around_target_ser_thr',
#  129: 'all_atom_positive_charge_all_backbone_around_target_ser_thr',
#  125: 'net_charge_all_backbone_with_around_target_ser_thr',
#  131: 'all_atom_positive_charge_all_backbone_with_around_target_ser_thr',
#  130: 'all_atom_positive_charge_all_sidechain_around_target_ser_thr',
#  2: 'number_of_hydrophilic',
#  34: 'number_of_thr',
#  5: 'number_of_aliphatic',
#  16: 'number_of_b',
#  7: 'number_of_positive',
#  9: 'number_of_g',
#  25: 'number_of_his',
#  13: 'number_of_l',
#  0: 'residue_SER_THR',
#  21: 'number_of_cys',
#  36: 'number_of_trp',
#  14: 'number_of_p',
#  4: 'number_of_aromatic',
#  10: 'number_of_v',
#  23: 'number_of_glu',
#  15: 'number_of_A'}
# the number of important features (threshold=0.95): 129 out of 156
# {107: ('all_sasa_ser', 0.014, 0.986),
#  83: ('all_sasa_g', 0.013, 0.974),
#  88: ('all_sasa_p', 0.012, 0.961),
#  94: ('all_sasa_ala', 0.012, 0.949),
#  70: ('sasa_ser', 0.011, 0.938),
#  51: ('sasa_p', 0.011, 0.927),
#  82: ('all_sasa_negative', 0.011, 0.916),
#  108: ('all_sasa_thr', 0.011, 0.905),
#  106: ('all_sasa_arg', 0.011, 0.893),
#  78: ('all_sasa_aromatic', 0.01, 0.883),
#  93: ('all_sasa_f', 0.01, 0.873),
#  69: ('sasa_arg', 0.01, 0.863),
#  76: ('all_sasa_hydrophilic', 0.01, 0.852),
#  105: ('all_sasa_gln', 0.01, 0.842),
#  99: ('all_sasa_his', 0.01, 0.832),
#  39: ('sasa_hydrophilic', 0.01, 0.822),
#  121: ('net_charge_all_around_target_ser_thr', 0.009, 0.813),
#  46: ('sasa_g', 0.009, 0.804),
#  117: ('all_sasa_side_with_whole_target', 0.009, 0.794),
#  104: ('all_sasa_asn', 0.009, 0.785),
#  96: ('all_sasa_asp', 0.009, 0.776),
#  74: ('sasa_tyr', 0.009, 0.766),
#  120: ('sasa_all_with_around_target_ser_thr', 0.009, 0.757),
#  86: ('all_sasa_n', 0.009, 0.748),
#  87: ('all_sasa_l', 0.009, 0.74),
#  56: ('sasa_f', 0.009, 0.731),
#  91: ('all_sasa_d', 0.009, 0.722),
#  140: ('exposed_charge_all_with_around_target_ser_thr', 0.009, 0.713),
#  139: ('exposed_charge_all_around_target_ser_thr', 0.009, 0.705),
#  113: ('all_sasa_back', 0.009, 0.696),
#  103: ('all_sasa_met', 0.009, 0.687),
#  112: ('sasa_back', 0.009, 0.679),
#  84: ('all_sasa_v', 0.008, 0.67),
#  47: ('sasa_v', 0.008, 0.662),
#  81: ('all_sasa_positive', 0.008, 0.654),
#  37: ('number_of_tyr', 0.008, 0.645),
#  138: ('all_atom_negative_charge_all_sidechain_with_around_target_ser_thr',
#   0.008,
#   0.637),
#  155: ('exposed_negative_charge_all_backbone_with_around_target_ser_thr',
#   0.008,
#   0.628),
#  38: ('sasa_hydrophobic', 0.008, 0.62),
#  90: ('all_sasa_b', 0.008, 0.612),
#  129: ('all_atom_positive_charge_all_backbone_around_target_ser_thr',
#   0.008,
#   0.603),
#  115: ('all_sasa_side', 0.008, 0.595),
#  142: ('exposed_charge_all_sidechain_around_target_ser_thr', 0.008, 0.587),
#  101: ('all_sasa_lys', 0.008, 0.579),
#  80: ('all_sasa_charged', 0.008, 0.57),
#  89: ('all_sasa_A', 0.008, 0.562),
#  131: ('all_atom_positive_charge_all_backbone_with_around_target_ser_thr',
#   0.008,
#   0.554),
#  141: ('exposed_charge_all_backbone_around_target_ser_thr', 0.008, 0.546),
#  85: ('all_sasa_s', 0.008, 0.538),
#  97: ('all_sasa_glu', 0.008, 0.53),
#  144: ('exposed_charge_all_sidechain_with_around_target_ser_thr',
#   0.008,
#   0.521),
#  79: ('all_sasa_aliphatic', 0.008, 0.513),
#  148: ('exposed_positive_charge_all_sidechain_around_target_ser_thr',
#   0.008,
#   0.505),
#  109: ('all_sasa_val', 0.008, 0.497),
#  98: ('all_sasa_phe', 0.008, 0.489),
#  125: ('net_charge_all_backbone_with_around_target_ser_thr', 0.008, 0.482),
#  41: ('sasa_aromatic', 0.008, 0.474),
#  95: ('all_sasa_cys', 0.008, 0.466),
#  75: ('all_sasa_hydrophobic', 0.008, 0.458),
#  149: ('exposed_positive_charge_all_backbone_with_around_target_ser_thr',
#   0.008,
#   0.45),
#  143: ('exposed_charge_all_backbone_with_around_target_ser_thr', 0.008, 0.442),
#  114: ('sasa_side', 0.008, 0.435),
#  123: ('net_charge_all_backbone_around_target_ser_thr', 0.008, 0.427),
#  119: ('sasa_all_around_target_ser_thr', 0.008, 0.42),
#  126: ('net_charge_all_sidechain_with_around_target_ser_thr', 0.008, 0.412),
#  146: ('exposed_positive_charge_all_with_around_target_ser_thr', 0.008, 0.404),
#  77: ('all_sasa_polar', 0.008, 0.397),
#  100: ('all_sasa_ile', 0.007, 0.389),
#  145: ('exposed_positive_charge_all_around_target_ser_thr', 0.007, 0.382),
#  151: ('exposed_negative_charge_all_around_target_ser_thr', 0.007, 0.374),
#  132: ('all_atom_positive_charge_all_sidechain_with_around_target_ser_thr',
#   0.007,
#   0.367),
#  111: ('all_sasa_tyr', 0.007, 0.36),
#  133: ('all_atom_negative_charge_all_around_target_ser_thr', 0.007, 0.352),
#  116: ('all_sasa_back_with_whole_target', 0.007, 0.345),
#  153: ('exposed_negative_charge_all_backbone_around_target_ser_thr',
#   0.007,
#   0.338),
#  110: ('all_sasa_trp', 0.007, 0.33),
#  150: ('exposed_positive_charge_all_sidechain_with_around_target_ser_thr',
#   0.007,
#   0.323),
#  137: ('all_atom_negative_charge_all_backbone_with_around_target_ser_thr',
#   0.007,
#   0.316),
#  71: ('sasa_thr', 0.007, 0.308),
#  45: ('sasa_negative', 0.007, 0.301),
#  92: ('all_sasa_e', 0.007, 0.294),
#  102: ('all_sasa_leu', 0.007, 0.287),
#  57: ('sasa_ala', 0.007, 0.28),
#  135: ('all_atom_negative_charge_all_backbone_around_target_ser_thr',
#   0.007,
#   0.273),
#  118: ('sasa_target_ser_thr', 0.007, 0.266),
#  152: ('exposed_negative_charge_all_with_around_target_ser_thr', 0.007, 0.26),
#  147: ('exposed_positive_charge_all_backbone_around_target_ser_thr',
#   0.007,
#   0.253),
#  130: ('all_atom_positive_charge_all_sidechain_around_target_ser_thr',
#   0.007,
#   0.246),
#  136: ('all_atom_negative_charge_all_sidechain_around_target_ser_thr',
#   0.007,
#   0.24),
#  124: ('net_charge_all_sidechain_around_target_ser_thr', 0.006, 0.233),
#  42: ('sasa_aliphatic', 0.006, 0.227),
#  127: ('all_atom_positive_charge_all_around_target_ser_thr', 0.006, 0.22),
#  128: ('all_atom_positive_charge_all_with_around_target_ser_thr',
#   0.006,
#   0.214),
#  122: ('net_charge_all_with_around_target_ser_thr', 0.006, 0.208),
#  68: ('sasa_gln', 0.006, 0.202),
#  154: ('exposed_negative_charge_all_sidechain_around_target_ser_thr',
#   0.006,
#   0.195),
#  134: ('all_atom_negative_charge_all_with_around_target_ser_thr',
#   0.006,
#   0.189),
#  48: ('sasa_s', 0.006, 0.183),
#  43: ('sasa_charged', 0.006, 0.177),
#  10: ('number_of_v', 0.006, 0.171),
#  50: ('sasa_l', 0.006, 0.165),
#  52: ('sasa_A', 0.006, 0.16),
#  49: ('sasa_n', 0.006, 0.154),
#  62: ('sasa_his', 0.005, 0.149),
#  59: ('sasa_asp', 0.005, 0.144),
#  0: ('residue_SER_THR', 0.005, 0.139),
#  64: ('sasa_lys', 0.005, 0.135),
#  14: ('number_of_p', 0.005, 0.13),
#  2: ('number_of_hydrophilic', 0.004, 0.126),
#  9: ('number_of_g', 0.004, 0.121),
#  54: ('sasa_d', 0.004, 0.117),
#  67: ('sasa_asn', 0.004, 0.113),
#  44: ('sasa_positive', 0.004, 0.109),
#  1: ('number_of_hydrophobic', 0.004, 0.105),
#  60: ('sasa_glu', 0.004, 0.101),
#  66: ('sasa_met', 0.004, 0.096),
#  53: ('sasa_b', 0.004, 0.092),
#  4: ('number_of_aromatic', 0.004, 0.088),
#  63: ('sasa_ile', 0.004, 0.085),
#  32: ('number_of_arg', 0.004, 0.081),
#  33: ('number_of_ser', 0.004, 0.077),
#  58: ('sasa_cys', 0.004, 0.074),
#  55: ('sasa_e', 0.004, 0.07),
#  11: ('number_of_s', 0.004, 0.066),
#  40: ('sasa_polar', 0.003, 0.063),
#  19: ('number_of_f', 0.003, 0.06),
#  13: ('number_of_l', 0.003, 0.057),
#  31: ('number_of_gln', 0.003, 0.054),
#  5: ('number_of_aliphatic', 0.003, 0.051)}

# %%
importance = pd.DataFrame(np.zeros((len(x), 3)), columns=['ElasticNet', 'ANOVA', 'RandomForest'], index=x)
for feature in EN_features:
    importance.loc[feature,'ElasticNet'] = 1
for feature in AN_features:
    importance.loc[feature,'ANOVA'] = 1
for feature in RF_features:
    importance.loc[feature,'RandomForest'] = 1
    
importance['Score'] = importance.sum(axis=1)
save_path = './result/important_variables_augmented_only_cts.csv'
if not exists(save_path):
    importance.to_csv(save_path)
importance_augmented = importance
importance_augmented
# Out:
#                                                     ElasticNet  ANOVA  \
# residue_SER_THR                                            0.0    1.0
# number_of_hydrophobic                                      0.0    0.0
# number_of_hydrophilic                                      0.0    1.0
# number_of_polar                                            1.0    1.0
# number_of_aromatic                                         0.0    1.0
# ...                                                        ...    ...
# exposed_negative_charge_all_around_target_ser_thr          0.0    0.0
# exposed_negative_charge_all_with_around_target_...         0.0    0.0
# exposed_negative_charge_all_backbone_around_tar...         0.0    0.0
# exposed_negative_charge_all_sidechain_around_ta...         0.0    0.0
# exposed_negative_charge_all_backbone_with_aroun...         0.0    0.0
#
#                                                     RandomForest  Score
# residue_SER_THR                                              1.0    2.0
# number_of_hydrophobic                                        1.0    1.0
# number_of_hydrophilic                                        1.0    2.0
# number_of_polar                                              0.0    2.0
# number_of_aromatic                                           1.0    2.0
# ...                                                          ...    ...
# exposed_negative_charge_all_around_target_ser_thr            1.0    1.0
# exposed_negative_charge_all_with_around_target_...           1.0    1.0
# exposed_negative_charge_all_backbone_around_tar...           1.0    1.0
# exposed_negative_charge_all_sidechain_around_ta...           1.0    1.0
# exposed_negative_charge_all_backbone_with_aroun...           1.0    1.0
#
# [156 rows x 4 columns]

# %% [markdown]
# ## both dataset

# %%
data = augmented_data
x = both_x
y = both_y

# ElasticNet
alpha = 0.0001
model = elasticnet(data, x, y, alpha)
EN_features = elastic_coeff(model, x)

# ANOVA
AN_features = anova(data, x, y)

# RandomForest
threshold = 0.95
model = randomforest(data, x, y)
RF_features = FI(model, threshold=threshold)
# Out:
# the number of important features: 43 out of 171
# {'sasa_ala': 0.059,
#  'all_sasa_lys': -0.048,
#  'nS/nT': 0.044,
#  'HSE_alpha_down': -0.037,
#  'sasa_ser': 0.029,
#  'sasa_g': 0.026,
#  'sasa_negative': 0.022,
#  'ASA': 0.021,
#  'nAli': 0.02,
#  'number_of_asn': -0.019,
#  'number_of_thr': -0.019,
#  'sasa_val': -0.015,
#  'Theta(i-1=>i+1)': 0.014,
#  'number_of_v': 0.014,
#  'exposed_charge_all_sidechain_with_around_target_ser_thr': -0.014,
#  'net_charge_all_around_target_ser_thr': 0.013,
#  'sasa_ile': -0.013,
#  'Proline': -0.011,
#  'sasa_cys': -0.01,
#  'P(H)': 0.01,
#  'number_of_lys': 0.01,
#  'sasa_back': -0.01,
#  'Tau(i-2=>i+2)': -0.01,
#  'number_of_leu': -0.009,
#  'all_sasa_leu': -0.009,
#  'number_of_ser': 0.009,
#  'number_of_l': -0.007,
#  'all_sasa_cys': -0.007,
#  'all_sasa_phe': -0.007,
#  'P(E)': -0.007,
#  'number_of_g': -0.006,
#  'exposed_charge_all_with_around_target_ser_thr': -0.006,
#  'number_of_arg': -0.005,
#  'sasa_polar': -0.004,
#  'sasa_s': -0.004,
#  'sasa_e': -0.004,
#  'sasa_leu': -0.003,
#  'exposed_positive_charge_all_with_around_target_ser_thr': -0.003,
#  'number_of_n': -0.002,
#  'sasa_lys': -0.002,
#  'all_sasa_met': -0.002,
#  'number_of_e': -0.001,
#  'number_of_polar': -0.001}
# 1th iteration
# 2th iteration
# 3th iteration
# 4th iteration
# 5th iteration
# the number of important features: 50 out of 171
#
# order variables by their importance
# {6: 'HSE_alpha_down',
#  13: 'nS/nT',
#  11: 'nAli',
#  35: 'number_of_ala',
#  48: 'number_of_ser',
#  43: 'number_of_leu',
#  32: 'number_of_d',
#  37: 'number_of_asp',
#  34: 'number_of_f',
#  42: 'number_of_lys',
#  26: 'number_of_s',
#  46: 'number_of_gln',
#  19: 'number_of_aromatic',
#  39: 'number_of_phe',
#  21: 'number_of_charged',
#  144: 'all_atom_positive_charge_all_backbone_around_target_ser_thr',
#  143: 'all_atom_positive_charge_all_with_around_target_ser_thr',
#  135: 'sasa_all_with_around_target_ser_thr',
#  141: 'net_charge_all_sidechain_with_around_target_ser_thr',
#  136: 'net_charge_all_around_target_ser_thr',
#  137: 'net_charge_all_with_around_target_ser_thr',
#  139: 'net_charge_all_sidechain_around_target_ser_thr',
#  140: 'net_charge_all_backbone_with_around_target_ser_thr',
#  142: 'all_atom_positive_charge_all_around_target_ser_thr',
#  138: 'net_charge_all_backbone_around_target_ser_thr',
#  146: 'all_atom_positive_charge_all_backbone_with_around_target_ser_thr',
#  145: 'all_atom_positive_charge_all_sidechain_around_target_ser_thr',
#  27: 'number_of_n',
#  17: 'number_of_hydrophilic',
#  28: 'number_of_l',
#  29: 'number_of_p',
#  18: 'number_of_polar',
#  24: 'number_of_g',
#  16: 'number_of_hydrophobic',
#  33: 'number_of_e',
#  31: 'number_of_b',
#  22: 'number_of_positive',
#  49: 'number_of_thr',
#  20: 'number_of_aliphatic',
#  15: 'residue_SER_THR',
#  41: 'number_of_ile',
#  36: 'number_of_cys',
#  40: 'number_of_his',
#  30: 'number_of_A',
#  23: 'number_of_negative',
#  25: 'number_of_v',
#  47: 'number_of_arg',
#  50: 'number_of_val',
#  38: 'number_of_glu',
#  4: 'Tau(i-2=>i+2)'}
# the number of important features (threshold=0.95): 140 out of 171
# {4: ('Tau(i-2=>i+2)', 0.017, 0.983),
#  5: ('HSE_alpha_up', 0.013, 0.97),
#  122: ('all_sasa_ser', 0.012, 0.958),
#  6: ('HSE_alpha_down', 0.012, 0.947),
#  103: ('all_sasa_p', 0.011, 0.936),
#  121: ('all_sasa_arg', 0.011, 0.925),
#  1: ('Phi', 0.011, 0.914),
#  109: ('all_sasa_ala', 0.011, 0.903),
#  0: ('ASA', 0.01, 0.892),
#  108: ('all_sasa_f', 0.01, 0.882),
#  85: ('sasa_ser', 0.01, 0.872),
#  13: ('nS/nT', 0.01, 0.862),
#  66: ('sasa_p', 0.01, 0.852),
#  97: ('all_sasa_negative', 0.01, 0.842),
#  98: ('all_sasa_g', 0.01, 0.832),
#  123: ('all_sasa_thr', 0.01, 0.822),
#  120: ('all_sasa_gln', 0.01, 0.813),
#  3: ('Theta(i-1=>i+1)', 0.009, 0.803),
#  10: ('flexibility', 0.009, 0.794),
#  91: ('all_sasa_hydrophilic', 0.009, 0.785),
#  102: ('all_sasa_l', 0.009, 0.777),
#  114: ('all_sasa_his', 0.009, 0.768),
#  119: ('all_sasa_asn', 0.008, 0.76),
#  61: ('sasa_g', 0.008, 0.751),
#  106: ('all_sasa_d', 0.008, 0.743),
#  84: ('sasa_arg', 0.008, 0.735),
#  93: ('all_sasa_aromatic', 0.008, 0.726),
#  136: ('net_charge_all_around_target_ser_thr', 0.008, 0.718),
#  135: ('sasa_all_with_around_target_ser_thr', 0.008, 0.71),
#  54: ('sasa_hydrophilic', 0.008, 0.702),
#  7: ('P(C)', 0.008, 0.694),
#  155: ('exposed_charge_all_with_around_target_ser_thr', 0.008, 0.686),
#  104: ('all_sasa_A', 0.008, 0.678),
#  111: ('all_sasa_asp', 0.008, 0.671),
#  132: ('all_sasa_side_with_whole_target', 0.008, 0.663),
#  95: ('all_sasa_charged', 0.008, 0.655),
#  118: ('all_sasa_met', 0.008, 0.647),
#  53: ('sasa_hydrophobic', 0.008, 0.64),
#  2: ('Psi', 0.008, 0.632),
#  168: ('exposed_negative_charge_all_backbone_around_target_ser_thr',
#   0.008,
#   0.624),
#  156: ('exposed_charge_all_backbone_around_target_ser_thr', 0.008, 0.617),
#  9: ('P(E)', 0.008, 0.609),
#  52: ('number_of_tyr', 0.008, 0.602),
#  147: ('all_atom_positive_charge_all_sidechain_with_around_target_ser_thr',
#   0.007,
#   0.594),
#  101: ('all_sasa_n', 0.007, 0.587),
#  127: ('sasa_back', 0.007, 0.579),
#  126: ('all_sasa_tyr', 0.007, 0.572),
#  110: ('all_sasa_cys', 0.007, 0.565),
#  153: ('all_atom_negative_charge_all_sidechain_with_around_target_ser_thr',
#   0.007,
#   0.557),
#  112: ('all_sasa_glu', 0.007, 0.55),
#  140: ('net_charge_all_backbone_with_around_target_ser_thr', 0.007, 0.543),
#  107: ('all_sasa_e', 0.007, 0.536),
#  116: ('all_sasa_lys', 0.007, 0.529),
#  60: ('sasa_negative', 0.007, 0.522),
#  150: ('all_atom_negative_charge_all_backbone_around_target_ser_thr',
#   0.007,
#   0.515),
#  130: ('all_sasa_side', 0.007, 0.508),
#  113: ('all_sasa_phe', 0.007, 0.501),
#  146: ('all_atom_positive_charge_all_backbone_with_around_target_ser_thr',
#   0.007,
#   0.494),
#  105: ('all_sasa_b', 0.007, 0.486),
#  164: ('exposed_positive_charge_all_backbone_with_around_target_ser_thr',
#   0.007,
#   0.48),
#  89: ('sasa_tyr', 0.007, 0.473),
#  90: ('all_sasa_hydrophobic', 0.007, 0.466),
#  71: ('sasa_f', 0.007, 0.459),
#  129: ('sasa_side', 0.007, 0.452),
#  124: ('all_sasa_val', 0.007, 0.445),
#  100: ('all_sasa_s', 0.007, 0.438),
#  94: ('all_sasa_aliphatic', 0.007, 0.431),
#  161: ('exposed_positive_charge_all_with_around_target_ser_thr', 0.007, 0.424),
#  170: ('exposed_negative_charge_all_backbone_with_around_target_ser_thr',
#   0.007,
#   0.417),
#  154: ('exposed_charge_all_around_target_ser_thr', 0.007, 0.41),
#  131: ('all_sasa_back_with_whole_target', 0.007, 0.404),
#  138: ('net_charge_all_backbone_around_target_ser_thr', 0.007, 0.397),
#  125: ('all_sasa_trp', 0.007, 0.39),
#  99: ('all_sasa_v', 0.007, 0.384),
#  159: ('exposed_charge_all_sidechain_with_around_target_ser_thr',
#   0.007,
#   0.377),
#  141: ('net_charge_all_sidechain_with_around_target_ser_thr', 0.007, 0.371),
#  157: ('exposed_charge_all_sidechain_around_target_ser_thr', 0.007, 0.364),
#  148: ('all_atom_negative_charge_all_around_target_ser_thr', 0.007, 0.357),
#  86: ('sasa_thr', 0.007, 0.351),
#  96: ('all_sasa_positive', 0.007, 0.344),
#  152: ('all_atom_negative_charge_all_backbone_with_around_target_ser_thr',
#   0.006,
#   0.338),
#  56: ('sasa_aromatic', 0.006, 0.331),
#  142: ('all_atom_positive_charge_all_around_target_ser_thr', 0.006, 0.325),
#  115: ('all_sasa_ile', 0.006, 0.319),
#  163: ('exposed_positive_charge_all_sidechain_around_target_ser_thr',
#   0.006,
#   0.312),
#  62: ('sasa_v', 0.006, 0.306),
#  158: ('exposed_charge_all_backbone_with_around_target_ser_thr', 0.006, 0.299),
#  128: ('all_sasa_back', 0.006, 0.293),
#  72: ('sasa_ala', 0.006, 0.287),
#  92: ('all_sasa_polar', 0.006, 0.28),
#  144: ('all_atom_positive_charge_all_backbone_around_target_ser_thr',
#   0.006,
#   0.274),
#  134: ('sasa_all_around_target_ser_thr', 0.006, 0.268),
#  133: ('sasa_target_ser_thr', 0.006, 0.262),
#  162: ('exposed_positive_charge_all_backbone_around_target_ser_thr',
#   0.006,
#   0.255),
#  166: ('exposed_negative_charge_all_around_target_ser_thr', 0.006, 0.249),
#  165: ('exposed_positive_charge_all_sidechain_with_around_target_ser_thr',
#   0.006,
#   0.243),
#  57: ('sasa_aliphatic', 0.006, 0.237),
#  8: ('P(H)', 0.006, 0.231),
#  160: ('exposed_positive_charge_all_around_target_ser_thr', 0.006, 0.224),
#  151: ('all_atom_negative_charge_all_sidechain_around_target_ser_thr',
#   0.006,
#   0.219),
#  117: ('all_sasa_leu', 0.006, 0.213),
#  169: ('exposed_negative_charge_all_sidechain_around_target_ser_thr',
#   0.006,
#   0.207),
#  139: ('net_charge_all_sidechain_around_target_ser_thr', 0.006, 0.202),
#  143: ('all_atom_positive_charge_all_with_around_target_ser_thr',
#   0.005,
#   0.197),
#  64: ('sasa_n', 0.005, 0.191),
#  65: ('sasa_l', 0.005, 0.186),
#  145: ('all_atom_positive_charge_all_sidechain_around_target_ser_thr',
#   0.005,
#   0.181),
#  149: ('all_atom_negative_charge_all_with_around_target_ser_thr',
#   0.005,
#   0.175),
#  63: ('sasa_s', 0.005, 0.17),
#  67: ('sasa_A', 0.005, 0.165),
#  58: ('sasa_charged', 0.005, 0.16),
#  167: ('exposed_negative_charge_all_with_around_target_ser_thr', 0.005, 0.155),
#  137: ('net_charge_all_with_around_target_ser_thr', 0.005, 0.15),
#  19: ('number_of_aromatic', 0.005, 0.145),
#  83: ('sasa_gln', 0.005, 0.141),
#  25: ('number_of_v', 0.005, 0.136),
#  74: ('sasa_asp', 0.005, 0.131),
#  77: ('sasa_his', 0.004, 0.127),
#  15: ('residue_SER_THR', 0.004, 0.123),
#  82: ('sasa_asn', 0.004, 0.119),
#  17: ('number_of_hydrophilic', 0.004, 0.115),
#  69: ('sasa_d', 0.004, 0.111),
#  68: ('sasa_b', 0.004, 0.108),
#  75: ('sasa_glu', 0.004, 0.104),
#  79: ('sasa_lys', 0.004, 0.1),
#  47: ('number_of_arg', 0.004, 0.097),
#  24: ('number_of_g', 0.004, 0.093),
#  59: ('sasa_positive', 0.003, 0.09),
#  11: ('nAli', 0.003, 0.086),
#  29: ('number_of_p', 0.003, 0.083),
#  16: ('number_of_hydrophobic', 0.003, 0.08),
#  81: ('sasa_met', 0.003, 0.076),
#  48: ('number_of_ser', 0.003, 0.073),
#  73: ('sasa_cys', 0.003, 0.07),
#  26: ('number_of_s', 0.003, 0.067),
#  78: ('sasa_ile', 0.003, 0.064),
#  70: ('sasa_e', 0.003, 0.061),
#  55: ('sasa_polar', 0.003, 0.058),
#  49: ('number_of_thr', 0.003, 0.055),
#  34: ('number_of_f', 0.003, 0.053)}

# %%
importance = pd.DataFrame(np.zeros((len(x), 3)), columns=['ElasticNet', 'ANOVA', 'RandomForest'], index=x)
for feature in EN_features:
    importance.loc[feature,'ElasticNet'] = 1
for feature in AN_features:
    importance.loc[feature,'ANOVA'] = 1
for feature in RF_features:
    importance.loc[feature,'RandomForest'] = 1
    
importance['Score'] = importance.sum(axis=1)
save_path = './result/important_variables_both_only_cts.csv'
if not exists(save_path):
    importance.to_csv(save_path)
importance_both = importance
importance_both
# Out:
#                                                     ElasticNet  ANOVA  \
# ASA                                                        1.0    0.0
# Phi                                                        0.0    0.0
# Psi                                                        0.0    0.0
# Theta(i-1=>i+1)                                            1.0    0.0
# Tau(i-2=>i+2)                                              1.0    1.0
# ...                                                        ...    ...
# exposed_negative_charge_all_around_target_ser_thr          0.0    0.0
# exposed_negative_charge_all_with_around_target_...         0.0    0.0
# exposed_negative_charge_all_backbone_around_tar...         0.0    0.0
# exposed_negative_charge_all_sidechain_around_ta...         0.0    0.0
# exposed_negative_charge_all_backbone_with_aroun...         0.0    0.0
#
#                                                     RandomForest  Score
# ASA                                                          1.0    2.0
# Phi                                                          1.0    1.0
# Psi                                                          1.0    1.0
# Theta(i-1=>i+1)                                              1.0    2.0
# Tau(i-2=>i+2)                                                1.0    3.0
# ...                                                          ...    ...
# exposed_negative_charge_all_around_target_ser_thr            1.0    1.0
# exposed_negative_charge_all_with_around_target_...           1.0    1.0
# exposed_negative_charge_all_backbone_around_tar...           1.0    1.0
# exposed_negative_charge_all_sidechain_around_ta...           1.0    1.0
# exposed_negative_charge_all_backbone_with_aroun...           1.0    1.0
#
# [171 rows x 4 columns]
