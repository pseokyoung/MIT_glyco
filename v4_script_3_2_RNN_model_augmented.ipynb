# %% [markdown]
# ## header

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
from os.path import exists

project_path = '/content/drive/MyDrive/Gproject/MIT_glyco'
os.chdir(project_path)

os.getcwd() # current working directory
# Out:
# Mounted at /content/drive
# '/content/drive/MyDrive/Gproject/MIT_glyco'

# %%
import pandas as pd
import numpy as np

import time

version = 'v4'
update = False

# %%
load_name = "v4_augmented_dataset_all.csv"
dataset = pd.read_csv(load_name)
protein_list = list(dataset.protein.unique())
pass_list = ['A2ABU4', 'P26039', 'P70670', 'P83741', 'Q5DTJ9', 'Q66L42', 'Q6GQX2', 
             'Q6ZPS6', 'Q76LL6', 'Q80TE4', 'Q80VP0', 'Q8CDG3', 'Q8CG79', 'A2AQ25', 'P07756']

for name in pass_list:
    protein_list.remove(name)
dataset = dataset[dataset['protein'].apply(lambda x: x in protein_list)].reset_index(drop=True)

positive_sites = dataset[dataset['positivity']==1]
negative_sites = dataset[dataset['positivity']==0]

print("total number of proteins:      ", len(dataset.protein.unique()))
print("total number of samples:       ", len(dataset))
print("total number of positive sites:", len(positive_sites))
print("total number of negative sites:", len(negative_sites))
display(dataset)
# Out:
# total number of proteins:       73
# total number of samples:        43217
# total number of positive sites: 157
# total number of negative sites: 43060
#          # SEQ SS    ASA   Phi    Psi  Theta(i-1=>i+1)  Tau(i-2=>i+2)  \
# 0        1   M  C  151.0 -94.2  133.0            115.1          155.6
# 1        2   A  C   91.5 -88.5  136.1            114.5         -132.9
# 2        3   A  C   79.9 -89.2  133.8            113.6         -128.4
# 3        4   A  C   65.3 -77.9  140.0            112.8         -108.1
# 4        5   P  C   71.5 -67.7  142.6            105.7         -106.1
# ...    ...  .. ..    ...   ...    ...              ...            ...
# 43212  729   A  H   29.7 -73.2  -30.4             98.8           56.7
# 43213  730   K  H  102.8 -72.5  -24.6             97.3           56.5
# 43214  731   Q  C   91.3 -85.0   -2.2            100.0           55.6
# 43215  732   G  C   50.1  79.5    4.9            101.0          -84.7
# 43216  733   L  C   81.2 -90.2   18.6            104.9          103.8
#
#        HSE_alpha_up  HSE_alpha_down  ...  \
# 0               3.9             5.6  ...
# 1               3.7             7.4  ...
# 2               5.2            11.5  ...
# 3               7.9            13.5  ...
# 4              10.1            13.8  ...
# ...             ...             ...  ...
# 43212          15.8            16.9  ...
# 43213           9.2            17.4  ...
# 43214           9.1            16.1  ...
# 43215           4.8            17.1  ...
# 43216          11.8            11.7  ...
#
#        exposed_positive_charge_all_with_around_target_ser_thr  \
# 0                                                   1.02
# 1                                                   1.02
# 2                                                   1.53
# 3                                                   2.55
# 4                                                   2.55
# ...                                                  ...
# 43212                                               4.42
# 43213                                               3.91
# 43214                                               3.40
# 43215                                               2.89
# 43216                                               3.06
#
#        exposed_positive_charge_all_backbone_around_target_ser_thr  \
# 0                                                   0.90
# 1                                                   5.63
# 2                                                   4.59
# 3                                                   9.80
# 4                                                  14.41
# ...                                                  ...
# 43212                                               8.10
# 43213                                               6.35
# 43214                                               5.34
# 43215                                               5.26
# 43216                                               3.79
#
#        exposed_positive_charge_all_sidechain_around_target_ser_thr  \
# 0                                                   1.53
# 1                                                   1.53
# 2                                                   2.04
# 3                                                   2.55
# 4                                                   2.55
# ...                                                  ...
# 43212                                               4.93
# 43213                                               4.42
# 43214                                               3.91
# 43215                                               3.40
# 43216                                               3.40
#
#        exposed_positive_charge_all_backbone_with_around_target_ser_thr  \
# 0                                                   1.53
# 1                                                   5.90
# 2                                                   4.86
# 3                                                  10.07
# 4                                                  14.77
# ...                                                  ...
# 43212                                               8.37
# 43213                                               8.19
# 43214                                               6.78
# 43215                                               5.35
# 43216                                               4.51
#
#       exposed_positive_charge_all_sidechain_with_around_target_ser_thr  \
# 0                                                  -4.04
# 1                                                  -9.50
# 2                                                 -10.40
# 3                                                 -17.09
# 4                                                 -23.01
# ...                                                  ...
# 43212                                             -14.84
# 43213                                             -16.23
# 43214                                             -10.20
# 43215                                              -9.63
# 43216                                              -8.27
#
#       exposed_negative_charge_all_around_target_ser_thr  \
# 0                                                 -5.30
# 1                                                -10.75
# 2                                                -11.65
# 3                                                -18.34
# 4                                                -23.99
# ...                                                 ...
# 43212                                            -16.09
# 43213                                            -17.40
# 43214                                            -11.88
# 43215                                            -10.63
# 43216                                            -10.33
#
#       exposed_negative_charge_all_with_around_target_ser_thr  \
# 0                                                  -3.23
# 1                                                  -4.59
# 2                                                  -5.57
# 3                                                  -6.59
# 4                                                  -8.47
# ...                                                  ...
# 43212                                              -8.30
# 43213                                              -9.32
# 43214                                              -6.81
# 43215                                              -5.34
# 43216                                              -5.00
#
#       exposed_negative_charge_all_backbone_around_target_ser_thr  \
# 0                                                  -0.81
# 1                                                  -4.91
# 2                                                  -4.83
# 3                                                 -10.50
# 4                                                 -14.54
# ...                                                  ...
# 43212                                              -6.54
# 43213                                              -6.91
# 43214                                              -3.39
# 43215                                              -4.29
# 43216                                              -3.27
#
#       exposed_negative_charge_all_sidechain_around_target_ser_thr  \
# 0                                                  -4.04
# 1                                                  -5.57
# 2                                                  -6.55
# 3                                                  -7.57
# 4                                                  -9.27
# ...                                                  ...
# 43212                                              -9.28
# 43213                                              -9.83
# 43214                                              -7.32
# 43215                                              -6.34
# 43216                                              -6.34
#
#       exposed_negative_charge_all_backbone_with_around_target_ser_thr
# 0                                                  -1.26
# 1                                                  -5.18
# 2                                                  -5.10
# 3                                                 -10.77
# 4                                                 -14.72
# ...                                                  ...
# 43212                                              -6.81
# 43213                                              -7.57
# 43214                                              -4.56
# 43215                                              -4.29
# 43216                                              -3.99
#
# [43217 rows x 184 columns]

# %%
display(dict(zip(range(len(dataset.columns)), dataset.columns)))
# Out:
# {0: '#',
#  1: 'SEQ',
#  2: 'SS',
#  3: 'ASA',
#  4: 'Phi',
#  5: 'Psi',
#  6: 'Theta(i-1=>i+1)',
#  7: 'Tau(i-2=>i+2)',
#  8: 'HSE_alpha_up',
#  9: 'HSE_alpha_down',
#  10: 'P(C)',
#  11: 'P(H)',
#  12: 'P(E)',
#  13: 'flexibility',
#  14: 'side_-1',
#  15: 'side_1',
#  16: 'side_2',
#  17: 'side_3',
#  18: 'side_4',
#  19: 'side_5',
#  20: 'nAli',
#  21: 'nPos',
#  22: 'nS/nT',
#  23: 'Proline',
#  24: 'phi_psi',
#  25: 'positivity',
#  26: 'protein',
#  27: '#.1',
#  28: 'residue_SER_THR',
#  29: 'number_of_hydrophobic',
#  30: 'number_of_hydrophilic',
#  31: 'number_of_polar',
#  32: 'number_of_aromatic',
#  33: 'number_of_aliphatic',
#  34: 'number_of_charged',
#  35: 'number_of_positive',
#  36: 'number_of_negative',
#  37: 'number_of_g',
#  38: 'number_of_v',
#  39: 'number_of_s',
#  40: 'number_of_n',
#  41: 'number_of_l',
#  42: 'number_of_p',
#  43: 'number_of_A',
#  44: 'number_of_b',
#  45: 'number_of_d',
#  46: 'number_of_e',
#  47: 'number_of_f',
#  48: 'number_of_ala',
#  49: 'number_of_cys',
#  50: 'number_of_asp',
#  51: 'number_of_glu',
#  52: 'number_of_phe',
#  53: 'number_of_his',
#  54: 'number_of_ile',
#  55: 'number_of_lys',
#  56: 'number_of_leu',
#  57: 'number_of_met',
#  58: 'number_of_asn',
#  59: 'number_of_gln',
#  60: 'number_of_arg',
#  61: 'number_of_ser',
#  62: 'number_of_thr',
#  63: 'number_of_val',
#  64: 'number_of_trp',
#  65: 'number_of_tyr',
#  66: 'sasa_hydrophobic',
#  67: 'sasa_hydrophilic',
#  68: 'sasa_polar',
#  69: 'sasa_aromatic',
#  70: 'sasa_aliphatic',
#  71: 'sasa_charged',
#  72: 'sasa_positive',
#  73: 'sasa_negative',
#  74: 'sasa_g',
#  75: 'sasa_v',
#  76: 'sasa_s',
#  77: 'sasa_n',
#  78: 'sasa_l',
#  79: 'sasa_p',
#  80: 'sasa_A',
#  81: 'sasa_b',
#  82: 'sasa_d',
#  83: 'sasa_e',
#  84: 'sasa_f',
#  85: 'sasa_ala',
#  86: 'sasa_cys',
#  87: 'sasa_asp',
#  88: 'sasa_glu',
#  89: 'sasa_phe',
#  90: 'sasa_his',
#  91: 'sasa_ile',
#  92: 'sasa_lys',
#  93: 'sasa_leu',
#  94: 'sasa_met',
#  95: 'sasa_asn',
#  96: 'sasa_gln',
#  97: 'sasa_arg',
#  98: 'sasa_ser',
#  99: 'sasa_thr',
#  100: 'sasa_val',
#  101: 'sasa_trp',
#  102: 'sasa_tyr',
#  103: 'all_sasa_hydrophobic',
#  104: 'all_sasa_hydrophilic',
#  105: 'all_sasa_polar',
#  106: 'all_sasa_aromatic',
#  107: 'all_sasa_aliphatic',
#  108: 'all_sasa_charged',
#  109: 'all_sasa_positive',
#  110: 'all_sasa_negative',
#  111: 'all_sasa_g',
#  112: 'all_sasa_v',
#  113: 'all_sasa_s',
#  114: 'all_sasa_n',
#  115: 'all_sasa_l',
#  116: 'all_sasa_p',
#  117: 'all_sasa_A',
#  118: 'all_sasa_b',
#  119: 'all_sasa_d',
#  120: 'all_sasa_e',
#  121: 'all_sasa_f',
#  122: 'all_sasa_ala',
#  123: 'all_sasa_cys',
#  124: 'all_sasa_asp',
#  125: 'all_sasa_glu',
#  126: 'all_sasa_phe',
#  127: 'all_sasa_his',
#  128: 'all_sasa_ile',
#  129: 'all_sasa_lys',
#  130: 'all_sasa_leu',
#  131: 'all_sasa_met',
#  132: 'all_sasa_asn',
#  133: 'all_sasa_gln',
#  134: 'all_sasa_arg',
#  135: 'all_sasa_ser',
#  136: 'all_sasa_thr',
#  137: 'all_sasa_val',
#  138: 'all_sasa_trp',
#  139: 'all_sasa_tyr',
#  140: 'sasa_back',
#  141: 'all_sasa_back',
#  142: 'sasa_side',
#  143: 'all_sasa_side',
#  144: 'all_sasa_back_with_whole_target',
#  145: 'all_sasa_side_with_whole_target',
#  146: 'sasa_target_ser_thr',
#  147: 'sasa_all_around_target_ser_thr',
#  148: 'sasa_all_with_around_target_ser_thr',
#  149: 'net_charge_all_around_target_ser_thr',
#  150: 'net_charge_all_with_around_target_ser_thr',
#  151: 'net_charge_all_backbone_around_target_ser_thr',
#  152: 'net_charge_all_sidechain_around_target_ser_thr',
#  153: 'net_charge_all_backbone_with_around_target_ser_thr',
#  154: 'net_charge_all_sidechain_with_around_target_ser_thr',
#  155: 'all_atom_positive_charge_all_around_target_ser_thr',
#  156: 'all_atom_positive_charge_all_with_around_target_ser_thr',
#  157: 'all_atom_positive_charge_all_backbone_around_target_ser_thr',
#  158: 'all_atom_positive_charge_all_sidechain_around_target_ser_thr',
#  159: 'all_atom_positive_charge_all_backbone_with_around_target_ser_thr',
#  160: 'all_atom_positive_charge_all_sidechain_with_around_target_ser_thr',
#  161: 'all_atom_negative_charge_all_around_target_ser_thr',
#  162: 'all_atom_negative_charge_all_with_around_target_ser_thr',
#  163: 'all_atom_negative_charge_all_backbone_around_target_ser_thr',
#  164: 'all_atom_negative_charge_all_sidechain_around_target_ser_thr',
#  165: 'all_atom_negative_charge_all_backbone_with_around_target_ser_thr',
#  166: 'all_atom_negative_charge_all_sidechain_with_around_target_ser_thr',
#  167: 'exposed_charge_all_around_target_ser_thr',
#  168: 'exposed_charge_all_with_around_target_ser_thr',
#  169: 'exposed_charge_all_backbone_around_target_ser_thr',
#  170: 'exposed_charge_all_sidechain_around_target_ser_thr',
#  171: 'exposed_charge_all_backbone_with_around_target_ser_thr',
#  172: 'exposed_charge_all_sidechain_with_around_target_ser_thr',
#  173: 'exposed_positive_charge_all_around_target_ser_thr',
#  174: 'exposed_positive_charge_all_with_around_target_ser_thr',
#  175: 'exposed_positive_charge_all_backbone_around_target_ser_thr',
#  176: 'exposed_positive_charge_all_sidechain_around_target_ser_thr',
#  177: 'exposed_positive_charge_all_backbone_with_around_target_ser_thr',
#  178: 'exposed_positive_charge_all_sidechain_with_around_target_ser_thr',
#  179: 'exposed_negative_charge_all_around_target_ser_thr',
#  180: 'exposed_negative_charge_all_with_around_target_ser_thr',
#  181: 'exposed_negative_charge_all_backbone_around_target_ser_thr',
#  182: 'exposed_negative_charge_all_sidechain_around_target_ser_thr',
#  183: 'exposed_negative_charge_all_backbone_with_around_target_ser_thr'}

# %% [markdown]
# ## case 1: without window

# %%
x_cat = ['SEQ', 'SS']
x_cts = ['ASA', 'Phi', 'Psi', 'Theta(i-1=>i+1)', 'Tau(i-2=>i+2)', 'HSE_alpha_up', 'HSE_alpha_down', 
         'P(C)', 'P(H)', 'P(E)', 'flexibility']
x_aug = [dataset.columns[x] for x in range(len(dataset.columns)) if x >= 28]
y_label = ['positivity']

data_x = pd.get_dummies(dataset[x_cts+x_aug+x_cat], columns=x_cat)
data_y = dataset[y_label]

print(data_x.shape)
print(data_y.shape)

print("\nx columns:")
display(pd.Series(data_x.columns))
# Out:
# (43217, 190)
# (43217, 1)
#
# x columns:
# 0                  ASA
# 1                  Phi
# 2                  Psi
# 3      Theta(i-1=>i+1)
# 4        Tau(i-2=>i+2)
#             ...
# 185              SEQ_W
# 186              SEQ_Y
# 187               SS_C
# 188               SS_E
# 189               SS_H
# Length: 190, dtype: object

# %%
input_data = data_x
output_data = data_y
window_size = 10
window_len  = 2 * window_size + 1

protein_list = list(dataset.protein.unique())
rnn_input = []
rnn_output = []
for name in protein_list:
    data = dataset[dataset['protein']==name]
    low_bound = data.index[0]
    up_bound  = data.index[-1]
    ST_idx = np.where((data['SEQ']=='S')|(data['SEQ']=='T'))[0] + low_bound
    
    for idx in ST_idx:
        start_idx = idx - window_size
        end_idx   = idx + window_size + 1
        
#         print(f"{name}, {low_bound}, {up_bound}, {start_idx}, {end_idx}")
        if start_idx < low_bound:
            zeros = np.zeros((low_bound-start_idx,input_data.shape[1]))
            temp  = input_data.iloc[low_bound:end_idx].values
            temp  = np.concatenate([zeros, temp], axis=0)
            
        elif end_idx > up_bound + 1:
            zeros = np.zeros((end_idx-up_bound-1,input_data.shape[1]))
            temp  = input_data.iloc[start_idx:up_bound+1].values
            temp  = np.concatenate([temp, zeros], axis=0)
            
        else:
            temp  = input_data.iloc[start_idx:end_idx].values
            
        rnn_input.append(temp)
        rnn_output.append(output_data.iloc[idx].values)
        
rnn_input = np.array(rnn_input)
rnn_output = np.array(rnn_output)

# %%
from sklearn.model_selection import StratifiedShuffleSplit

def stratified_split(data_x, data_y, test_size=0.2, n_splits=1, random_state=1, dtype='arr'):

    split = StratifiedShuffleSplit(n_splits=n_splits, test_size=test_size, random_state=random_state)
    
    train_x, train_y, test_x, test_y  = [], [], [], []
    if dtype=='df':
        data_x = data_x.values
        data_y = data_y.values
    
    for train_index, test_index in split.split(data_x, data_y):
        train_x.append(data_x[train_index])
        train_y.append(data_y[train_index])

        test_x.append(data_x[test_index])
        test_y.append(data_y[test_index])
        
    print("train/test dataset")
    print("train:", train_x[0].shape, train_y[0].shape)
    print("test:", test_x[0].shape, test_y[0].shape)
    
    if n_splits == 1:
        return train_x[0],train_y[0], test_x[0], test_y[0]
    else:
        return train_x, train_y, test_x, test_y

# %%
### split data into train/test dataset ###
test_size = 0.2
n_splits = 10
random_state = 1

split = StratifiedShuffleSplit(n_splits=n_splits, test_size=test_size, random_state=random_state)
arr_x, arr_y = rnn_input, rnn_output # convert dataframe to nd-array 

i=1
train_idx_list, train_x_list, train_y_list, test_idx_list, test_x_list, test_y_list = [], [], [], [], [], []
for train_index, test_index in split.split(arr_x, arr_y):
    train_x = arr_x[train_index]
    train_y = arr_y[train_index]
    test_x = arr_x[test_index]
    test_y = arr_y[test_index]
    
    train_cts = train_x[:,:,:len(x_cts)]
    test_cts  = test_x[:,:,:len(x_cts)]
    
    x_min = train_cts.min(0).min(0)
    x_max = train_cts.max(0).max(0)
    
    train_x[:,:,:len(x_cts)] = (train_cts-x_min)/(x_max-x_min)
    test_x[:,:,:len(x_cts)] = (test_cts-x_min)/(x_max-x_min)
    
    print(f"{i}th iteration")
    print("train:", train_x.shape, train_y.shape, "check scale:", train_x.min(), train_x.max())
    print("test: ", test_x.shape, test_y.shape, "check scale:", test_x.min(), test_x.max())
    
    train_idx_list.append(train_index)
    train_x_list.append(train_x)
    train_y_list.append(train_y)
    
    test_idx_list.append(test_index)
    test_x_list.append(test_x)
    test_y_list.append(test_y)
    
    i += 1
# Out:
# 1th iteration
# train: (5284, 21, 190) (5284, 1) check scale: -110.97 2427.857421875
# test:  (1322, 21, 190) (1322, 1) check scale: -105.77 2372.45068359375
# 2th iteration
# train: (5284, 21, 190) (5284, 1) check scale: -110.97 2372.45068359375
# test:  (1322, 21, 190) (1322, 1) check scale: -107.22 2427.857421875
# 3th iteration
# train: (5284, 21, 190) (5284, 1) check scale: -110.97 2427.857421875
# test:  (1322, 21, 190) (1322, 1) check scale: -107.22 2372.45068359375
# 4th iteration
# train: (5284, 21, 190) (5284, 1) check scale: -110.97 2427.857421875
# test:  (1322, 21, 190) (1322, 1) check scale: -107.22 2372.45068359375
# 5th iteration
# train: (5284, 21, 190) (5284, 1) check scale: -110.97 2427.857421875
# test:  (1322, 21, 190) (1322, 1) check scale: -107.22 2297.109375
# 6th iteration
# train: (5284, 21, 190) (5284, 1) check scale: -107.22 2427.857421875
# test:  (1322, 21, 190) (1322, 1) check scale: -110.97 2297.109375
# 7th iteration
# train: (5284, 21, 190) (5284, 1) check scale: -110.97 2362.98193359375
# test:  (1322, 21, 190) (1322, 1) check scale: -102.57 2427.857421875
# 8th iteration
# train: (5284, 21, 190) (5284, 1) check scale: -110.97 2427.857421875
# test:  (1322, 21, 190) (1322, 1) check scale: -105.77 2362.98193359375
# 9th iteration
# train: (5284, 21, 190) (5284, 1) check scale: -110.97 2427.857421875
# test:  (1322, 21, 190) (1322, 1) check scale: -107.22 2372.45068359375
# 10th iteration
# train: (5284, 21, 190) (5284, 1) check scale: -107.22 2427.857421875
# test:  (1322, 21, 190) (1322, 1) check scale: -110.97 2372.45068359375

# %%
## upsampling dataset 
import random
random_state = random_state

upsample_x_list, upsample_y_list = [], []
for train_x, train_y in zip(train_x_list, train_y_list):
    index_pos = np.where(train_y == 1)[0]
    index_neg = np.where(train_y == 0)[0]

    random.seed(random_state)
    up_index = [random.choice(index_pos) for _ in range(len(index_neg))] # get samples from positive sites as much as the number of negative sites

    upsample_pos_x = train_x[up_index]
    upsample_pos_y = train_y[up_index]
    sample_neg_x = train_x[index_neg]
    sample_neg_y = train_y[index_neg]

    sample_x = np.concatenate([upsample_pos_x, sample_neg_x], axis=0)
    sample_y = np.concatenate([upsample_pos_y, sample_neg_y], axis=0)

    shuffle_index = np.arange(len(sample_x))
    np.random.seed(random_state)
    np.random.shuffle(shuffle_index)
    sample_x = sample_x[shuffle_index]
    sample_y = sample_y[shuffle_index]
    
    upsample_x_list.append(sample_x)
    upsample_y_list.append(sample_y)

print("up-sampled train dataset:", sample_x.shape, sample_y.shape)
print("test dataset:", test_x.shape, test_y.shape)
# Out:
# up-sampled train dataset: (10316, 21, 190) (10316, 1)
# test dataset: (1322, 21, 190) (1322, 1)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import *
from keras.models import Model
from keras.callbacks import ModelCheckpoint, EarlyStopping

from tensorflow.keras.optimizers import Adam

def ClassifierLSTM(
    history_size, history_dim, class_num,
    rnn_layers = 1, rnn_neurons = 100,
    dense_layers = 1, dense_neurons = 100,
    optimizer = Adam(learning_rate = 0.001, beta_1=0.9, beta_2=0.999), loss="binary_crossentropy", metrics = ['accuracy']
):
    encoder_input = Input(shape=(history_size, history_dim), name='input_encoder')
    
    # encoder module
    if rnn_layers == 1:
        encoder_output, state_h, state_c = LSTM(rnn_neurons, return_state=True, name='encoder_last')(encoder_input)
        # encoder_states = [state_h, state_c]
        
    else:
        for i in range(rnn_layers):
            #first encoder layer
            if i==0: 
                encoder_output = LSTM(rnn_neurons, return_sequences=True, name="encoder_1")(encoder_input)
            #mediate encoder layer
            elif i < rnn_layers-1: 
                encoder_output = LSTM(rnn_neurons, return_sequences=True, name=f"encoder_{i+1}")(encoder_output)
            #last encoder layer
            else: 
                encoder_output, state_h, state_c  = LSTM(rnn_neurons, return_state=True, name=f"encoder_last")(encoder_output)
                # encoder_states = [state_h, state_c]
    
    # dense module
    if dense_layers == 1:
        dense_output = Dense(dense_neurons, name='dense_1')(encoder_output)
    else:
        for i in range(dense_layers):
            #first dense layer
            
            if i==0:
                dense_output = Dense(dense_neurons, name='dense_1')(encoder_output)
            #mediate encoder layer
            else:
                dense_output = Dense(dense_neurons, name=f'dense_{i+1}')(dense_output)
    dense_output = Dense(class_num, activation='sigmoid', name=f'dense_last')(dense_output)  
    
    # model compile
    model = Model(encoder_input, dense_output)
    model.compile(loss=loss,optimizer = optimizer, metrics=metrics)
    
    return model

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from seaborn import heatmap
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def scores(y_real, y_pred, rounding=4):
    
    accuracy  = 100*np.array(accuracy_score(y_real, y_pred)).round(rounding)
    precision = 100*np.array(precision_score(y_real, y_pred, average=None)).round(rounding)[1]
    recall    = 100*np.array(recall_score(y_real, y_pred, average=None)).round(rounding)[1]
    f1        = 100*np.array(f1_score(y_real, y_pred, average=None)).round(rounding)[1]
    
    return accuracy, precision, recall, f1

# %%
## hyper-parameter optimization
model_type = 'RNN_without_window_augmented'

valid_size = test_size/(1-test_size)
patience = 30
monitor = 'val_loss'
random_state = random_state
early_stopping_cb = EarlyStopping(patience=patience, restore_best_weights=True, monitor=monitor)

parameter_config = {
    "rnn_layers" : range(1,5),
    "rnn_neurons" : [16, 32, 64, 128, 256],
    "dnn_layers" : range(1,11),
    "dnn_neurons" : [16, 32, 64, 128, 256],
}

method = "random"
counts = 30
metrics = ['time', 'rnn_layers', 'rnn_neurons', 'dnn_layers', 'dnn_neurons', 
           'loss', 'val_loss', 'test_loss', 'accuracy', 'precision', 'recall', 'f1']


train_x = upsample_x_list[0]
train_y = upsample_y_list[0]
test_x = test_x_list[0]
test_y = test_y_list[0]

hpo_result = pd.DataFrame([], columns=metrics)
for i in range(counts):
    random.seed(i+1)
    rnn_layers = random.choice(parameter_config["rnn_layers"])
    rnn_neurons = random.choice(parameter_config["rnn_neurons"])
    dnn_layers = random.choice(parameter_config["dnn_layers"])
    dnn_neurons = random.choice(parameter_config["dnn_neurons"])
    print(f"random, {i+1} of {counts}: {rnn_layers} layers, {rnn_neurons} neurons, {dnn_layers} layers, {dnn_neurons} neurons")
    
    model_name = f'{version}_{model_type}_hpo_{i+1}of{counts}'
    save_path  = f'./model/{model_name}.h5'
    score_path = f"./score/{model_name}.csv"
    
    history_size = train_x.shape[1]
    history_dim = train_x.shape[2]
    y_dim = train_y.shape[1]
    
    model = ClassifierLSTM(history_size, history_dim, y_dim,
                           rnn_layers = rnn_layers, rnn_neurons = rnn_neurons,
                           dense_layers = dnn_layers, dense_neurons = dnn_neurons) 

    if not exists(save_path) or update:
        tf.random.set_seed(i+1)
        
        time_start = time.time()
        history = model.fit(train_x, train_y, verbose=0,
                            epochs=10000, callbacks=[early_stopping_cb], validation_split= valid_size)
        time_end = time.time()
        time_elapse = round((time_end - time_start)/60, 3)
        
        model.save_weights(save_path)
        print(f"model is saved to: {save_path}")
        
        idx = np.array(history.history[monitor]).argmin()
        val_loss = history.history['val_loss'][idx]
        loss = history.history['loss'][idx]
        test_loss = model.evaluate(test_x, test_y, verbose=0)[0]
        prediction = model.predict(test_x, verbose=0)
        prediction = prediction.round(0).astype(int)
        y_real = test_y
        y_pred = prediction
        accuracy, precision, recall, f1 = scores(y_real, y_pred)
        scores_df = pd.DataFrame([[time_elapse, rnn_layers, rnn_neurons, dnn_layers, dnn_neurons, 
                                   loss, val_loss, test_loss, accuracy, precision, recall, f1]], 
                                  columns=metrics)

        scores_df.to_csv(score_path)
        print(f"history is saved to: {score_path}")

    else:
        scores_df = pd.read_csv(score_path, index_col=0, header=0)
        print(f"history is loaded from: {score_path}")
        
    hpo_result = pd.concat([hpo_result, scores_df], axis=0)

hpo_result = hpo_result.reset_index(drop=True)
# Out:
# random, 1 of 30: 2 layers, 256 neurons, 2 layers, 64 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_1of30.h5
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_1of30.csv
# random, 2 of 30: 1 layers, 16 neurons, 2 layers, 64 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_2of30.h5
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_2of30.csv
# random, 3 of 30: 2 layers, 256 neurons, 9 layers, 32 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_3of30.h5
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_3of30.csv
# random, 4 of 30: 2 layers, 64 neurons, 2 layers, 128 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_4of30.h5
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_4of30.csv
# random, 5 of 30: 3 layers, 64 neurons, 9 layers, 16 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_5of30.h5
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_5of30.csv
# random, 6 of 30: 1 layers, 128 neurons, 5 layers, 16 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_6of30.h5
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_6of30.csv
# random, 7 of 30: 3 layers, 32 neurons, 7 layers, 16 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_7of30.h5
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_7of30.csv
# random, 8 of 30: 2 layers, 64 neurons, 7 layers, 32 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_8of30.h5
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_8of30.csv
# random, 9 of 30: 4 layers, 256 neurons, 6 layers, 64 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_9of30.h5
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_9of30.csv
# random, 10 of 30: 1 layers, 128 neurons, 8 layers, 256 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_10of30.h5
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_10of30.csv
# random, 11 of 30: 4 layers, 256 neurons, 8 layers, 128 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_11of30.h5
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_11of30.csv
# random, 12 of 30: 4 layers, 64 neurons, 9 layers, 64 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_12of30.h5
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_12of30.csv
# random, 13 of 30: 3 layers, 64 neurons, 3 layers, 32 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_13of30.h5
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_13of30.csv
# random, 14 of 30: 1 layers, 256 neurons, 9 layers, 32 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_14of30.h5
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_14of30.csv
# random, 15 of 30: 2 layers, 16 neurons, 9 layers, 16 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_15of30.h5
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_15of30.csv
# random, 16 of 30: 3 layers, 128 neurons, 8 layers, 64 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_16of30.h5
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_16of30.csv
# random, 17 of 30: 4 layers, 64 neurons, 6 layers, 64 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_17of30.h5
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_17of30.csv
# random, 18 of 30: 2 layers, 16 neurons, 8 layers, 64 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_18of30.h5
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_18of30.csv
# random, 19 of 30: 1 layers, 256 neurons, 2 layers, 256 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_19of30.h5
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_19of30.csv
# random, 20 of 30: 2 layers, 64 neurons, 2 layers, 64 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_20of30.h5
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_20of30.csv
# random, 21 of 30: 2 layers, 128 neurons, 7 layers, 64 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_21of30.h5
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_21of30.csv
# random, 22 of 30: 2 layers, 32 neurons, 1 layers, 256 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_22of30.h5
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_22of30.csv
# random, 23 of 30: 3 layers, 16 neurons, 1 layers, 256 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_23of30.h5
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_23of30.csv
# random, 24 of 30: 4 layers, 256 neurons, 3 layers, 32 neurons
# model is saved to: ./model/v4_RNN_without_window_augmented_hpo_24of30.h5
# history is saved to: ./score/v4_RNN_without_window_augmented_hpo_24of30.csv
# random, 25 of 30: 4 layers, 16 neurons, 4 layers, 64 neurons

# %%
# show the HPO result
target_metric = 'f1'
best_idx = hpo_result[target_metric].argmax()
best_parameters = hpo_result.iloc[best_idx]
print(f'best hyperparamerter: index {best_idx}')
display(best_parameters)

display(hpo_result.describe())

# %%
# bulid model
rnn_layers = best_parameters['rnn_layers']
rnn_neurons = best_parameters['rnn_neurons']
dnn_layers = best_parameters['dnn_layers']
dnn_neurons = best_parameters['dnn_neurons']

i=1
for train_x, train_y in zip(upsample_x_list, upsample_y_list):
    print(f"{i}th iteration")
    model_name = f'{version}_{model_type}_{rnn_layers}_{rnn_neurons}_{dnn_layers}_{dnn_neurons}_cv_{i}of{n_splits}'
    save_path  = f'./model/{model_name}.h5'
    
    if not exists(save_path) or update:
        history_size = train_x.shape[1]
        history_dim = train_x.shape[2]
        y_dim = train_y.shape[1]
        model = ClassifierLSTM(history_size, history_dim, y_dim,
                               rnn_layers = rnn_layers, rnn_neurons = rnn_neurons,
                               dense_layers = dnn_layers, dense_neurons = dnn_neurons) 

        if not exists(save_path) or update:
            tf.random.set_seed(random_state)
            history = model.fit(train_x, train_y, verbose=0,
                                epochs=10000, callbacks=[early_stopping_cb], validation_split= valid_size)
            model.save_weights(save_path)
            print(f"model is saved to: {save_path}")
    else:
        print(f"model already exists at: {save_path}")
    i += 1
display(model.summary())

# %%
# evaluate the trained model
i=1
accuracy_list, precision_list, recall_list, f1_list = [], [], [], []
for test_x, test_y in zip(test_x_list, test_y_list):
    model_name = f'{version}_{model_type}_{rnn_layers}_{rnn_neurons}_{dnn_layers}_{dnn_neurons}_cv_{i}of{n_splits}'
    save_path  = f'./model/{model_name}.h5'
    
    model = ClassifierLSTM(history_size, history_dim, y_dim,
                               rnn_layers = rnn_layers, rnn_neurons = rnn_neurons,
                               dense_layers = dnn_layers, dense_neurons = dnn_neurons) 
    model.load_weights(save_path)
    
    prediction = model.predict(test_x, verbose=0)
    prediction = prediction.round(0).astype(int)

    y_real = test_y
    y_pred = prediction
    
    accuracy  = 100*np.array(accuracy_score(y_real, y_pred)).round(4)
    precision = 100*np.array(precision_score(y_real, y_pred, average=None)).round(4)[1]
    recall    = 100*np.array(recall_score(y_real, y_pred, average=None)).round(4)[1]
    f1        = 100*np.array(f1_score(y_real, y_pred, average=None)).round(4)[1]
    
    accuracy_list.append(accuracy)
    precision_list.append(precision)
    recall_list.append(recall)
    f1_list.append(f1)
    
accuracies = np.array(accuracy_list)
precisions = np.array(precision_list)
recalls = np.array(recall_list)
f1s = np.array(f1_list)

results = pd.DataFrame(np.array([accuracies, precisions, recalls, f1s]).T, columns=['accuracy', 'precision', 'recall', 'f1-score'])
results.describe()

# %% [markdown]
# ## case 1: with window

# %%
x_cat = ['SEQ', 'nS/nT', 'nAli', 'nPos', 'phi_psi', 'SS', 
         'side_-1', 'side_1', 'side_2', 'side_3','side_4', 'side_5']
x_cts = ['Proline', 'flexibility']
x_aug = [dataset.columns[x] for x in range(len(dataset.columns)) if x >= 28]
y_label = ['positivity']

data_x = pd.get_dummies(dataset[x_cts+x_aug+x_cat], columns=x_cat)
data_y = dataset[y_label]

print(data_x.shape)
print(data_y.shape)

print("\nx columns:")
display(pd.Series(data_x.columns))

# %%
input_data = data_x
output_data = data_y

protein_list = list(dataset.protein.unique())
rnn_input = []
rnn_output = []
for name in protein_list:
    data = dataset[dataset['protein']==name]
    low_bound = data.index[0]
    up_bound  = data.index[-1]
    ST_idx = np.where((data['SEQ']=='S')|(data['SEQ']=='T'))[0] + low_bound
    
    for idx in ST_idx:
        start_idx = idx - window_size
        end_idx   = idx + window_size + 1
        
#         print(f"{name}, {low_bound}, {up_bound}, {start_idx}, {end_idx}")
        if start_idx < low_bound:
            zeros = np.zeros((low_bound-start_idx,input_data.shape[1]))
            temp  = input_data.iloc[low_bound:end_idx].values
            temp  = np.concatenate([zeros, temp], axis=0)
            
        elif end_idx > up_bound + 1:
            zeros = np.zeros((end_idx-up_bound-1,input_data.shape[1]))
            temp  = input_data.iloc[start_idx:up_bound+1].values
            temp  = np.concatenate([temp, zeros], axis=0)
            
        else:
            temp  = input_data.iloc[start_idx:end_idx].values
            
        rnn_input.append(temp)
        rnn_output.append(output_data.iloc[idx].values)
        
rnn_input = np.array(rnn_input)
rnn_output = np.array(rnn_output)

# %%
### split data into train/test dataset ###
split = StratifiedShuffleSplit(n_splits=n_splits, test_size=test_size, random_state=random_state)
arr_x, arr_y = rnn_input, rnn_output # convert dataframe to nd-array 

i=1
train_idx_list, train_x_list, train_y_list, test_idx_list, test_x_list, test_y_list = [], [], [], [], [], []
for train_index, test_index in split.split(arr_x, arr_y):
    train_x = arr_x[train_index]
    train_y = arr_y[train_index]
    test_x = arr_x[test_index]
    test_y = arr_y[test_index]
    
    train_cts = train_x[:,:,:len(x_cts)]
    test_cts  = test_x[:,:,:len(x_cts)]
    
    x_min = train_cts.min(0).min(0)
    x_max = train_cts.max(0).max(0)
    
    train_x[:,:,:len(x_cts)] = (train_cts-x_min)/(x_max-x_min)
    test_x[:,:,:len(x_cts)] = (test_cts-x_min)/(x_max-x_min)
    
    print(f"{i}th iteration")
    print("train:", train_x.shape, train_y.shape, "check scale:", train_x.min(), train_x.max())
    print("test: ", test_x.shape, test_y.shape, "check scale:", test_x.min(), test_x.max())
    
    train_idx_list.append(train_index)
    train_x_list.append(train_x)
    train_y_list.append(train_y)
    
    test_idx_list.append(test_index)
    test_x_list.append(test_x)
    test_y_list.append(test_y)
    
    i += 1

# %%
## upsampling dataset 
random_state = random_state

upsample_x_list, upsample_y_list = [], []
for train_x, train_y in zip(train_x_list, train_y_list):
    index_pos = np.where(train_y == 1)[0]
    index_neg = np.where(train_y == 0)[0]

    random.seed(random_state)
    up_index = [random.choice(index_pos) for _ in range(len(index_neg))] # get samples from positive sites as much as the number of negative sites

    upsample_pos_x = train_x[up_index]
    upsample_pos_y = train_y[up_index]
    sample_neg_x = train_x[index_neg]
    sample_neg_y = train_y[index_neg]

    sample_x = np.concatenate([upsample_pos_x, sample_neg_x], axis=0)
    sample_y = np.concatenate([upsample_pos_y, sample_neg_y], axis=0)

    shuffle_index = np.arange(len(sample_x))
    np.random.seed(random_state)
    np.random.shuffle(shuffle_index)
    sample_x = sample_x[shuffle_index]
    sample_y = sample_y[shuffle_index]
    
    upsample_x_list.append(sample_x)
    upsample_y_list.append(sample_y)

print("up-sampled train dataset:", sample_x.shape, sample_y.shape)
print("test dataset:", test_x.shape, test_y.shape)

# %%
## hyper-parameter optimization
model_type = 'RNN_without_window_augmented'

train_x = upsample_x_list[0]
train_y = upsample_y_list[0]
test_x = test_x_list[0]
test_y = test_y_list[0]

hpo_result = pd.DataFrame([], columns=metrics)
for i in range(counts):
    random.seed(i+1)
    rnn_layers = random.choice(parameter_config["rnn_layers"])
    rnn_neurons = random.choice(parameter_config["rnn_neurons"])
    dnn_layers = random.choice(parameter_config["dnn_layers"])
    dnn_neurons = random.choice(parameter_config["dnn_neurons"])
    print(f"random, {i+1} of {counts}: {rnn_layers} layers, {rnn_neurons} neurons, {dnn_layers} layers, {dnn_neurons} neurons")
    
    model_name = f'{version}_{model_type}_hpo_{i+1}of{counts}'
    save_path  = f'./model/{model_name}.h5'
    score_path = f"./score/{model_name}.csv"
    
    history_size = train_x.shape[1]
    history_dim = train_x.shape[2]
    y_dim = train_y.shape[1]
    
    model = ClassifierLSTM(history_size, history_dim, y_dim,
                           rnn_layers = rnn_layers, rnn_neurons = rnn_neurons,
                           dense_layers = dnn_layers, dense_neurons = dnn_neurons) 

    if not exists(save_path) or update:
        tf.random.set_seed(i+1)
        
        time_start = time.time()
        history = model.fit(train_x, train_y, verbose=0,
                            epochs=10000, callbacks=[early_stopping_cb], validation_split= valid_size)
        time_end = time.time()
        time_elapse = round((time_end - time_start)/60, 3)
        
        model.save_weights(save_path)
        print(f"model is saved to: {save_path}")
        
        idx = np.array(history.history[monitor]).argmin()
        val_loss = history.history['val_loss'][idx]
        loss = history.history['loss'][idx]
        test_loss = model.evaluate(test_x, test_y, verbose=0)[0]
        prediction = model.predict(test_x, verbose=0)
        prediction = prediction.round(0).astype(int)
        y_real = test_y
        y_pred = prediction
        accuracy, precision, recall, f1 = scores(y_real, y_pred)
        scores_df = pd.DataFrame([[time_elapse, rnn_layers, rnn_neurons, dnn_layers, dnn_neurons, 
                                   loss, val_loss, test_loss, accuracy, precision, recall, f1]], 
                                  columns=metrics)

        scores_df.to_csv(score_path)
        print(f"history is saved to: {score_path}")

    else:
        scores_df = pd.read_csv(score_path, index_col=0, header=0)
        print(f"history is loaded from: {score_path}")
        
    hpo_result = pd.concat([hpo_result, scores_df], axis=0)

hpo_result = hpo_result.reset_index(drop=True)

# %%
# show the HPO result
target_metric = 'f1'
best_idx = hpo_result[target_metric].argmax()
best_parameters = hpo_result.iloc[best_idx]
print(f'best hyperparamerter: index {best_idx}')
display(best_parameters)

display(hpo_result.describe())

# %%
# bulid model
rnn_layers = best_parameters['rnn_layers']
rnn_neurons = best_parameters['rnn_neurons']
dnn_layers = best_parameters['dnn_layers']
dnn_neurons = best_parameters['dnn_neurons']

i=1
for train_x, train_y in zip(upsample_x_list, upsample_y_list):
    print(f"{i}th iteration")
    model_name = f'{version}_{model_type}_{rnn_layers}_{rnn_neurons}_{dnn_layers}_{dnn_neurons}_cv_{i}of{n_splits}'
    save_path  = f'./model/{model_name}.h5'
    
    if not exists(save_path) or update:
        history_size = train_x.shape[1]
        history_dim = train_x.shape[2]
        y_dim = train_y.shape[1]
        model = ClassifierLSTM(history_size, history_dim, y_dim,
                               rnn_layers = rnn_layers, rnn_neurons = rnn_neurons,
                               dense_layers = dnn_layers, dense_neurons = dnn_neurons) 

        if not exists(save_path) or update:
            tf.random.set_seed(random_state)
            history = model.fit(train_x, train_y, verbose=0,
                                epochs=10000, callbacks=[early_stopping_cb], validation_split= valid_size)
            model.save_weights(save_path)
            print(f"model is saved to: {save_path}")
    else:
        print(f"model already exists at: {save_path}")
    i += 1
display(model.summary())

# %%
# evaluate the trained model
i=1
accuracy_list, precision_list, recall_list, f1_list = [], [], [], []
for test_x, test_y in zip(test_x_list, test_y_list):
    model_name = f'{version}_{model_type}_{rnn_layers}_{rnn_neurons}_{dnn_layers}_{dnn_neurons}_cv_{i}of{n_splits}'
    save_path  = f'./model/{model_name}.h5'
    
    model = ClassifierLSTM(history_size, history_dim, y_dim,
                               rnn_layers = rnn_layers, rnn_neurons = rnn_neurons,
                               dense_layers = dnn_layers, dense_neurons = dnn_neurons) 
    model.load_weights(save_path)
    
    prediction = model.predict(test_x, verbose=0)
    prediction = prediction.round(0).astype(int)

    y_real = test_y
    y_pred = prediction
    
    accuracy  = 100*np.array(accuracy_score(y_real, y_pred)).round(4)
    precision = 100*np.array(precision_score(y_real, y_pred, average=None)).round(4)[1]
    recall    = 100*np.array(recall_score(y_real, y_pred, average=None)).round(4)[1]
    f1        = 100*np.array(f1_score(y_real, y_pred, average=None)).round(4)[1]
    
    accuracy_list.append(accuracy)
    precision_list.append(precision)
    recall_list.append(recall)
    f1_list.append(f1)
    
accuracies = np.array(accuracy_list)
precisions = np.array(precision_list)
recalls = np.array(recall_list)
f1s = np.array(f1_list)

results = pd.DataFrame(np.array([accuracies, precisions, recalls, f1s]).T, columns=['accuracy', 'precision', 'recall', 'f1-score'])
results.describe()
