# %% [markdown]
# # Header

# %%
import numpy as np
import pandas as pd
import scipy as sp
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from os.path import exists
from src.Data import *
from src.Preprocessing import *
variables = xy_variables()

# %% [markdown]
# ## original dataset

# %%
load_path = f"./data/data_for_ml.csv"
original_data = pd.read_csv(load_path)
original_data = original_data[(original_data['SEQ']=='S') | (original_data['SEQ']=='T')]

x_cts   = variables.x_cts_window
x_cat   = variables.x_cat_window
y_label = variables.y_label

data_x, data_y = df_to_dummy(original_data, x_cts, x_cat, y_label)
original_data = pd.concat([data_x, data_y], axis=1)
original_features = dict(
    zip(range(0, len(original_data.columns)), original_data.columns)
)

display(original_features)
# Out:
# dummy x shape: (41264, 87)
# dummy y shape: (41264, 1)
# {0: 'Proline',
#  1: 'flexibility',
#  2: 'SEQ_S',
#  3: 'SEQ_T',
#  4: 'nS/nT_1',
#  5: 'nS/nT_2',
#  6: 'nS/nT_3',
#  7: 'nS/nT_4',
#  8: 'nS/nT_5',
#  9: 'nS/nT_6',
#  10: 'nS/nT_7',
#  11: 'nS/nT_8',
#  12: 'nS/nT_9',
#  13: 'nS/nT_10',
#  14: 'nS/nT_11',
#  15: 'nS/nT_12',
#  16: 'nS/nT_13',
#  17: 'nS/nT_14',
#  18: 'nS/nT_15',
#  19: 'nS/nT_16',
#  20: 'nS/nT_17',
#  21: 'nS/nT_18',
#  22: 'nS/nT_19',
#  23: 'nS/nT_20',
#  24: 'nS/nT_21',
#  25: 'nAli_0',
#  26: 'nAli_1',
#  27: 'nAli_2',
#  28: 'nAli_3',
#  29: 'nPos_0',
#  30: 'nPos_1',
#  31: 'nPos_2',
#  32: 'nPos_3',
#  33: 'phi_psi_alpha',
#  34: 'phi_psi_beta',
#  35: 'phi_psi_other',
#  36: 'SS_C',
#  37: 'SS_E',
#  38: 'SS_H',
#  39: 'side_-1_None',
#  40: 'side_-1_cycle',
#  41: 'side_-1_gly',
#  42: 'side_-1_long',
#  43: 'side_-1_normal',
#  44: 'side_-1_pro',
#  45: 'side_-1_small',
#  46: 'side_-1_very_small',
#  47: 'side_1_None',
#  48: 'side_1_cycle',
#  49: 'side_1_gly',
#  50: 'side_1_long',
#  51: 'side_1_normal',
#  52: 'side_1_pro',
#  53: 'side_1_small',
#  54: 'side_1_very_small',
#  55: 'side_2_None',
#  56: 'side_2_cycle',
#  57: 'side_2_gly',
#  58: 'side_2_long',
#  59: 'side_2_normal',
#  60: 'side_2_pro',
#  61: 'side_2_small',
#  62: 'side_2_very_small',
#  63: 'side_3_None',
#  64: 'side_3_cycle',
#  65: 'side_3_gly',
#  66: 'side_3_long',
#  67: 'side_3_normal',
#  68: 'side_3_pro',
#  69: 'side_3_small',
#  70: 'side_3_very_small',
#  71: 'side_4_None',
#  72: 'side_4_cycle',
#  73: 'side_4_gly',
#  74: 'side_4_long',
#  75: 'side_4_normal',
#  76: 'side_4_pro',
#  77: 'side_4_small',
#  78: 'side_4_very_small',
#  79: 'side_5_None',
#  80: 'side_5_cycle',
#  81: 'side_5_gly',
#  82: 'side_5_long',
#  83: 'side_5_normal',
#  84: 'side_5_pro',
#  85: 'side_5_small',
#  86: 'side_5_very_small',
#  87: 'positivity'}

# %%
original_x = list(original_data.columns[:-1])
original_y = original_data.columns[-1]

# %% [markdown]
# ## augmented dataset

# %%
load_name = "./data/data_for_ml.csv"
protein_list = list(pd.read_csv(load_name).protein.unique())
protein_augmented = [name for name in protein_list if exists(f'./data/data_for_ml(augmented)/{name}.csv')]

augmented_data = []
for name in protein_augmented:
    load_path = f'./data/data_for_ml(augmented)/{name}.csv'
    augmented_data.append(pd.read_csv(load_path))
augmented_data = pd.concat(augmented_data, axis=0).reset_index(drop=True)
augmented_data = augmented_data[(augmented_data['SEQ']=='S') | (augmented_data['SEQ']=='T')].reset_index(drop=True)

x_charge = pd.read_csv('./data/from_Krishna/features-all-names.csv').name.to_list()[1:-1]
x_cts   = variables.x_cts_window + x_charge
x_cat   = variables.x_cat_window
y_label = variables.y_label

data_x, data_y = df_to_dummy(augmented_data, x_cts, x_cat, y_label)
augmented_data = pd.concat([data_x, data_y], axis=1)

augmented_features = dict(
    zip(range(0, len(augmented_data.columns)), augmented_data.columns)
)
display(augmented_features)
# Out:
# dummy x shape: (8910, 236)
# dummy y shape: (8910, 1)
# {0: 'Proline',
#  1: 'flexibility',
#  2: 'residue_SER_THR',
#  3: 'number_of_hydrophobic',
#  4: 'number_of_hydrophilic',
#  5: 'number_of_polar',
#  6: 'number_of_aromatic',
#  7: 'number_of_aliphatic',
#  8: 'number_of_charged',
#  9: 'number_of_positive',
#  10: 'number_of_negative',
#  11: 'number_of_g',
#  12: 'number_of_v',
#  13: 'number_of_s',
#  14: 'number_of_n',
#  15: 'number_of_l',
#  16: 'number_of_p',
#  17: 'number_of_A',
#  18: 'number_of_b',
#  19: 'number_of_d',
#  20: 'number_of_e',
#  21: 'number_of_f',
#  22: 'number_of_ala',
#  23: 'number_of_cys',
#  24: 'number_of_asp',
#  25: 'number_of_glu',
#  26: 'number_of_phe',
#  27: 'number_of_his',
#  28: 'number_of_ile',
#  29: 'number_of_lys',
#  30: 'number_of_leu',
#  31: 'number_of_met',
#  32: 'number_of_asn',
#  33: 'number_of_gln',
#  34: 'number_of_arg',
#  35: 'number_of_ser',
#  36: 'number_of_thr',
#  37: 'number_of_val',
#  38: 'number_of_trp',
#  39: 'number_of_tyr',
#  40: 'sasa_hydrophobic',
#  41: 'sasa_hydrophilic',
#  42: 'sasa_polar',
#  43: 'sasa_aromatic',
#  44: 'sasa_aliphatic',
#  45: 'sasa_charged',
#  46: 'sasa_positive',
#  47: 'sasa_negative',
#  48: 'sasa_g',
#  49: 'sasa_v',
#  50: 'sasa_s',
#  51: 'sasa_n',
#  52: 'sasa_l',
#  53: 'sasa_p',
#  54: 'sasa_A',
#  55: 'sasa_b',
#  56: 'sasa_d',
#  57: 'sasa_e',
#  58: 'sasa_f',
#  59: 'sasa_ala',
#  60: 'sasa_cys',
#  61: 'sasa_asp',
#  62: 'sasa_glu',
#  63: 'sasa_phe',
#  64: 'sasa_his',
#  65: 'sasa_ile',
#  66: 'sasa_lys',
#  67: 'sasa_leu',
#  68: 'sasa_met',
#  69: 'sasa_asn',
#  70: 'sasa_gln',
#  71: 'sasa_arg',
#  72: 'sasa_ser',
#  73: 'sasa_thr',
#  74: 'sasa_val',
#  75: 'sasa_trp',
#  76: 'sasa_tyr',
#  77: 'all_sasa_hydrophobic',
#  78: 'all_sasa_hydrophilic',
#  79: 'all_sasa_polar',
#  80: 'all_sasa_aromatic',
#  81: 'all_sasa_aliphatic',
#  82: 'all_sasa_charged',
#  83: 'all_sasa_positive',
#  84: 'all_sasa_negative',
#  85: 'all_sasa_g',
#  86: 'all_sasa_v',
#  87: 'all_sasa_s',
#  88: 'all_sasa_n',
#  89: 'all_sasa_l',
#  90: 'all_sasa_p',
#  91: 'all_sasa_A',
#  92: 'all_sasa_b',
#  93: 'all_sasa_d',
#  94: 'all_sasa_e',
#  95: 'all_sasa_f',
#  96: 'all_sasa_ala',
#  97: 'all_sasa_cys',
#  98: 'all_sasa_asp',
#  99: 'all_sasa_glu',
#  100: 'all_sasa_phe',
#  101: 'all_sasa_his',
#  102: 'all_sasa_ile',
#  103: 'all_sasa_lys',
#  104: 'all_sasa_leu',
#  105: 'all_sasa_met',
#  106: 'all_sasa_asn',
#  107: 'all_sasa_gln',
#  108: 'all_sasa_arg',
#  109: 'all_sasa_ser',
#  110: 'all_sasa_thr',
#  111: 'all_sasa_val',
#  112: 'all_sasa_trp',
#  113: 'all_sasa_tyr',
#  114: 'sasa_back',
#  115: 'all_sasa_back',
#  116: 'sasa_side',
#  117: 'all_sasa_side',
#  118: 'all_sasa_back_with_whole_target',
#  119: 'all_sasa_side_with_whole_target',
#  120: 'sasa_target_ser_thr',
#  121: 'sasa_all_around_target_ser_thr',
#  122: 'sasa_all_with_around_target_ser_thr',
#  123: 'net_charge_all_around_target_ser_thr',
#  124: 'net_charge_all_with_around_target_ser_thr',
#  125: 'net_charge_all_backbone_around_target_ser_thr',
#  126: 'net_charge_all_sidechain_around_target_ser_thr',
#  127: 'net_charge_all_backbone_with_around_target_ser_thr',
#  128: 'net_charge_all_sidechain_with_around_target_ser_thr',
#  129: 'all_atom_positive_charge_all_around_target_ser_thr',
#  130: 'all_atom_positive_charge_all_with_around_target_ser_thr',
#  131: 'all_atom_positive_charge_all_backbone_around_target_ser_thr',
#  132: 'all_atom_positive_charge_all_sidechain_around_target_ser_thr',
#  133: 'all_atom_positive_charge_all_backbone_with_around_target_ser_thr',
#  134: 'all_atom_positive_charge_all_sidechain_with_around_target_ser_thr',
#  135: 'all_atom_negative_charge_all_around_target_ser_thr',
#  136: 'all_atom_negative_charge_all_with_around_target_ser_thr',
#  137: 'all_atom_negative_charge_all_backbone_around_target_ser_thr',
#  138: 'all_atom_negative_charge_all_sidechain_around_target_ser_thr',
#  139: 'all_atom_negative_charge_all_backbone_with_around_target_ser_thr',
#  140: 'all_atom_negative_charge_all_sidechain_with_around_target_ser_thr',
#  141: 'exposed_charge_all_around_target_ser_thr',
#  142: 'exposed_charge_all_with_around_target_ser_thr',
#  143: 'exposed_charge_all_backbone_around_target_ser_thr',
#  144: 'exposed_charge_all_sidechain_around_target_ser_thr',
#  145: 'exposed_charge_all_backbone_with_around_target_ser_thr',
#  146: 'exposed_charge_all_sidechain_with_around_target_ser_thr',
#  147: 'exposed_positive_charge_all_around_target_ser_thr',
#  148: 'exposed_positive_charge_all_with_around_target_ser_thr',
#  149: 'exposed_positive_charge_all_backbone_around_target_ser_thr',
#  150: 'exposed_positive_charge_all_sidechain_around_target_ser_thr',
#  151: 'exposed_positive_charge_all_backbone_with_around_target_ser_thr',
#  152: 'exposed_positive_charge_all_sidechain_with_around_target_ser_thr',
#  153: 'exposed_negative_charge_all_around_target_ser_thr',
#  154: 'exposed_negative_charge_all_with_around_target_ser_thr',
#  155: 'exposed_negative_charge_all_backbone_around_target_ser_thr',
#  156: 'exposed_negative_charge_all_sidechain_around_target_ser_thr',
#  157: 'exposed_negative_charge_all_backbone_with_around_target_ser_thr',
#  158: 'SEQ_S',
#  159: 'SEQ_T',
#  160: 'nS/nT_1',
#  161: 'nS/nT_2',
#  162: 'nS/nT_3',
#  163: 'nS/nT_4',
#  164: 'nS/nT_5',
#  165: 'nS/nT_6',
#  166: 'nS/nT_7',
#  167: 'nS/nT_8',
#  168: 'nS/nT_9',
#  169: 'nS/nT_10',
#  170: 'nS/nT_11',
#  171: 'nS/nT_12',
#  172: 'nS/nT_13',
#  173: 'nS/nT_14',
#  174: 'nS/nT_15',
#  175: 'nAli_0',
#  176: 'nAli_1',
#  177: 'nAli_2',
#  178: 'nAli_3',
#  179: 'nPos_0',
#  180: 'nPos_1',
#  181: 'nPos_2',
#  182: 'nPos_3',
#  183: 'phi_psi_alpha',
#  184: 'phi_psi_beta',
#  185: 'phi_psi_other',
#  186: 'SS_C',
#  187: 'SS_E',
#  188: 'SS_H',
#  189: 'side_-1_cycle',
#  190: 'side_-1_gly',
#  191: 'side_-1_long',
#  192: 'side_-1_normal',
#  193: 'side_-1_pro',
#  194: 'side_-1_small',
#  195: 'side_-1_very_small',
#  196: 'side_1_None',
#  197: 'side_1_cycle',
#  198: 'side_1_gly',
#  199: 'side_1_long',
#  200: 'side_1_normal',
#  201: 'side_1_pro',
#  202: 'side_1_small',
#  203: 'side_1_very_small',
#  204: 'side_2_None',
#  205: 'side_2_cycle',
#  206: 'side_2_gly',
#  207: 'side_2_long',
#  208: 'side_2_normal',
#  209: 'side_2_pro',
#  210: 'side_2_small',
#  211: 'side_2_very_small',
#  212: 'side_3_None',
#  213: 'side_3_cycle',
#  214: 'side_3_gly',
#  215: 'side_3_long',
#  216: 'side_3_normal',
#  217: 'side_3_pro',
#  218: 'side_3_small',
#  219: 'side_3_very_small',
#  220: 'side_4_None',
#  221: 'side_4_cycle',
#  222: 'side_4_gly',
#  223: 'side_4_long',
#  224: 'side_4_normal',
#  225: 'side_4_pro',
#  226: 'side_4_small',
#  227: 'side_4_very_small',
#  228: 'side_5_None',
#  229: 'side_5_cycle',
#  230: 'side_5_gly',
#  231: 'side_5_long',
#  232: 'side_5_normal',
#  233: 'side_5_pro',
#  234: 'side_5_small',
#  235: 'side_5_very_small',
#  236: 'positivity'}

# %%
augmented_x = list(augmented_data.columns[2:158])
augmented_y = augmented_data.columns[-1]

# %%
both_x = list(augmented_data.columns[:2]) + list(augmented_data.columns[158:-1])
both_x = both_x + augmented_x
both_y = 'positivity'

# %% [markdown]
# # ElasticNet model

# %%
from sklearn.linear_model import ElasticNet

def elasticnet(data, x=[], y='', 
               alpha=0.001, l1_ratio=0.5):
    data_x = data[x]
    data_y = data[y]
    
    x_min = data_x.min(0)
    x_max = data_x.max(0)
    data_x_sc = (data_x - x_min) / (x_max - x_min)
    
    elastic_model = ElasticNet(alpha=alpha, l1_ratio=l1_ratio)
    elastic_model.fit(data_x_sc, data_y)
    
    return elastic_model

def elastic_coeff(model, x, rnd=3, disp=False):
    df = pd.DataFrame(
        zip(x, model.coef_, np.abs(model.coef_)
           ), columns = ['features', 'coefficient', 'absolute'] )
    df = df.sort_values(by='absolute', ascending=False).round(rnd)
    if disp:
        display(df.head(disp))
        
    df_important = df[df['absolute']>0]
    print(f'the number of important features: {len(df_important)} out of {len(x)} \n')
    display(dict(zip(df_important['features'], df_important['coefficient'])))
    
    return list(df_important['features'])

# %% [markdown]
# ## original dataset

# %%
data = original_data
x = original_x
y = original_y

alpha = 0.0001
model = elasticnet(data, x, y, alpha)
features = elastic_coeff(model, x)
# Out:
# the number of important features: 48 out of 87
# {'nS/nT_10': 0.017,
#  'flexibility': -0.012,
#  'nS/nT_11': 0.01,
#  'side_2_gly': 0.008,
#  'side_-1_pro': -0.007,
#  'nAli_0': -0.007,
#  'nAli_3': 0.007,
#  'side_2_very_small': 0.007,
#  'side_-1_very_small': 0.007,
#  'Proline': -0.005,
#  'side_4_gly': 0.005,
#  'side_3_long': -0.005,
#  'side_-1_small': 0.005,
#  'nPos_0': -0.004,
#  'SEQ_S': -0.004,
#  'side_4_small': 0.004,
#  'side_3_cycle': -0.004,
#  'side_5_normal': -0.004,
#  'SS_C': 0.004,
#  'side_5_very_small': 0.003,
#  'nS/nT_8': 0.003,
#  'side_3_very_small': 0.003,
#  'nAli_1': -0.003,
#  'nS/nT_12': 0.003,
#  'nS/nT_2': -0.003,
#  'side_1_pro': -0.003,
#  'nS/nT_7': 0.003,
#  'side_1_small': 0.002,
#  'nS/nT_3': -0.002,
#  'side_5_cycle': -0.002,
#  'side_4_long': 0.002,
#  'side_4_normal': -0.002,
#  'side_-1_normal': -0.002,
#  'nPos_1': 0.002,
#  'side_3_gly': 0.002,
#  'side_2_normal': -0.002,
#  'side_1_long': 0.001,
#  'nS/nT_1': -0.001,
#  'nS/nT_4': -0.001,
#  'side_2_long': -0.001,
#  'phi_psi_beta': -0.001,
#  'side_2_cycle': -0.001,
#  'side_2_small': 0.001,
#  'side_1_very_small': 0.001,
#  'nAli_2': 0.001,
#  'phi_psi_alpha': 0.001,
#  'side_5_gly': 0.001,
#  'nS/nT_5': -0.001}

# %% [markdown]
# ## augmented dataset

# %%
data = augmented_data
x = augmented_x
y = augmented_y
alpha = 0.0001

model = elasticnet(data, x, y, alpha)
features = elastic_coeff(model, x)
# Out:
# the number of important features: 38 out of 156
# {'sasa_ala': 0.047,
#  'sasa_g': 0.034,
#  'all_sasa_lys': -0.032,
#  'number_of_asn': -0.025,
#  'number_of_g': -0.023,
#  'sasa_ser': 0.022,
#  'sasa_cys': -0.021,
#  'sasa_p': 0.02,
#  'number_of_ser': 0.018,
#  'number_of_thr': -0.017,
#  'sasa_lys': -0.016,
#  'sasa_val': -0.016,
#  'number_of_leu': -0.014,
#  'sasa_negative': 0.013,
#  'net_charge_all_around_target_ser_thr': 0.012,
#  'sasa_ile': -0.011,
#  'sasa_s': -0.011,
#  'sasa_leu': -0.01,
#  'exposed_charge_all_sidechain_with_around_target_ser_thr': -0.009,
#  'all_sasa_aliphatic': -0.009,
#  'sasa_back': -0.009,
#  'number_of_lys': 0.008,
#  'exposed_charge_all_with_around_target_ser_thr': -0.008,
#  'sasa_polar': -0.008,
#  'sasa_phe': -0.008,
#  'exposed_positive_charge_all_with_around_target_ser_thr': -0.007,
#  'number_of_polar': -0.007,
#  'number_of_charged': -0.007,
#  'number_of_e': -0.007,
#  'sasa_e': -0.007,
#  'all_atom_negative_charge_all_backbone_around_target_ser_thr': 0.005,
#  'number_of_l': -0.004,
#  'sasa_f': 0.004,
#  'all_sasa_met': -0.003,
#  'sasa_met': -0.003,
#  'number_of_n': -0.002,
#  'number_of_negative': -0.002,
#  'all_sasa_glu': -0.002}

# %% [markdown]
# ## both dataset

# %%
data = augmented_data
x = both_x
y = both_y
alpha = 0.0001

model = elasticnet(data, x, y, alpha)
features = elastic_coeff(model, x)
# Out:
# the number of important features: 98 out of 236
# {'nS/nT_15': 0.596,
#  'sasa_ala': 0.049,
#  'all_sasa_lys': -0.038,
#  'sasa_l': 0.029,
#  'nS/nT_11': 0.027,
#  'number_of_g': -0.026,
#  'sasa_ser': 0.024,
#  'flexibility': -0.024,
#  'side_-1_pro': -0.024,
#  'number_of_asn': -0.019,
#  'nS/nT_8': 0.018,
#  'number_of_ser': 0.017,
#  'sasa_lys': -0.017,
#  'sasa_val': -0.016,
#  'side_2_gly': 0.015,
#  'side_4_gly': 0.014,
#  'nAli_0': -0.012,
#  'net_charge_all_around_target_ser_thr': 0.011,
#  'number_of_negative': -0.011,
#  'Proline': -0.011,
#  'number_of_thr': -0.011,
#  'sasa_cys': -0.011,
#  'nAli_3': 0.011,
#  'nS/nT_5': -0.009,
#  'nS/nT_1': -0.009,
#  'number_of_arg': -0.009,
#  'side_-1_very_small': 0.009,
#  'exposed_charge_all_with_around_target_ser_thr': -0.008,
#  'side_2_None': -0.008,
#  'exposed_positive_charge_all_with_around_target_ser_thr': -0.008,
#  'SS_E': -0.008,
#  'sasa_negative': 0.008,
#  'side_3_very_small': 0.008,
#  'side_2_pro': -0.008,
#  'number_of_leu': -0.008,
#  'number_of_polar': -0.008,
#  'number_of_l': -0.007,
#  'sasa_back': -0.006,
#  'side_5_normal': -0.006,
#  'side_2_very_small': 0.006,
#  'sasa_ile': -0.006,
#  'side_3_small': 0.006,
#  'side_1_very_small': 0.006,
#  'side_5_very_small': 0.006,
#  'all_sasa_cys': -0.006,
#  'side_-1_small': 0.005,
#  'side_3_long': -0.005,
#  'side_4_normal': -0.005,
#  'side_1_pro': -0.005,
#  'all_atom_negative_charge_all_backbone_around_target_ser_thr': 0.005,
#  'all_sasa_phe': -0.005,
#  'side_-1_long': -0.005,
#  'side_2_cycle': -0.005,
#  'number_of_lys': 0.005,
#  'side_-1_normal': -0.005,
#  'residue_SER_THR': -0.005,
#  'nS/nT_10': 0.005,
#  'number_of_charged': -0.005,
#  'sasa_leu': -0.005,
#  'side_3_gly': -0.004,
#  'side_4_very_small': -0.004,
#  'nS/nT_3': -0.004,
#  'nAli_1': -0.004,
#  'SS_H': 0.004,
#  'side_2_small': 0.004,
#  'number_of_e': -0.004,
#  'side_1_normal': -0.004,
#  'phi_psi_beta': -0.003,
#  'sasa_thr': 0.003,
#  'side_3_cycle': -0.003,
#  'all_sasa_v': -0.003,
#  'side_1_small': 0.003,
#  'all_sasa_leu': -0.003,
#  'nPos_3': -0.003,
#  'nS/nT_2': -0.003,
#  'nPos_2': -0.003,
#  'nPos_1': 0.003,
#  'nS/nT_13': -0.003,
#  'side_5_pro': 0.003,
#  'side_1_cycle': -0.003,
#  'side_4_small': 0.003,
#  'SEQ_S': -0.002,
#  'all_sasa_met': -0.002,
#  'side_4_pro': -0.002,
#  'exposed_charge_all_sidechain_with_around_target_ser_thr': -0.002,
#  'sasa_phe': -0.002,
#  'nS/nT_9': 0.002,
#  'nS/nT_7': -0.002,
#  'side_5_small': 0.002,
#  'side_5_long': -0.002,
#  'side_5_cycle': -0.001,
#  'nAli_2': 0.001,
#  'side_2_long': -0.001,
#  'side_3_pro': 0.001,
#  'sasa_gln': 0.001,
#  'phi_psi_other': 0.001,
#  'sasa_asp': 0.001,
#  'nS/nT_6': 0.001}

# %% [markdown]
# # ANOVA model

# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm

def anova(data, x=[], y='',
          disp=False, rnd=4):
    data = data[x + [y]]

    f_num = [f"f{num}" for num in range(len(x))]
    data.columns =  f_num + [y]

    n_not = len(f_num) # the number of not important features (initialize to the number of features)
    i = 1
    while n_not > 0:
        print(f'{i}th iteration')
        fs = '+'.join(f_num) 
        model = smf.ols(
            y + '~' + fs,
            data).fit()

        result = sm.stats.anova_lm(model, typ=2).round(rnd)
        n_not = len(result[result['PR(>F)'] > 0.05])
        f_num = [fn for fn in result[result['PR(>F)'] <= 0.05].index]

        i += 1

    result = result.sort_values(by='PR(>F)')
    print(f'the number of important features: {len(f_num)} out of {len(x)}')

    if disp:
        n = 10
        i = 0
        while i < len(result):
            print(result.iloc[i:i+n, :])
            i += n

    x_idx = [int(x.removeprefix('f')) for x in result.index[:-1]]
    x_names = [x[idx] for idx in x_idx]

    print('\norder variables by their importance')
    display(dict(zip(x_idx, x_names)))
    
    return x_names

# %% [markdown]
# ## original dataset

# %%
data = original_data
x = original_x
y = original_y

features = anova(data, x, y)
# Out:
# 1th iteration
# 2th iteration
# the number of important features: 1 out of 87
#
# order variables by their importance
# {1: 'flexibility'}

# %% [markdown]
# ## augmented dataset

# %%
data = augmented_data
x = augmented_x
y = augmented_y

features = anova(data, x, y)
# Out:
# 1th iteration
# 2th iteration
# 3th iteration
# the number of important features: 41 out of 156
#
# order variables by their importance
# {35: 'number_of_val',
#  28: 'number_of_leu',
#  17: 'number_of_d',
#  11: 'number_of_s',
#  27: 'number_of_lys',
#  22: 'number_of_asp',
#  19: 'number_of_f',
#  18: 'number_of_e',
#  12: 'number_of_n',
#  8: 'number_of_negative',
#  3: 'number_of_polar',
#  6: 'number_of_charged',
#  24: 'number_of_phe',
#  124: 'net_charge_all_sidechain_around_target_ser_thr',
#  126: 'net_charge_all_sidechain_with_around_target_ser_thr',
#  123: 'net_charge_all_backbone_around_target_ser_thr',
#  122: 'net_charge_all_with_around_target_ser_thr',
#  121: 'net_charge_all_around_target_ser_thr',
#  120: 'sasa_all_with_around_target_ser_thr',
#  127: 'all_atom_positive_charge_all_around_target_ser_thr',
#  128: 'all_atom_positive_charge_all_with_around_target_ser_thr',
#  129: 'all_atom_positive_charge_all_backbone_around_target_ser_thr',
#  125: 'net_charge_all_backbone_with_around_target_ser_thr',
#  131: 'all_atom_positive_charge_all_backbone_with_around_target_ser_thr',
#  130: 'all_atom_positive_charge_all_sidechain_around_target_ser_thr',
#  2: 'number_of_hydrophilic',
#  34: 'number_of_thr',
#  5: 'number_of_aliphatic',
#  16: 'number_of_b',
#  7: 'number_of_positive',
#  9: 'number_of_g',
#  25: 'number_of_his',
#  13: 'number_of_l',
#  0: 'residue_SER_THR',
#  21: 'number_of_cys',
#  36: 'number_of_trp',
#  14: 'number_of_p',
#  4: 'number_of_aromatic',
#  10: 'number_of_v',
#  23: 'number_of_glu',
#  15: 'number_of_A'}

# %% [markdown]
# ## both dataset

# %%
data = augmented_data
x = both_x
y = both_y

features = anova(data, x, y)
# Out:
# 1th iteration
# 2th iteration
# 3th iteration
# 4th iteration
# 5th iteration
# the number of important features: 48 out of 236
#
# order variables by their importance
# {18: 'nS/nT_15',
#  39: 'side_-1_very_small',
#  38: 'side_-1_small',
#  2: 'SEQ_S',
#  115: 'number_of_val',
#  3: 'SEQ_T',
#  113: 'number_of_ser',
#  88: 'number_of_negative',
#  100: 'number_of_ala',
#  95: 'number_of_A',
#  108: 'number_of_leu',
#  91: 'number_of_s',
#  98: 'number_of_e',
#  107: 'number_of_lys',
#  111: 'number_of_gln',
#  86: 'number_of_charged',
#  200: 'sasa_all_with_around_target_ser_thr',
#  206: 'net_charge_all_sidechain_with_around_target_ser_thr',
#  208: 'all_atom_positive_charge_all_with_around_target_ser_thr',
#  209: 'all_atom_positive_charge_all_backbone_around_target_ser_thr',
#  207: 'all_atom_positive_charge_all_around_target_ser_thr',
#  202: 'net_charge_all_with_around_target_ser_thr',
#  203: 'net_charge_all_backbone_around_target_ser_thr',
#  204: 'net_charge_all_sidechain_around_target_ser_thr',
#  201: 'net_charge_all_around_target_ser_thr',
#  205: 'net_charge_all_backbone_with_around_target_ser_thr',
#  211: 'all_atom_positive_charge_all_backbone_with_around_target_ser_thr',
#  50: 'side_2_gly',
#  210: 'all_atom_positive_charge_all_sidechain_around_target_ser_thr',
#  92: 'number_of_n',
#  89: 'number_of_g',
#  81: 'number_of_hydrophobic',
#  82: 'number_of_hydrophilic',
#  80: 'residue_SER_THR',
#  105: 'number_of_his',
#  94: 'number_of_p',
#  106: 'number_of_ile',
#  97: 'number_of_d',
#  87: 'number_of_positive',
#  96: 'number_of_b',
#  93: 'number_of_l',
#  112: 'number_of_arg',
#  116: 'number_of_trp',
#  84: 'number_of_aromatic',
#  90: 'number_of_v',
#  103: 'number_of_glu',
#  66: 'side_4_gly',
#  14: 'nS/nT_11'}

# %% [markdown]
# # Random Forest model

# %%
from sklearn.ensemble import RandomForestClassifier

def randomforest(data, x=[], y='',
                 n_estimators=500, rs=1):
    model = RandomForestClassifier(n_estimators = n_estimators, n_jobs=-1, random_state=rs)
    model.fit(data[x], data[y])
    
    return model

def FI(model, threshold= 0.95, rnd=3, disp=False):
    df = pd.DataFrame(zip(x, model.feature_importances_), columns = ['features', 'score'])
    df = df.sort_values(by='score', ascending=False)

    score_sum = []
    s = 1
    for score in df.score:
        s -= score
        score_sum.append(s)
    df['sum'] = np.array(score_sum)
    df = df.round(rnd)
    
    if disp:
        display(df.head(disp))

    
    df_important = df[df['sum']>= 1-threshold]

    print(f'the number of important features (threshold={threshold}): {len(df_important)} out of {len(df)}')
    display(dict(
        zip(df_important.index, zip(df_important['features'].values, df_important['score'].values, df_important['sum'].values))
    ))
    
    return list(df_important['features'])

# %% [markdown]
# ## original dataset

# %%
data = original_data
x = original_x
y = original_y

model = randomforest(data, x, y)
features = FI(model)
# Out:
# the number of important features (threshold=0.95): 62 out of 87
# {1: ('flexibility', 0.155, 0.845),
#  69: ('side_3_small', 0.022, 0.823),
#  85: ('side_5_small', 0.021, 0.802),
#  61: ('side_2_small', 0.021, 0.781),
#  33: ('phi_psi_alpha', 0.02, 0.76),
#  53: ('side_1_small', 0.02, 0.74),
#  77: ('side_4_small', 0.02, 0.721),
#  67: ('side_3_normal', 0.019, 0.702),
#  34: ('phi_psi_beta', 0.019, 0.684),
#  26: ('nAli_1', 0.018, 0.666),
#  3: ('SEQ_T', 0.017, 0.648),
#  70: ('side_3_very_small', 0.017, 0.631),
#  2: ('SEQ_S', 0.017, 0.614),
#  27: ('nAli_2', 0.016, 0.598),
#  62: ('side_2_very_small', 0.016, 0.582),
#  30: ('nPos_1', 0.016, 0.566),
#  8: ('nS/nT_5', 0.016, 0.55),
#  86: ('side_5_very_small', 0.016, 0.534),
#  45: ('side_-1_small', 0.016, 0.518),
#  29: ('nPos_0', 0.016, 0.502),
#  35: ('phi_psi_other', 0.015, 0.487),
#  7: ('nS/nT_4', 0.015, 0.472),
#  51: ('side_1_normal', 0.015, 0.456),
#  54: ('side_1_very_small', 0.015, 0.442),
#  9: ('nS/nT_6', 0.014, 0.428),
#  10: ('nS/nT_7', 0.014, 0.414),
#  78: ('side_4_very_small', 0.014, 0.401),
#  59: ('side_2_normal', 0.013, 0.387),
#  50: ('side_1_long', 0.012, 0.375),
#  68: ('side_3_pro', 0.012, 0.363),
#  83: ('side_5_normal', 0.012, 0.35),
#  25: ('nAli_0', 0.012, 0.338),
#  74: ('side_4_long', 0.012, 0.326),
#  82: ('side_5_long', 0.012, 0.314),
#  6: ('nS/nT_3', 0.012, 0.302),
#  60: ('side_2_pro', 0.012, 0.29),
#  75: ('side_4_normal', 0.012, 0.278),
#  57: ('side_2_gly', 0.012, 0.267),
#  84: ('side_5_pro', 0.012, 0.255),
#  73: ('side_4_gly', 0.012, 0.244),
#  11: ('nS/nT_8', 0.011, 0.232),
#  46: ('side_-1_very_small', 0.011, 0.221),
#  65: ('side_3_gly', 0.011, 0.21),
#  76: ('side_4_pro', 0.011, 0.199),
#  81: ('side_5_gly', 0.01, 0.189),
#  58: ('side_2_long', 0.01, 0.179),
#  42: ('side_-1_long', 0.009, 0.169),
#  49: ('side_1_gly', 0.009, 0.16),
#  36: ('SS_C', 0.009, 0.152),
#  48: ('side_1_cycle', 0.009, 0.143),
#  80: ('side_5_cycle', 0.009, 0.134),
#  66: ('side_3_long', 0.008, 0.126),
#  43: ('side_-1_normal', 0.008, 0.118),
#  13: ('nS/nT_10', 0.008, 0.11),
#  5: ('nS/nT_2', 0.008, 0.102),
#  72: ('side_4_cycle', 0.008, 0.095),
#  12: ('nS/nT_9', 0.007, 0.087),
#  28: ('nAli_3', 0.007, 0.08),
#  41: ('side_-1_gly', 0.007, 0.073),
#  56: ('side_2_cycle', 0.007, 0.066),
#  31: ('nPos_2', 0.007, 0.059),
#  64: ('side_3_cycle', 0.007, 0.052)}

# %% [markdown]
# ## augmented dataset

# %%
data = augmented_data
x = augmented_x
y = augmented_y

model = randomforest(data, x, y)
features = FI(model)
# Out:
# the number of important features (threshold=0.95): 129 out of 156
# {107: ('all_sasa_ser', 0.014, 0.986),
#  83: ('all_sasa_g', 0.013, 0.974),
#  88: ('all_sasa_p', 0.012, 0.961),
#  94: ('all_sasa_ala', 0.012, 0.949),
#  70: ('sasa_ser', 0.011, 0.938),
#  51: ('sasa_p', 0.011, 0.927),
#  82: ('all_sasa_negative', 0.011, 0.916),
#  108: ('all_sasa_thr', 0.011, 0.905),
#  106: ('all_sasa_arg', 0.011, 0.893),
#  78: ('all_sasa_aromatic', 0.01, 0.883),
#  93: ('all_sasa_f', 0.01, 0.873),
#  69: ('sasa_arg', 0.01, 0.863),
#  76: ('all_sasa_hydrophilic', 0.01, 0.852),
#  105: ('all_sasa_gln', 0.01, 0.842),
#  99: ('all_sasa_his', 0.01, 0.832),
#  39: ('sasa_hydrophilic', 0.01, 0.822),
#  121: ('net_charge_all_around_target_ser_thr', 0.009, 0.813),
#  46: ('sasa_g', 0.009, 0.804),
#  117: ('all_sasa_side_with_whole_target', 0.009, 0.794),
#  104: ('all_sasa_asn', 0.009, 0.785),
#  96: ('all_sasa_asp', 0.009, 0.776),
#  74: ('sasa_tyr', 0.009, 0.766),
#  120: ('sasa_all_with_around_target_ser_thr', 0.009, 0.757),
#  86: ('all_sasa_n', 0.009, 0.748),
#  87: ('all_sasa_l', 0.009, 0.74),
#  56: ('sasa_f', 0.009, 0.731),
#  91: ('all_sasa_d', 0.009, 0.722),
#  140: ('exposed_charge_all_with_around_target_ser_thr', 0.009, 0.713),
#  139: ('exposed_charge_all_around_target_ser_thr', 0.009, 0.705),
#  113: ('all_sasa_back', 0.009, 0.696),
#  103: ('all_sasa_met', 0.009, 0.687),
#  112: ('sasa_back', 0.009, 0.679),
#  84: ('all_sasa_v', 0.008, 0.67),
#  47: ('sasa_v', 0.008, 0.662),
#  81: ('all_sasa_positive', 0.008, 0.654),
#  37: ('number_of_tyr', 0.008, 0.645),
#  138: ('all_atom_negative_charge_all_sidechain_with_around_target_ser_thr',
#   0.008,
#   0.637),
#  155: ('exposed_negative_charge_all_backbone_with_around_target_ser_thr',
#   0.008,
#   0.628),
#  38: ('sasa_hydrophobic', 0.008, 0.62),
#  90: ('all_sasa_b', 0.008, 0.612),
#  129: ('all_atom_positive_charge_all_backbone_around_target_ser_thr',
#   0.008,
#   0.603),
#  115: ('all_sasa_side', 0.008, 0.595),
#  142: ('exposed_charge_all_sidechain_around_target_ser_thr', 0.008, 0.587),
#  101: ('all_sasa_lys', 0.008, 0.579),
#  80: ('all_sasa_charged', 0.008, 0.57),
#  89: ('all_sasa_A', 0.008, 0.562),
#  131: ('all_atom_positive_charge_all_backbone_with_around_target_ser_thr',
#   0.008,
#   0.554),
#  141: ('exposed_charge_all_backbone_around_target_ser_thr', 0.008, 0.546),
#  85: ('all_sasa_s', 0.008, 0.538),
#  97: ('all_sasa_glu', 0.008, 0.53),
#  144: ('exposed_charge_all_sidechain_with_around_target_ser_thr',
#   0.008,
#   0.521),
#  79: ('all_sasa_aliphatic', 0.008, 0.513),
#  148: ('exposed_positive_charge_all_sidechain_around_target_ser_thr',
#   0.008,
#   0.505),
#  109: ('all_sasa_val', 0.008, 0.497),
#  98: ('all_sasa_phe', 0.008, 0.489),
#  125: ('net_charge_all_backbone_with_around_target_ser_thr', 0.008, 0.482),
#  41: ('sasa_aromatic', 0.008, 0.474),
#  95: ('all_sasa_cys', 0.008, 0.466),
#  75: ('all_sasa_hydrophobic', 0.008, 0.458),
#  149: ('exposed_positive_charge_all_backbone_with_around_target_ser_thr',
#   0.008,
#   0.45),
#  143: ('exposed_charge_all_backbone_with_around_target_ser_thr', 0.008, 0.442),
#  114: ('sasa_side', 0.008, 0.435),
#  123: ('net_charge_all_backbone_around_target_ser_thr', 0.008, 0.427),
#  119: ('sasa_all_around_target_ser_thr', 0.008, 0.42),
#  126: ('net_charge_all_sidechain_with_around_target_ser_thr', 0.008, 0.412),
#  146: ('exposed_positive_charge_all_with_around_target_ser_thr', 0.008, 0.404),
#  77: ('all_sasa_polar', 0.008, 0.397),
#  100: ('all_sasa_ile', 0.007, 0.389),
#  145: ('exposed_positive_charge_all_around_target_ser_thr', 0.007, 0.382),
#  151: ('exposed_negative_charge_all_around_target_ser_thr', 0.007, 0.374),
#  132: ('all_atom_positive_charge_all_sidechain_with_around_target_ser_thr',
#   0.007,
#   0.367),
#  111: ('all_sasa_tyr', 0.007, 0.36),
#  133: ('all_atom_negative_charge_all_around_target_ser_thr', 0.007, 0.352),
#  116: ('all_sasa_back_with_whole_target', 0.007, 0.345),
#  153: ('exposed_negative_charge_all_backbone_around_target_ser_thr',
#   0.007,
#   0.338),
#  110: ('all_sasa_trp', 0.007, 0.33),
#  150: ('exposed_positive_charge_all_sidechain_with_around_target_ser_thr',
#   0.007,
#   0.323),
#  137: ('all_atom_negative_charge_all_backbone_with_around_target_ser_thr',
#   0.007,
#   0.316),
#  71: ('sasa_thr', 0.007, 0.308),
#  45: ('sasa_negative', 0.007, 0.301),
#  92: ('all_sasa_e', 0.007, 0.294),
#  102: ('all_sasa_leu', 0.007, 0.287),
#  57: ('sasa_ala', 0.007, 0.28),
#  135: ('all_atom_negative_charge_all_backbone_around_target_ser_thr',
#   0.007,
#   0.273),
#  118: ('sasa_target_ser_thr', 0.007, 0.266),
#  152: ('exposed_negative_charge_all_with_around_target_ser_thr', 0.007, 0.26),
#  147: ('exposed_positive_charge_all_backbone_around_target_ser_thr',
#   0.007,
#   0.253),
#  130: ('all_atom_positive_charge_all_sidechain_around_target_ser_thr',
#   0.007,
#   0.246),
#  136: ('all_atom_negative_charge_all_sidechain_around_target_ser_thr',
#   0.007,
#   0.24),
#  124: ('net_charge_all_sidechain_around_target_ser_thr', 0.006, 0.233),
#  42: ('sasa_aliphatic', 0.006, 0.227),
#  127: ('all_atom_positive_charge_all_around_target_ser_thr', 0.006, 0.22),
#  128: ('all_atom_positive_charge_all_with_around_target_ser_thr',
#   0.006,
#   0.214),
#  122: ('net_charge_all_with_around_target_ser_thr', 0.006, 0.208),
#  68: ('sasa_gln', 0.006, 0.202),
#  154: ('exposed_negative_charge_all_sidechain_around_target_ser_thr',
#   0.006,
#   0.195),
#  134: ('all_atom_negative_charge_all_with_around_target_ser_thr',
#   0.006,
#   0.189),
#  48: ('sasa_s', 0.006, 0.183),
#  43: ('sasa_charged', 0.006, 0.177),
#  10: ('number_of_v', 0.006, 0.171),
#  50: ('sasa_l', 0.006, 0.165),
#  52: ('sasa_A', 0.006, 0.16),
#  49: ('sasa_n', 0.006, 0.154),
#  62: ('sasa_his', 0.005, 0.149),
#  59: ('sasa_asp', 0.005, 0.144),
#  0: ('residue_SER_THR', 0.005, 0.139),
#  64: ('sasa_lys', 0.005, 0.135),
#  14: ('number_of_p', 0.005, 0.13),
#  2: ('number_of_hydrophilic', 0.004, 0.126),
#  9: ('number_of_g', 0.004, 0.121),
#  54: ('sasa_d', 0.004, 0.117),
#  67: ('sasa_asn', 0.004, 0.113),
#  44: ('sasa_positive', 0.004, 0.109),
#  1: ('number_of_hydrophobic', 0.004, 0.105),
#  60: ('sasa_glu', 0.004, 0.101),
#  66: ('sasa_met', 0.004, 0.096),
#  53: ('sasa_b', 0.004, 0.092),
#  4: ('number_of_aromatic', 0.004, 0.088),
#  63: ('sasa_ile', 0.004, 0.085),
#  32: ('number_of_arg', 0.004, 0.081),
#  33: ('number_of_ser', 0.004, 0.077),
#  58: ('sasa_cys', 0.004, 0.074),
#  55: ('sasa_e', 0.004, 0.07),
#  11: ('number_of_s', 0.004, 0.066),
#  40: ('sasa_polar', 0.003, 0.063),
#  19: ('number_of_f', 0.003, 0.06),
#  13: ('number_of_l', 0.003, 0.057),
#  31: ('number_of_gln', 0.003, 0.054),
#  5: ('number_of_aliphatic', 0.003, 0.051)}

# %% [markdown]
# ## both dataset

# %%
data = augmented_data
x = both_x
y = both_y

model = randomforest(data, x, y)
features = FI(model)
# Out:
# the number of important features (threshold=0.95): 167 out of 236
# {187: ('all_sasa_ser', 0.012, 0.988),
#  168: ('all_sasa_p', 0.011, 0.977),
#  163: ('all_sasa_g', 0.011, 0.965),
#  131: ('sasa_p', 0.011, 0.955),
#  174: ('all_sasa_ala', 0.01, 0.944),
#  186: ('all_sasa_arg', 0.01, 0.934),
#  150: ('sasa_ser', 0.01, 0.924),
#  162: ('all_sasa_negative', 0.01, 0.914),
#  185: ('all_sasa_gln', 0.01, 0.905),
#  173: ('all_sasa_f', 0.01, 0.895),
#  126: ('sasa_g', 0.009, 0.886),
#  1: ('flexibility', 0.009, 0.877),
#  156: ('all_sasa_hydrophilic', 0.009, 0.868),
#  119: ('sasa_hydrophilic', 0.009, 0.859),
#  188: ('all_sasa_thr', 0.009, 0.85),
#  155: ('all_sasa_hydrophobic', 0.009, 0.841),
#  149: ('sasa_arg', 0.009, 0.832),
#  179: ('all_sasa_his', 0.009, 0.823),
#  184: ('all_sasa_asn', 0.009, 0.815),
#  197: ('all_sasa_side_with_whole_target', 0.008, 0.806),
#  176: ('all_sasa_asp', 0.008, 0.798),
#  158: ('all_sasa_aromatic', 0.008, 0.789),
#  166: ('all_sasa_n', 0.008, 0.781),
#  171: ('all_sasa_d', 0.008, 0.773),
#  169: ('all_sasa_A', 0.008, 0.764),
#  154: ('sasa_tyr', 0.008, 0.756),
#  160: ('all_sasa_charged', 0.008, 0.748),
#  209: ('all_atom_positive_charge_all_backbone_around_target_ser_thr',
#   0.008,
#   0.74),
#  159: ('all_sasa_aliphatic', 0.008, 0.732),
#  201: ('net_charge_all_around_target_ser_thr', 0.008, 0.724),
#  211: ('all_atom_positive_charge_all_backbone_with_around_target_ser_thr',
#   0.008,
#   0.716),
#  118: ('sasa_hydrophobic', 0.008, 0.708),
#  195: ('all_sasa_side', 0.008, 0.7),
#  200: ('sasa_all_with_around_target_ser_thr', 0.008, 0.692),
#  218: ('all_atom_negative_charge_all_sidechain_with_around_target_ser_thr',
#   0.008,
#   0.684),
#  192: ('sasa_back', 0.008, 0.677),
#  127: ('sasa_v', 0.008, 0.669),
#  165: ('all_sasa_s', 0.008, 0.661),
#  205: ('net_charge_all_backbone_with_around_target_ser_thr', 0.008, 0.653),
#  175: ('all_sasa_cys', 0.008, 0.646),
#  193: ('all_sasa_back', 0.008, 0.638),
#  121: ('sasa_aromatic', 0.008, 0.63),
#  235: ('exposed_negative_charge_all_backbone_with_around_target_ser_thr',
#   0.008,
#   0.623),
#  220: ('exposed_charge_all_with_around_target_ser_thr', 0.008, 0.615),
#  164: ('all_sasa_v', 0.008, 0.608),
#  181: ('all_sasa_lys', 0.008, 0.6),
#  231: ('exposed_negative_charge_all_around_target_ser_thr', 0.008, 0.593),
#  167: ('all_sasa_l', 0.007, 0.585),
#  170: ('all_sasa_b', 0.007, 0.578),
#  199: ('sasa_all_around_target_ser_thr', 0.007, 0.57),
#  222: ('exposed_charge_all_sidechain_around_target_ser_thr', 0.007, 0.563),
#  136: ('sasa_f', 0.007, 0.556),
#  224: ('exposed_charge_all_sidechain_with_around_target_ser_thr',
#   0.007,
#   0.548),
#  221: ('exposed_charge_all_backbone_around_target_ser_thr', 0.007, 0.541),
#  196: ('all_sasa_back_with_whole_target', 0.007, 0.534),
#  228: ('exposed_positive_charge_all_sidechain_around_target_ser_thr',
#   0.007,
#   0.526),
#  219: ('exposed_charge_all_around_target_ser_thr', 0.007, 0.519),
#  161: ('all_sasa_positive', 0.007, 0.512),
#  226: ('exposed_positive_charge_all_with_around_target_ser_thr', 0.007, 0.504),
#  217: ('all_atom_negative_charge_all_backbone_with_around_target_ser_thr',
#   0.007,
#   0.497),
#  223: ('exposed_charge_all_backbone_with_around_target_ser_thr', 0.007, 0.49),
#  229: ('exposed_positive_charge_all_backbone_with_around_target_ser_thr',
#   0.007,
#   0.483),
#  191: ('all_sasa_tyr', 0.007, 0.476),
#  178: ('all_sasa_phe', 0.007, 0.468),
#  183: ('all_sasa_met', 0.007, 0.461),
#  233: ('exposed_negative_charge_all_backbone_around_target_ser_thr',
#   0.007,
#   0.454),
#  212: ('all_atom_positive_charge_all_sidechain_with_around_target_ser_thr',
#   0.007,
#   0.447),
#  194: ('sasa_side', 0.007, 0.44),
#  227: ('exposed_positive_charge_all_backbone_around_target_ser_thr',
#   0.007,
#   0.433),
#  213: ('all_atom_negative_charge_all_around_target_ser_thr', 0.007, 0.426),
#  125: ('sasa_negative', 0.007, 0.419),
#  198: ('sasa_target_ser_thr', 0.007, 0.412),
#  203: ('net_charge_all_backbone_around_target_ser_thr', 0.007, 0.405),
#  206: ('net_charge_all_sidechain_with_around_target_ser_thr', 0.007, 0.398),
#  189: ('all_sasa_val', 0.007, 0.391),
#  215: ('all_atom_negative_charge_all_backbone_around_target_ser_thr',
#   0.007,
#   0.384),
#  225: ('exposed_positive_charge_all_around_target_ser_thr', 0.007, 0.377),
#  177: ('all_sasa_glu', 0.007, 0.37),
#  190: ('all_sasa_trp', 0.007, 0.364),
#  117: ('number_of_tyr', 0.007, 0.357),
#  182: ('all_sasa_leu', 0.007, 0.35),
#  180: ('all_sasa_ile', 0.007, 0.344),
#  210: ('all_atom_positive_charge_all_sidechain_around_target_ser_thr',
#   0.006,
#   0.337),
#  230: ('exposed_positive_charge_all_sidechain_with_around_target_ser_thr',
#   0.006,
#   0.331),
#  172: ('all_sasa_e', 0.006, 0.324),
#  204: ('net_charge_all_sidechain_around_target_ser_thr', 0.006, 0.318),
#  151: ('sasa_thr', 0.006, 0.312),
#  157: ('all_sasa_polar', 0.006, 0.306),
#  137: ('sasa_ala', 0.006, 0.3),
#  214: ('all_atom_negative_charge_all_with_around_target_ser_thr',
#   0.006,
#   0.294),
#  207: ('all_atom_positive_charge_all_around_target_ser_thr', 0.006, 0.288),
#  130: ('sasa_l', 0.006, 0.282),
#  129: ('sasa_n', 0.006, 0.276),
#  148: ('sasa_gln', 0.006, 0.27),
#  122: ('sasa_aliphatic', 0.006, 0.264),
#  202: ('net_charge_all_with_around_target_ser_thr', 0.006, 0.258),
#  234: ('exposed_negative_charge_all_sidechain_around_target_ser_thr',
#   0.006,
#   0.253),
#  216: ('all_atom_negative_charge_all_sidechain_around_target_ser_thr',
#   0.006,
#   0.247),
#  232: ('exposed_negative_charge_all_with_around_target_ser_thr', 0.005, 0.241),
#  208: ('all_atom_positive_charge_all_with_around_target_ser_thr',
#   0.005,
#   0.236),
#  128: ('sasa_s', 0.005, 0.231),
#  123: ('sasa_charged', 0.005, 0.225),
#  90: ('number_of_v', 0.005, 0.22),
#  132: ('sasa_A', 0.005, 0.215),
#  142: ('sasa_his', 0.005, 0.21),
#  139: ('sasa_asp', 0.005, 0.206),
#  124: ('sasa_positive', 0.004, 0.201),
#  18: ('nS/nT_15', 0.004, 0.197),
#  84: ('number_of_aromatic', 0.004, 0.193),
#  147: ('sasa_asn', 0.004, 0.189),
#  82: ('number_of_hydrophilic', 0.004, 0.185),
#  144: ('sasa_lys', 0.004, 0.18),
#  134: ('sasa_d', 0.004, 0.177),
#  80: ('residue_SER_THR', 0.004, 0.173),
#  94: ('number_of_p', 0.004, 0.169),
#  133: ('sasa_b', 0.004, 0.165),
#  113: ('number_of_ser', 0.004, 0.162),
#  89: ('number_of_g', 0.004, 0.158),
#  81: ('number_of_hydrophobic', 0.004, 0.155),
#  146: ('sasa_met', 0.004, 0.151),
#  91: ('number_of_s', 0.004, 0.148),
#  143: ('sasa_ile', 0.003, 0.144),
#  140: ('sasa_glu', 0.003, 0.141),
#  107: ('number_of_lys', 0.003, 0.138),
#  120: ('sasa_polar', 0.003, 0.135),
#  112: ('number_of_arg', 0.003, 0.132),
#  138: ('sasa_cys', 0.003, 0.128),
#  111: ('number_of_gln', 0.003, 0.125),
#  85: ('number_of_aliphatic', 0.003, 0.122),
#  135: ('sasa_e', 0.003, 0.119),
#  99: ('number_of_f', 0.003, 0.117),
#  95: ('number_of_A', 0.003, 0.114),
#  93: ('number_of_l', 0.003, 0.111),
#  100: ('number_of_ala', 0.003, 0.108),
#  88: ('number_of_negative', 0.003, 0.106),
#  114: ('number_of_thr', 0.002, 0.103),
#  86: ('number_of_charged', 0.002, 0.101),
#  153: ('sasa_trp', 0.002, 0.099),
#  96: ('number_of_b', 0.002, 0.096),
#  92: ('number_of_n', 0.002, 0.094),
#  11: ('nS/nT_8', 0.002, 0.092),
#  141: ('sasa_phe', 0.002, 0.09),
#  102: ('number_of_asp', 0.002, 0.088),
#  105: ('number_of_his', 0.002, 0.086),
#  87: ('number_of_positive', 0.002, 0.084),
#  110: ('number_of_asn', 0.002, 0.082),
#  109: ('number_of_met', 0.002, 0.08),
#  97: ('number_of_d', 0.002, 0.078),
#  106: ('number_of_ile', 0.002, 0.076),
#  66: ('side_4_gly', 0.002, 0.075),
#  39: ('side_-1_very_small', 0.002, 0.073),
#  145: ('sasa_leu', 0.002, 0.072),
#  83: ('number_of_polar', 0.002, 0.07),
#  98: ('number_of_e', 0.002, 0.068),
#  22: ('nAli_3', 0.001, 0.067),
#  50: ('side_2_gly', 0.001, 0.066),
#  61: ('side_3_pro', 0.001, 0.064),
#  21: ('nAli_2', 0.001, 0.063),
#  47: ('side_1_very_small', 0.001, 0.061),
#  77: ('side_5_pro', 0.001, 0.06),
#  101: ('number_of_cys', 0.001, 0.059),
#  7: ('nS/nT_4', 0.001, 0.057),
#  79: ('side_5_very_small', 0.001, 0.056),
#  9: ('nS/nT_6', 0.001, 0.055),
#  29: ('phi_psi_other', 0.001, 0.054),
#  38: ('side_-1_small', 0.001, 0.052),
#  152: ('sasa_val', 0.001, 0.051)}

# %% [markdown]
# # Result of finding important variables

# %% [markdown]
# ## original dataset

# %%
data = original_data
x = original_x
y = original_y

# ElasticNet
alpha = 0.0001
model = elasticnet(data, x, y, alpha)
EN_features = elastic_coeff(model, x)

# ANOVA
AN_features = anova(data, x, y)

# RandomForest
threshold = 0.95
model = randomforest(data, x, y)
RF_features = FI(model, threshold=threshold)
# Out:
# the number of important features: 48 out of 87
# {'nS/nT_10': 0.017,
#  'flexibility': -0.012,
#  'nS/nT_11': 0.01,
#  'side_2_gly': 0.008,
#  'side_-1_pro': -0.007,
#  'nAli_0': -0.007,
#  'nAli_3': 0.007,
#  'side_2_very_small': 0.007,
#  'side_-1_very_small': 0.007,
#  'Proline': -0.005,
#  'side_4_gly': 0.005,
#  'side_3_long': -0.005,
#  'side_-1_small': 0.005,
#  'nPos_0': -0.004,
#  'SEQ_S': -0.004,
#  'side_4_small': 0.004,
#  'side_3_cycle': -0.004,
#  'side_5_normal': -0.004,
#  'SS_C': 0.004,
#  'side_5_very_small': 0.003,
#  'nS/nT_8': 0.003,
#  'side_3_very_small': 0.003,
#  'nAli_1': -0.003,
#  'nS/nT_12': 0.003,
#  'nS/nT_2': -0.003,
#  'side_1_pro': -0.003,
#  'nS/nT_7': 0.003,
#  'side_1_small': 0.002,
#  'nS/nT_3': -0.002,
#  'side_5_cycle': -0.002,
#  'side_4_long': 0.002,
#  'side_4_normal': -0.002,
#  'side_-1_normal': -0.002,
#  'nPos_1': 0.002,
#  'side_3_gly': 0.002,
#  'side_2_normal': -0.002,
#  'side_1_long': 0.001,
#  'nS/nT_1': -0.001,
#  'nS/nT_4': -0.001,
#  'side_2_long': -0.001,
#  'phi_psi_beta': -0.001,
#  'side_2_cycle': -0.001,
#  'side_2_small': 0.001,
#  'side_1_very_small': 0.001,
#  'nAli_2': 0.001,
#  'phi_psi_alpha': 0.001,
#  'side_5_gly': 0.001,
#  'nS/nT_5': -0.001}
# 1th iteration
# 2th iteration
# the number of important features: 1 out of 87
#
# order variables by their importance
# {1: 'flexibility'}
# the number of important features (threshold=0.95): 62 out of 87
# {1: ('flexibility', 0.155, 0.845),
#  69: ('side_3_small', 0.022, 0.823),
#  85: ('side_5_small', 0.021, 0.802),
#  61: ('side_2_small', 0.021, 0.781),
#  33: ('phi_psi_alpha', 0.02, 0.76),
#  53: ('side_1_small', 0.02, 0.74),
#  77: ('side_4_small', 0.02, 0.721),
#  67: ('side_3_normal', 0.019, 0.702),
#  34: ('phi_psi_beta', 0.019, 0.684),
#  26: ('nAli_1', 0.018, 0.666),
#  3: ('SEQ_T', 0.017, 0.648),
#  70: ('side_3_very_small', 0.017, 0.631),
#  2: ('SEQ_S', 0.017, 0.614),
#  27: ('nAli_2', 0.016, 0.598),
#  62: ('side_2_very_small', 0.016, 0.582),
#  30: ('nPos_1', 0.016, 0.566),
#  8: ('nS/nT_5', 0.016, 0.55),
#  86: ('side_5_very_small', 0.016, 0.534),
#  45: ('side_-1_small', 0.016, 0.518),
#  29: ('nPos_0', 0.016, 0.502),
#  35: ('phi_psi_other', 0.015, 0.487),
#  7: ('nS/nT_4', 0.015, 0.472),
#  51: ('side_1_normal', 0.015, 0.456),
#  54: ('side_1_very_small', 0.015, 0.442),
#  9: ('nS/nT_6', 0.014, 0.428),
#  10: ('nS/nT_7', 0.014, 0.414),
#  78: ('side_4_very_small', 0.014, 0.401),
#  59: ('side_2_normal', 0.013, 0.387),
#  50: ('side_1_long', 0.012, 0.375),
#  68: ('side_3_pro', 0.012, 0.363),
#  83: ('side_5_normal', 0.012, 0.35),
#  25: ('nAli_0', 0.012, 0.338),
#  74: ('side_4_long', 0.012, 0.326),
#  82: ('side_5_long', 0.012, 0.314),
#  6: ('nS/nT_3', 0.012, 0.302),
#  60: ('side_2_pro', 0.012, 0.29),
#  75: ('side_4_normal', 0.012, 0.278),
#  57: ('side_2_gly', 0.012, 0.267),
#  84: ('side_5_pro', 0.012, 0.255),
#  73: ('side_4_gly', 0.012, 0.244),
#  11: ('nS/nT_8', 0.011, 0.232),
#  46: ('side_-1_very_small', 0.011, 0.221),
#  65: ('side_3_gly', 0.011, 0.21),
#  76: ('side_4_pro', 0.011, 0.199),
#  81: ('side_5_gly', 0.01, 0.189),
#  58: ('side_2_long', 0.01, 0.179),
#  42: ('side_-1_long', 0.009, 0.169),
#  49: ('side_1_gly', 0.009, 0.16),
#  36: ('SS_C', 0.009, 0.152),
#  48: ('side_1_cycle', 0.009, 0.143),
#  80: ('side_5_cycle', 0.009, 0.134),
#  66: ('side_3_long', 0.008, 0.126),
#  43: ('side_-1_normal', 0.008, 0.118),
#  13: ('nS/nT_10', 0.008, 0.11),
#  5: ('nS/nT_2', 0.008, 0.102),
#  72: ('side_4_cycle', 0.008, 0.095),
#  12: ('nS/nT_9', 0.007, 0.087),
#  28: ('nAli_3', 0.007, 0.08),
#  41: ('side_-1_gly', 0.007, 0.073),
#  56: ('side_2_cycle', 0.007, 0.066),
#  31: ('nPos_2', 0.007, 0.059),
#  64: ('side_3_cycle', 0.007, 0.052)}

# %%
importance = pd.DataFrame(np.zeros((len(x), 3)), columns=['ElasticNet', 'ANOVA', 'RandomForest'], index=x)
for feature in EN_features:
    importance.loc[feature,'ElasticNet'] = 1
for feature in AN_features:
    importance.loc[feature,'ANOVA'] = 1
for feature in RF_features:
    importance.loc[feature,'RandomForest'] = 1
    
importance['Score'] = importance.sum(axis=1)
save_path = './result/important_variables_original_cts_cat.csv'
if not exists(save_path):
    importance.to_csv(save_path)
importance_original = importance
importance_original
# Out:
#                    ElasticNet  ANOVA  RandomForest  Score
# Proline                   1.0    0.0           0.0    1.0
# flexibility               1.0    1.0           1.0    3.0
# SEQ_S                     1.0    0.0           1.0    2.0
# SEQ_T                     0.0    0.0           1.0    1.0
# nS/nT_1                   1.0    0.0           0.0    1.0
# ...                       ...    ...           ...    ...
# side_5_long               0.0    0.0           1.0    1.0
# side_5_normal             1.0    0.0           1.0    2.0
# side_5_pro                0.0    0.0           1.0    1.0
# side_5_small              0.0    0.0           1.0    1.0
# side_5_very_small         1.0    0.0           1.0    2.0
#
# [87 rows x 4 columns]

# %% [markdown]
# ## augmented dataset

# %%
data = augmented_data
x = augmented_x
y = augmented_y

# ElasticNet
alpha = 0.0001
model = elasticnet(data, x, y, alpha)
EN_features = elastic_coeff(model, x)

# ANOVA
AN_features = anova(data, x, y)

# RandomForest
threshold = 0.95
model = randomforest(data, x, y)
RF_features = FI(model, threshold=threshold)
# Out:
# the number of important features: 38 out of 156
# {'sasa_ala': 0.047,
#  'sasa_g': 0.034,
#  'all_sasa_lys': -0.032,
#  'number_of_asn': -0.025,
#  'number_of_g': -0.023,
#  'sasa_ser': 0.022,
#  'sasa_cys': -0.021,
#  'sasa_p': 0.02,
#  'number_of_ser': 0.018,
#  'number_of_thr': -0.017,
#  'sasa_lys': -0.016,
#  'sasa_val': -0.016,
#  'number_of_leu': -0.014,
#  'sasa_negative': 0.013,
#  'net_charge_all_around_target_ser_thr': 0.012,
#  'sasa_ile': -0.011,
#  'sasa_s': -0.011,
#  'sasa_leu': -0.01,
#  'exposed_charge_all_sidechain_with_around_target_ser_thr': -0.009,
#  'all_sasa_aliphatic': -0.009,
#  'sasa_back': -0.009,
#  'number_of_lys': 0.008,
#  'exposed_charge_all_with_around_target_ser_thr': -0.008,
#  'sasa_polar': -0.008,
#  'sasa_phe': -0.008,
#  'exposed_positive_charge_all_with_around_target_ser_thr': -0.007,
#  'number_of_polar': -0.007,
#  'number_of_charged': -0.007,
#  'number_of_e': -0.007,
#  'sasa_e': -0.007,
#  'all_atom_negative_charge_all_backbone_around_target_ser_thr': 0.005,
#  'number_of_l': -0.004,
#  'sasa_f': 0.004,
#  'all_sasa_met': -0.003,
#  'sasa_met': -0.003,
#  'number_of_n': -0.002,
#  'number_of_negative': -0.002,
#  'all_sasa_glu': -0.002}
# 1th iteration
# 2th iteration
# 3th iteration
# the number of important features: 41 out of 156
#
# order variables by their importance
# {35: 'number_of_val',
#  28: 'number_of_leu',
#  17: 'number_of_d',
#  11: 'number_of_s',
#  27: 'number_of_lys',
#  22: 'number_of_asp',
#  19: 'number_of_f',
#  18: 'number_of_e',
#  12: 'number_of_n',
#  8: 'number_of_negative',
#  3: 'number_of_polar',
#  6: 'number_of_charged',
#  24: 'number_of_phe',
#  124: 'net_charge_all_sidechain_around_target_ser_thr',
#  126: 'net_charge_all_sidechain_with_around_target_ser_thr',
#  123: 'net_charge_all_backbone_around_target_ser_thr',
#  122: 'net_charge_all_with_around_target_ser_thr',
#  121: 'net_charge_all_around_target_ser_thr',
#  120: 'sasa_all_with_around_target_ser_thr',
#  127: 'all_atom_positive_charge_all_around_target_ser_thr',
#  128: 'all_atom_positive_charge_all_with_around_target_ser_thr',
#  129: 'all_atom_positive_charge_all_backbone_around_target_ser_thr',
#  125: 'net_charge_all_backbone_with_around_target_ser_thr',
#  131: 'all_atom_positive_charge_all_backbone_with_around_target_ser_thr',
#  130: 'all_atom_positive_charge_all_sidechain_around_target_ser_thr',
#  2: 'number_of_hydrophilic',
#  34: 'number_of_thr',
#  5: 'number_of_aliphatic',
#  16: 'number_of_b',
#  7: 'number_of_positive',
#  9: 'number_of_g',
#  25: 'number_of_his',
#  13: 'number_of_l',
#  0: 'residue_SER_THR',
#  21: 'number_of_cys',
#  36: 'number_of_trp',
#  14: 'number_of_p',
#  4: 'number_of_aromatic',
#  10: 'number_of_v',
#  23: 'number_of_glu',
#  15: 'number_of_A'}
# the number of important features (threshold=0.95): 129 out of 156
# {107: ('all_sasa_ser', 0.014, 0.986),
#  83: ('all_sasa_g', 0.013, 0.974),
#  88: ('all_sasa_p', 0.012, 0.961),
#  94: ('all_sasa_ala', 0.012, 0.949),
#  70: ('sasa_ser', 0.011, 0.938),
#  51: ('sasa_p', 0.011, 0.927),
#  82: ('all_sasa_negative', 0.011, 0.916),
#  108: ('all_sasa_thr', 0.011, 0.905),
#  106: ('all_sasa_arg', 0.011, 0.893),
#  78: ('all_sasa_aromatic', 0.01, 0.883),
#  93: ('all_sasa_f', 0.01, 0.873),
#  69: ('sasa_arg', 0.01, 0.863),
#  76: ('all_sasa_hydrophilic', 0.01, 0.852),
#  105: ('all_sasa_gln', 0.01, 0.842),
#  99: ('all_sasa_his', 0.01, 0.832),
#  39: ('sasa_hydrophilic', 0.01, 0.822),
#  121: ('net_charge_all_around_target_ser_thr', 0.009, 0.813),
#  46: ('sasa_g', 0.009, 0.804),
#  117: ('all_sasa_side_with_whole_target', 0.009, 0.794),
#  104: ('all_sasa_asn', 0.009, 0.785),
#  96: ('all_sasa_asp', 0.009, 0.776),
#  74: ('sasa_tyr', 0.009, 0.766),
#  120: ('sasa_all_with_around_target_ser_thr', 0.009, 0.757),
#  86: ('all_sasa_n', 0.009, 0.748),
#  87: ('all_sasa_l', 0.009, 0.74),
#  56: ('sasa_f', 0.009, 0.731),
#  91: ('all_sasa_d', 0.009, 0.722),
#  140: ('exposed_charge_all_with_around_target_ser_thr', 0.009, 0.713),
#  139: ('exposed_charge_all_around_target_ser_thr', 0.009, 0.705),
#  113: ('all_sasa_back', 0.009, 0.696),
#  103: ('all_sasa_met', 0.009, 0.687),
#  112: ('sasa_back', 0.009, 0.679),
#  84: ('all_sasa_v', 0.008, 0.67),
#  47: ('sasa_v', 0.008, 0.662),
#  81: ('all_sasa_positive', 0.008, 0.654),
#  37: ('number_of_tyr', 0.008, 0.645),
#  138: ('all_atom_negative_charge_all_sidechain_with_around_target_ser_thr',
#   0.008,
#   0.637),
#  155: ('exposed_negative_charge_all_backbone_with_around_target_ser_thr',
#   0.008,
#   0.628),
#  38: ('sasa_hydrophobic', 0.008, 0.62),
#  90: ('all_sasa_b', 0.008, 0.612),
#  129: ('all_atom_positive_charge_all_backbone_around_target_ser_thr',
#   0.008,
#   0.603),
#  115: ('all_sasa_side', 0.008, 0.595),
#  142: ('exposed_charge_all_sidechain_around_target_ser_thr', 0.008, 0.587),
#  101: ('all_sasa_lys', 0.008, 0.579),
#  80: ('all_sasa_charged', 0.008, 0.57),
#  89: ('all_sasa_A', 0.008, 0.562),
#  131: ('all_atom_positive_charge_all_backbone_with_around_target_ser_thr',
#   0.008,
#   0.554),
#  141: ('exposed_charge_all_backbone_around_target_ser_thr', 0.008, 0.546),
#  85: ('all_sasa_s', 0.008, 0.538),
#  97: ('all_sasa_glu', 0.008, 0.53),
#  144: ('exposed_charge_all_sidechain_with_around_target_ser_thr',
#   0.008,
#   0.521),
#  79: ('all_sasa_aliphatic', 0.008, 0.513),
#  148: ('exposed_positive_charge_all_sidechain_around_target_ser_thr',
#   0.008,
#   0.505),
#  109: ('all_sasa_val', 0.008, 0.497),
#  98: ('all_sasa_phe', 0.008, 0.489),
#  125: ('net_charge_all_backbone_with_around_target_ser_thr', 0.008, 0.482),
#  41: ('sasa_aromatic', 0.008, 0.474),
#  95: ('all_sasa_cys', 0.008, 0.466),
#  75: ('all_sasa_hydrophobic', 0.008, 0.458),
#  149: ('exposed_positive_charge_all_backbone_with_around_target_ser_thr',
#   0.008,
#   0.45),
#  143: ('exposed_charge_all_backbone_with_around_target_ser_thr', 0.008, 0.442),
#  114: ('sasa_side', 0.008, 0.435),
#  123: ('net_charge_all_backbone_around_target_ser_thr', 0.008, 0.427),
#  119: ('sasa_all_around_target_ser_thr', 0.008, 0.42),
#  126: ('net_charge_all_sidechain_with_around_target_ser_thr', 0.008, 0.412),
#  146: ('exposed_positive_charge_all_with_around_target_ser_thr', 0.008, 0.404),
#  77: ('all_sasa_polar', 0.008, 0.397),
#  100: ('all_sasa_ile', 0.007, 0.389),
#  145: ('exposed_positive_charge_all_around_target_ser_thr', 0.007, 0.382),
#  151: ('exposed_negative_charge_all_around_target_ser_thr', 0.007, 0.374),
#  132: ('all_atom_positive_charge_all_sidechain_with_around_target_ser_thr',
#   0.007,
#   0.367),
#  111: ('all_sasa_tyr', 0.007, 0.36),
#  133: ('all_atom_negative_charge_all_around_target_ser_thr', 0.007, 0.352),
#  116: ('all_sasa_back_with_whole_target', 0.007, 0.345),
#  153: ('exposed_negative_charge_all_backbone_around_target_ser_thr',
#   0.007,
#   0.338),
#  110: ('all_sasa_trp', 0.007, 0.33),
#  150: ('exposed_positive_charge_all_sidechain_with_around_target_ser_thr',
#   0.007,
#   0.323),
#  137: ('all_atom_negative_charge_all_backbone_with_around_target_ser_thr',
#   0.007,
#   0.316),
#  71: ('sasa_thr', 0.007, 0.308),
#  45: ('sasa_negative', 0.007, 0.301),
#  92: ('all_sasa_e', 0.007, 0.294),
#  102: ('all_sasa_leu', 0.007, 0.287),
#  57: ('sasa_ala', 0.007, 0.28),
#  135: ('all_atom_negative_charge_all_backbone_around_target_ser_thr',
#   0.007,
#   0.273),
#  118: ('sasa_target_ser_thr', 0.007, 0.266),
#  152: ('exposed_negative_charge_all_with_around_target_ser_thr', 0.007, 0.26),
#  147: ('exposed_positive_charge_all_backbone_around_target_ser_thr',
#   0.007,
#   0.253),
#  130: ('all_atom_positive_charge_all_sidechain_around_target_ser_thr',
#   0.007,
#   0.246),
#  136: ('all_atom_negative_charge_all_sidechain_around_target_ser_thr',
#   0.007,
#   0.24),
#  124: ('net_charge_all_sidechain_around_target_ser_thr', 0.006, 0.233),
#  42: ('sasa_aliphatic', 0.006, 0.227),
#  127: ('all_atom_positive_charge_all_around_target_ser_thr', 0.006, 0.22),
#  128: ('all_atom_positive_charge_all_with_around_target_ser_thr',
#   0.006,
#   0.214),
#  122: ('net_charge_all_with_around_target_ser_thr', 0.006, 0.208),
#  68: ('sasa_gln', 0.006, 0.202),
#  154: ('exposed_negative_charge_all_sidechain_around_target_ser_thr',
#   0.006,
#   0.195),
#  134: ('all_atom_negative_charge_all_with_around_target_ser_thr',
#   0.006,
#   0.189),
#  48: ('sasa_s', 0.006, 0.183),
#  43: ('sasa_charged', 0.006, 0.177),
#  10: ('number_of_v', 0.006, 0.171),
#  50: ('sasa_l', 0.006, 0.165),
#  52: ('sasa_A', 0.006, 0.16),
#  49: ('sasa_n', 0.006, 0.154),
#  62: ('sasa_his', 0.005, 0.149),
#  59: ('sasa_asp', 0.005, 0.144),
#  0: ('residue_SER_THR', 0.005, 0.139),
#  64: ('sasa_lys', 0.005, 0.135),
#  14: ('number_of_p', 0.005, 0.13),
#  2: ('number_of_hydrophilic', 0.004, 0.126),
#  9: ('number_of_g', 0.004, 0.121),
#  54: ('sasa_d', 0.004, 0.117),
#  67: ('sasa_asn', 0.004, 0.113),
#  44: ('sasa_positive', 0.004, 0.109),
#  1: ('number_of_hydrophobic', 0.004, 0.105),
#  60: ('sasa_glu', 0.004, 0.101),
#  66: ('sasa_met', 0.004, 0.096),
#  53: ('sasa_b', 0.004, 0.092),
#  4: ('number_of_aromatic', 0.004, 0.088),
#  63: ('sasa_ile', 0.004, 0.085),
#  32: ('number_of_arg', 0.004, 0.081),
#  33: ('number_of_ser', 0.004, 0.077),
#  58: ('sasa_cys', 0.004, 0.074),
#  55: ('sasa_e', 0.004, 0.07),
#  11: ('number_of_s', 0.004, 0.066),
#  40: ('sasa_polar', 0.003, 0.063),
#  19: ('number_of_f', 0.003, 0.06),
#  13: ('number_of_l', 0.003, 0.057),
#  31: ('number_of_gln', 0.003, 0.054),
#  5: ('number_of_aliphatic', 0.003, 0.051)}

# %%
importance = pd.DataFrame(np.zeros((len(x), 3)), columns=['ElasticNet', 'ANOVA', 'RandomForest'], index=x)
for feature in EN_features:
    importance.loc[feature,'ElasticNet'] = 1
for feature in AN_features:
    importance.loc[feature,'ANOVA'] = 1
for feature in RF_features:
    importance.loc[feature,'RandomForest'] = 1
    
importance['Score'] = importance.sum(axis=1)
save_path = './result/important_variables_augmented_cts_cat.csv'
if not exists(save_path):
    importance.to_csv(save_path)
importance_augmented = importance
importance_augmented
# Out:
#                                                     ElasticNet  ANOVA  \
# residue_SER_THR                                            0.0    1.0
# number_of_hydrophobic                                      0.0    0.0
# number_of_hydrophilic                                      0.0    1.0
# number_of_polar                                            1.0    1.0
# number_of_aromatic                                         0.0    1.0
# ...                                                        ...    ...
# exposed_negative_charge_all_around_target_ser_thr          0.0    0.0
# exposed_negative_charge_all_with_around_target_...         0.0    0.0
# exposed_negative_charge_all_backbone_around_tar...         0.0    0.0
# exposed_negative_charge_all_sidechain_around_ta...         0.0    0.0
# exposed_negative_charge_all_backbone_with_aroun...         0.0    0.0
#
#                                                     RandomForest  Score
# residue_SER_THR                                              1.0    2.0
# number_of_hydrophobic                                        1.0    1.0
# number_of_hydrophilic                                        1.0    2.0
# number_of_polar                                              0.0    2.0
# number_of_aromatic                                           1.0    2.0
# ...                                                          ...    ...
# exposed_negative_charge_all_around_target_ser_thr            1.0    1.0
# exposed_negative_charge_all_with_around_target_...           1.0    1.0
# exposed_negative_charge_all_backbone_around_tar...           1.0    1.0
# exposed_negative_charge_all_sidechain_around_ta...           1.0    1.0
# exposed_negative_charge_all_backbone_with_aroun...           1.0    1.0
#
# [156 rows x 4 columns]

# %% [markdown]
# ## both dataset

# %%
data = augmented_data
x = both_x
y = both_y

# ElasticNet
alpha = 0.0001
model = elasticnet(data, x, y, alpha)
EN_features = elastic_coeff(model, x)

# ANOVA
AN_features = anova(data, x, y)

# RandomForest
threshold = 0.95
model = randomforest(data, x, y)
RF_features = FI(model, threshold=threshold)
# Out:
# the number of important features: 98 out of 236
# {'nS/nT_15': 0.596,
#  'sasa_ala': 0.049,
#  'all_sasa_lys': -0.038,
#  'sasa_l': 0.029,
#  'nS/nT_11': 0.027,
#  'number_of_g': -0.026,
#  'sasa_ser': 0.024,
#  'flexibility': -0.024,
#  'side_-1_pro': -0.024,
#  'number_of_asn': -0.019,
#  'nS/nT_8': 0.018,
#  'number_of_ser': 0.017,
#  'sasa_lys': -0.017,
#  'sasa_val': -0.016,
#  'side_2_gly': 0.015,
#  'side_4_gly': 0.014,
#  'nAli_0': -0.012,
#  'net_charge_all_around_target_ser_thr': 0.011,
#  'number_of_negative': -0.011,
#  'Proline': -0.011,
#  'number_of_thr': -0.011,
#  'sasa_cys': -0.011,
#  'nAli_3': 0.011,
#  'nS/nT_5': -0.009,
#  'nS/nT_1': -0.009,
#  'number_of_arg': -0.009,
#  'side_-1_very_small': 0.009,
#  'exposed_charge_all_with_around_target_ser_thr': -0.008,
#  'side_2_None': -0.008,
#  'exposed_positive_charge_all_with_around_target_ser_thr': -0.008,
#  'SS_E': -0.008,
#  'sasa_negative': 0.008,
#  'side_3_very_small': 0.008,
#  'side_2_pro': -0.008,
#  'number_of_leu': -0.008,
#  'number_of_polar': -0.008,
#  'number_of_l': -0.007,
#  'sasa_back': -0.006,
#  'side_5_normal': -0.006,
#  'side_2_very_small': 0.006,
#  'sasa_ile': -0.006,
#  'side_3_small': 0.006,
#  'side_1_very_small': 0.006,
#  'side_5_very_small': 0.006,
#  'all_sasa_cys': -0.006,
#  'side_-1_small': 0.005,
#  'side_3_long': -0.005,
#  'side_4_normal': -0.005,
#  'side_1_pro': -0.005,
#  'all_atom_negative_charge_all_backbone_around_target_ser_thr': 0.005,
#  'all_sasa_phe': -0.005,
#  'side_-1_long': -0.005,
#  'side_2_cycle': -0.005,
#  'number_of_lys': 0.005,
#  'side_-1_normal': -0.005,
#  'residue_SER_THR': -0.005,
#  'nS/nT_10': 0.005,
#  'number_of_charged': -0.005,
#  'sasa_leu': -0.005,
#  'side_3_gly': -0.004,
#  'side_4_very_small': -0.004,
#  'nS/nT_3': -0.004,
#  'nAli_1': -0.004,
#  'SS_H': 0.004,
#  'side_2_small': 0.004,
#  'number_of_e': -0.004,
#  'side_1_normal': -0.004,
#  'phi_psi_beta': -0.003,
#  'sasa_thr': 0.003,
#  'side_3_cycle': -0.003,
#  'all_sasa_v': -0.003,
#  'side_1_small': 0.003,
#  'all_sasa_leu': -0.003,
#  'nPos_3': -0.003,
#  'nS/nT_2': -0.003,
#  'nPos_2': -0.003,
#  'nPos_1': 0.003,
#  'nS/nT_13': -0.003,
#  'side_5_pro': 0.003,
#  'side_1_cycle': -0.003,
#  'side_4_small': 0.003,
#  'SEQ_S': -0.002,
#  'all_sasa_met': -0.002,
#  'side_4_pro': -0.002,
#  'exposed_charge_all_sidechain_with_around_target_ser_thr': -0.002,
#  'sasa_phe': -0.002,
#  'nS/nT_9': 0.002,
#  'nS/nT_7': -0.002,
#  'side_5_small': 0.002,
#  'side_5_long': -0.002,
#  'side_5_cycle': -0.001,
#  'nAli_2': 0.001,
#  'side_2_long': -0.001,
#  'side_3_pro': 0.001,
#  'sasa_gln': 0.001,
#  'phi_psi_other': 0.001,
#  'sasa_asp': 0.001,
#  'nS/nT_6': 0.001}
# 1th iteration
# 2th iteration
# 3th iteration
# 4th iteration
# 5th iteration
# the number of important features: 48 out of 236
#
# order variables by their importance
# {18: 'nS/nT_15',
#  39: 'side_-1_very_small',
#  38: 'side_-1_small',
#  2: 'SEQ_S',
#  115: 'number_of_val',
#  3: 'SEQ_T',
#  113: 'number_of_ser',
#  88: 'number_of_negative',
#  100: 'number_of_ala',
#  95: 'number_of_A',
#  108: 'number_of_leu',
#  91: 'number_of_s',
#  98: 'number_of_e',
#  107: 'number_of_lys',
#  111: 'number_of_gln',
#  86: 'number_of_charged',
#  200: 'sasa_all_with_around_target_ser_thr',
#  206: 'net_charge_all_sidechain_with_around_target_ser_thr',
#  208: 'all_atom_positive_charge_all_with_around_target_ser_thr',
#  209: 'all_atom_positive_charge_all_backbone_around_target_ser_thr',
#  207: 'all_atom_positive_charge_all_around_target_ser_thr',
#  202: 'net_charge_all_with_around_target_ser_thr',
#  203: 'net_charge_all_backbone_around_target_ser_thr',
#  204: 'net_charge_all_sidechain_around_target_ser_thr',
#  201: 'net_charge_all_around_target_ser_thr',
#  205: 'net_charge_all_backbone_with_around_target_ser_thr',
#  211: 'all_atom_positive_charge_all_backbone_with_around_target_ser_thr',
#  50: 'side_2_gly',
#  210: 'all_atom_positive_charge_all_sidechain_around_target_ser_thr',
#  92: 'number_of_n',
#  89: 'number_of_g',
#  81: 'number_of_hydrophobic',
#  82: 'number_of_hydrophilic',
#  80: 'residue_SER_THR',
#  105: 'number_of_his',
#  94: 'number_of_p',
#  106: 'number_of_ile',
#  97: 'number_of_d',
#  87: 'number_of_positive',
#  96: 'number_of_b',
#  93: 'number_of_l',
#  112: 'number_of_arg',
#  116: 'number_of_trp',
#  84: 'number_of_aromatic',
#  90: 'number_of_v',
#  103: 'number_of_glu',
#  66: 'side_4_gly',
#  14: 'nS/nT_11'}
# the number of important features (threshold=0.95): 167 out of 236
# {187: ('all_sasa_ser', 0.012, 0.988),
#  168: ('all_sasa_p', 0.011, 0.977),
#  163: ('all_sasa_g', 0.011, 0.965),
#  131: ('sasa_p', 0.011, 0.955),
#  174: ('all_sasa_ala', 0.01, 0.944),
#  186: ('all_sasa_arg', 0.01, 0.934),
#  150: ('sasa_ser', 0.01, 0.924),
#  162: ('all_sasa_negative', 0.01, 0.914),
#  185: ('all_sasa_gln', 0.01, 0.905),
#  173: ('all_sasa_f', 0.01, 0.895),
#  126: ('sasa_g', 0.009, 0.886),
#  1: ('flexibility', 0.009, 0.877),
#  156: ('all_sasa_hydrophilic', 0.009, 0.868),
#  119: ('sasa_hydrophilic', 0.009, 0.859),
#  188: ('all_sasa_thr', 0.009, 0.85),
#  155: ('all_sasa_hydrophobic', 0.009, 0.841),
#  149: ('sasa_arg', 0.009, 0.832),
#  179: ('all_sasa_his', 0.009, 0.823),
#  184: ('all_sasa_asn', 0.009, 0.815),
#  197: ('all_sasa_side_with_whole_target', 0.008, 0.806),
#  176: ('all_sasa_asp', 0.008, 0.798),
#  158: ('all_sasa_aromatic', 0.008, 0.789),
#  166: ('all_sasa_n', 0.008, 0.781),
#  171: ('all_sasa_d', 0.008, 0.773),
#  169: ('all_sasa_A', 0.008, 0.764),
#  154: ('sasa_tyr', 0.008, 0.756),
#  160: ('all_sasa_charged', 0.008, 0.748),
#  209: ('all_atom_positive_charge_all_backbone_around_target_ser_thr',
#   0.008,
#   0.74),
#  159: ('all_sasa_aliphatic', 0.008, 0.732),
#  201: ('net_charge_all_around_target_ser_thr', 0.008, 0.724),
#  211: ('all_atom_positive_charge_all_backbone_with_around_target_ser_thr',
#   0.008,
#   0.716),
#  118: ('sasa_hydrophobic', 0.008, 0.708),
#  195: ('all_sasa_side', 0.008, 0.7),
#  200: ('sasa_all_with_around_target_ser_thr', 0.008, 0.692),
#  218: ('all_atom_negative_charge_all_sidechain_with_around_target_ser_thr',
#   0.008,
#   0.684),
#  192: ('sasa_back', 0.008, 0.677),
#  127: ('sasa_v', 0.008, 0.669),
#  165: ('all_sasa_s', 0.008, 0.661),
#  205: ('net_charge_all_backbone_with_around_target_ser_thr', 0.008, 0.653),
#  175: ('all_sasa_cys', 0.008, 0.646),
#  193: ('all_sasa_back', 0.008, 0.638),
#  121: ('sasa_aromatic', 0.008, 0.63),
#  235: ('exposed_negative_charge_all_backbone_with_around_target_ser_thr',
#   0.008,
#   0.623),
#  220: ('exposed_charge_all_with_around_target_ser_thr', 0.008, 0.615),
#  164: ('all_sasa_v', 0.008, 0.608),
#  181: ('all_sasa_lys', 0.008, 0.6),
#  231: ('exposed_negative_charge_all_around_target_ser_thr', 0.008, 0.593),
#  167: ('all_sasa_l', 0.007, 0.585),
#  170: ('all_sasa_b', 0.007, 0.578),
#  199: ('sasa_all_around_target_ser_thr', 0.007, 0.57),
#  222: ('exposed_charge_all_sidechain_around_target_ser_thr', 0.007, 0.563),
#  136: ('sasa_f', 0.007, 0.556),
#  224: ('exposed_charge_all_sidechain_with_around_target_ser_thr',
#   0.007,
#   0.548),
#  221: ('exposed_charge_all_backbone_around_target_ser_thr', 0.007, 0.541),
#  196: ('all_sasa_back_with_whole_target', 0.007, 0.534),
#  228: ('exposed_positive_charge_all_sidechain_around_target_ser_thr',
#   0.007,
#   0.526),
#  219: ('exposed_charge_all_around_target_ser_thr', 0.007, 0.519),
#  161: ('all_sasa_positive', 0.007, 0.512),
#  226: ('exposed_positive_charge_all_with_around_target_ser_thr', 0.007, 0.504),
#  217: ('all_atom_negative_charge_all_backbone_with_around_target_ser_thr',
#   0.007,
#   0.497),
#  223: ('exposed_charge_all_backbone_with_around_target_ser_thr', 0.007, 0.49),
#  229: ('exposed_positive_charge_all_backbone_with_around_target_ser_thr',
#   0.007,
#   0.483),
#  191: ('all_sasa_tyr', 0.007, 0.476),
#  178: ('all_sasa_phe', 0.007, 0.468),
#  183: ('all_sasa_met', 0.007, 0.461),
#  233: ('exposed_negative_charge_all_backbone_around_target_ser_thr',
#   0.007,
#   0.454),
#  212: ('all_atom_positive_charge_all_sidechain_with_around_target_ser_thr',
#   0.007,
#   0.447),
#  194: ('sasa_side', 0.007, 0.44),
#  227: ('exposed_positive_charge_all_backbone_around_target_ser_thr',
#   0.007,
#   0.433),
#  213: ('all_atom_negative_charge_all_around_target_ser_thr', 0.007, 0.426),
#  125: ('sasa_negative', 0.007, 0.419),
#  198: ('sasa_target_ser_thr', 0.007, 0.412),
#  203: ('net_charge_all_backbone_around_target_ser_thr', 0.007, 0.405),
#  206: ('net_charge_all_sidechain_with_around_target_ser_thr', 0.007, 0.398),
#  189: ('all_sasa_val', 0.007, 0.391),
#  215: ('all_atom_negative_charge_all_backbone_around_target_ser_thr',
#   0.007,
#   0.384),
#  225: ('exposed_positive_charge_all_around_target_ser_thr', 0.007, 0.377),
#  177: ('all_sasa_glu', 0.007, 0.37),
#  190: ('all_sasa_trp', 0.007, 0.364),
#  117: ('number_of_tyr', 0.007, 0.357),
#  182: ('all_sasa_leu', 0.007, 0.35),
#  180: ('all_sasa_ile', 0.007, 0.344),
#  210: ('all_atom_positive_charge_all_sidechain_around_target_ser_thr',
#   0.006,
#   0.337),
#  230: ('exposed_positive_charge_all_sidechain_with_around_target_ser_thr',
#   0.006,
#   0.331),
#  172: ('all_sasa_e', 0.006, 0.324),
#  204: ('net_charge_all_sidechain_around_target_ser_thr', 0.006, 0.318),
#  151: ('sasa_thr', 0.006, 0.312),
#  157: ('all_sasa_polar', 0.006, 0.306),
#  137: ('sasa_ala', 0.006, 0.3),
#  214: ('all_atom_negative_charge_all_with_around_target_ser_thr',
#   0.006,
#   0.294),
#  207: ('all_atom_positive_charge_all_around_target_ser_thr', 0.006, 0.288),
#  130: ('sasa_l', 0.006, 0.282),
#  129: ('sasa_n', 0.006, 0.276),
#  148: ('sasa_gln', 0.006, 0.27),
#  122: ('sasa_aliphatic', 0.006, 0.264),
#  202: ('net_charge_all_with_around_target_ser_thr', 0.006, 0.258),
#  234: ('exposed_negative_charge_all_sidechain_around_target_ser_thr',
#   0.006,
#   0.253),
#  216: ('all_atom_negative_charge_all_sidechain_around_target_ser_thr',
#   0.006,
#   0.247),
#  232: ('exposed_negative_charge_all_with_around_target_ser_thr', 0.005, 0.241),
#  208: ('all_atom_positive_charge_all_with_around_target_ser_thr',
#   0.005,
#   0.236),
#  128: ('sasa_s', 0.005, 0.231),
#  123: ('sasa_charged', 0.005, 0.225),
#  90: ('number_of_v', 0.005, 0.22),
#  132: ('sasa_A', 0.005, 0.215),
#  142: ('sasa_his', 0.005, 0.21),
#  139: ('sasa_asp', 0.005, 0.206),
#  124: ('sasa_positive', 0.004, 0.201),
#  18: ('nS/nT_15', 0.004, 0.197),
#  84: ('number_of_aromatic', 0.004, 0.193),
#  147: ('sasa_asn', 0.004, 0.189),
#  82: ('number_of_hydrophilic', 0.004, 0.185),
#  144: ('sasa_lys', 0.004, 0.18),
#  134: ('sasa_d', 0.004, 0.177),
#  80: ('residue_SER_THR', 0.004, 0.173),
#  94: ('number_of_p', 0.004, 0.169),
#  133: ('sasa_b', 0.004, 0.165),
#  113: ('number_of_ser', 0.004, 0.162),
#  89: ('number_of_g', 0.004, 0.158),
#  81: ('number_of_hydrophobic', 0.004, 0.155),
#  146: ('sasa_met', 0.004, 0.151),
#  91: ('number_of_s', 0.004, 0.148),
#  143: ('sasa_ile', 0.003, 0.144),
#  140: ('sasa_glu', 0.003, 0.141),
#  107: ('number_of_lys', 0.003, 0.138),
#  120: ('sasa_polar', 0.003, 0.135),
#  112: ('number_of_arg', 0.003, 0.132),
#  138: ('sasa_cys', 0.003, 0.128),
#  111: ('number_of_gln', 0.003, 0.125),
#  85: ('number_of_aliphatic', 0.003, 0.122),
#  135: ('sasa_e', 0.003, 0.119),
#  99: ('number_of_f', 0.003, 0.117),
#  95: ('number_of_A', 0.003, 0.114),
#  93: ('number_of_l', 0.003, 0.111),
#  100: ('number_of_ala', 0.003, 0.108),
#  88: ('number_of_negative', 0.003, 0.106),
#  114: ('number_of_thr', 0.002, 0.103),
#  86: ('number_of_charged', 0.002, 0.101),
#  153: ('sasa_trp', 0.002, 0.099),
#  96: ('number_of_b', 0.002, 0.096),
#  92: ('number_of_n', 0.002, 0.094),
#  11: ('nS/nT_8', 0.002, 0.092),
#  141: ('sasa_phe', 0.002, 0.09),
#  102: ('number_of_asp', 0.002, 0.088),
#  105: ('number_of_his', 0.002, 0.086),
#  87: ('number_of_positive', 0.002, 0.084),
#  110: ('number_of_asn', 0.002, 0.082),
#  109: ('number_of_met', 0.002, 0.08),
#  97: ('number_of_d', 0.002, 0.078),
#  106: ('number_of_ile', 0.002, 0.076),
#  66: ('side_4_gly', 0.002, 0.075),
#  39: ('side_-1_very_small', 0.002, 0.073),
#  145: ('sasa_leu', 0.002, 0.072),
#  83: ('number_of_polar', 0.002, 0.07),
#  98: ('number_of_e', 0.002, 0.068),
#  22: ('nAli_3', 0.001, 0.067),
#  50: ('side_2_gly', 0.001, 0.066),
#  61: ('side_3_pro', 0.001, 0.064),
#  21: ('nAli_2', 0.001, 0.063),
#  47: ('side_1_very_small', 0.001, 0.061),
#  77: ('side_5_pro', 0.001, 0.06),
#  101: ('number_of_cys', 0.001, 0.059),
#  7: ('nS/nT_4', 0.001, 0.057),
#  79: ('side_5_very_small', 0.001, 0.056),
#  9: ('nS/nT_6', 0.001, 0.055),
#  29: ('phi_psi_other', 0.001, 0.054),
#  38: ('side_-1_small', 0.001, 0.052),
#  152: ('sasa_val', 0.001, 0.051)}

# %%
importance = pd.DataFrame(np.zeros((len(x), 3)), columns=['ElasticNet', 'ANOVA', 'RandomForest'], index=x)
for feature in EN_features:
    importance.loc[feature,'ElasticNet'] = 1
for feature in AN_features:
    importance.loc[feature,'ANOVA'] = 1
for feature in RF_features:
    importance.loc[feature,'RandomForest'] = 1
    
importance['Score'] = importance.sum(axis=1)
save_path = './result/important_variables_both_cts_cat.csv'
if not exists(save_path):
    importance.to_csv(save_path)
importance_both = importance
importance_both
# Out:
#                                                     ElasticNet  ANOVA  \
# Proline                                                    1.0    0.0
# flexibility                                                1.0    0.0
# SEQ_S                                                      1.0    1.0
# SEQ_T                                                      0.0    1.0
# nS/nT_1                                                    1.0    0.0
# ...                                                        ...    ...
# exposed_negative_charge_all_around_target_ser_thr          0.0    0.0
# exposed_negative_charge_all_with_around_target_...         0.0    0.0
# exposed_negative_charge_all_backbone_around_tar...         0.0    0.0
# exposed_negative_charge_all_sidechain_around_ta...         0.0    0.0
# exposed_negative_charge_all_backbone_with_aroun...         0.0    0.0
#
#                                                     RandomForest  Score
# Proline                                                      0.0    1.0
# flexibility                                                  1.0    2.0
# SEQ_S                                                        0.0    2.0
# SEQ_T                                                        0.0    1.0
# nS/nT_1                                                      0.0    1.0
# ...                                                          ...    ...
# exposed_negative_charge_all_around_target_ser_thr            1.0    1.0
# exposed_negative_charge_all_with_around_target_...           1.0    1.0
# exposed_negative_charge_all_backbone_around_tar...           1.0    1.0
# exposed_negative_charge_all_sidechain_around_ta...           1.0    1.0
# exposed_negative_charge_all_backbone_with_aroun...           1.0    1.0
#
# [236 rows x 4 columns]
