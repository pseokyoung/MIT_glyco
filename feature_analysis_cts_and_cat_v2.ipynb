# %% [markdown]
# # Header

# %%
import numpy as np
import pandas as pd
import scipy as sp
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from os.path import exists
from src.Data import *
from src.Preprocessing import *
variables = xy_variables()

# %% [markdown]
# ## original dataset

# %%
load_path = f"./data/data_for_ml.csv"
original_data = pd.read_csv(load_path)
original_data = original_data[(original_data['SEQ']=='S') | (original_data['SEQ']=='T')]

x_cts   = variables.x_cts_window
x_cat   = variables.x_cat_window
y_label = variables.y_label

data_x, data_y = df_to_dummy(original_data, x_cts, x_cat, y_label)
original_data = pd.concat([data_x, data_y], axis=1)
original_features = dict(
    zip(range(0, len(original_data.columns)), original_data.columns)
)

display(original_features)
# Out:
# dummy x shape: (41264, 87)
# dummy y shape: (41264, 1)
# {0: 'Proline',
#  1: 'flexibility',
#  2: 'SEQ_S',
#  3: 'SEQ_T',
#  4: 'nS/nT_1',
#  5: 'nS/nT_2',
#  6: 'nS/nT_3',
#  7: 'nS/nT_4',
#  8: 'nS/nT_5',
#  9: 'nS/nT_6',
#  10: 'nS/nT_7',
#  11: 'nS/nT_8',
#  12: 'nS/nT_9',
#  13: 'nS/nT_10',
#  14: 'nS/nT_11',
#  15: 'nS/nT_12',
#  16: 'nS/nT_13',
#  17: 'nS/nT_14',
#  18: 'nS/nT_15',
#  19: 'nS/nT_16',
#  20: 'nS/nT_17',
#  21: 'nS/nT_18',
#  22: 'nS/nT_19',
#  23: 'nS/nT_20',
#  24: 'nS/nT_21',
#  25: 'nAli_0',
#  26: 'nAli_1',
#  27: 'nAli_2',
#  28: 'nAli_3',
#  29: 'nPos_0',
#  30: 'nPos_1',
#  31: 'nPos_2',
#  32: 'nPos_3',
#  33: 'phi_psi_alpha',
#  34: 'phi_psi_beta',
#  35: 'phi_psi_other',
#  36: 'SS_C',
#  37: 'SS_E',
#  38: 'SS_H',
#  39: 'side_-1_None',
#  40: 'side_-1_cycle',
#  41: 'side_-1_gly',
#  42: 'side_-1_long',
#  43: 'side_-1_normal',
#  44: 'side_-1_pro',
#  45: 'side_-1_small',
#  46: 'side_-1_very_small',
#  47: 'side_1_None',
#  48: 'side_1_cycle',
#  49: 'side_1_gly',
#  50: 'side_1_long',
#  51: 'side_1_normal',
#  52: 'side_1_pro',
#  53: 'side_1_small',
#  54: 'side_1_very_small',
#  55: 'side_2_None',
#  56: 'side_2_cycle',
#  57: 'side_2_gly',
#  58: 'side_2_long',
#  59: 'side_2_normal',
#  60: 'side_2_pro',
#  61: 'side_2_small',
#  62: 'side_2_very_small',
#  63: 'side_3_None',
#  64: 'side_3_cycle',
#  65: 'side_3_gly',
#  66: 'side_3_long',
#  67: 'side_3_normal',
#  68: 'side_3_pro',
#  69: 'side_3_small',
#  70: 'side_3_very_small',
#  71: 'side_4_None',
#  72: 'side_4_cycle',
#  73: 'side_4_gly',
#  74: 'side_4_long',
#  75: 'side_4_normal',
#  76: 'side_4_pro',
#  77: 'side_4_small',
#  78: 'side_4_very_small',
#  79: 'side_5_None',
#  80: 'side_5_cycle',
#  81: 'side_5_gly',
#  82: 'side_5_long',
#  83: 'side_5_normal',
#  84: 'side_5_pro',
#  85: 'side_5_small',
#  86: 'side_5_very_small',
#  87: 'positivity'}

# %%
original_x = list(original_data.columns[:-1])
original_y = original_data.columns[-1]

# %% [markdown]
# ## augmented dataset

# %%
load_name = "./data/data_for_ml.csv"
protein_list = list(pd.read_csv(load_name).protein.unique())
protein_augmented = [name for name in protein_list if exists(f'./data/data_for_ml(augmented)/{name}.csv')]

augmented_data = []
for name in protein_augmented:
    load_path = f'./data/data_for_ml(augmented)/{name}.csv'
    augmented_data.append(pd.read_csv(load_path))
augmented_data = pd.concat(augmented_data, axis=0).reset_index(drop=True)
augmented_data = augmented_data[(augmented_data['SEQ']=='S') | (augmented_data['SEQ']=='T')].reset_index(drop=True)

x_charge = pd.read_csv('./data/from_Krishna/features-all-names.csv').name.to_list()[1:-1]
x_cts   = variables.x_cts_window + x_charge[38:]
x_cat   = variables.x_cat_window + x_charge[:38]
y_label = variables.y_label

data_x, data_y = df_to_dummy(augmented_data, x_cts, x_cat, y_label)
augmented_data = pd.concat([data_x, data_y], axis=1)

augmented_features = dict(
    zip(range(0, len(augmented_data.columns)), augmented_data.columns)
)
display(augmented_features)
# Out:
# dummy x shape: (8910, 9307)
# dummy y shape: (8910, 1)
# {0: 'Proline',
#  1: 'flexibility',
#  2: 'sasa_hydrophobic',
#  3: 'sasa_hydrophilic',
#  4: 'sasa_polar',
#  5: 'sasa_aromatic',
#  6: 'sasa_aliphatic',
#  7: 'sasa_charged',
#  8: 'sasa_positive',
#  9: 'sasa_negative',
#  10: 'sasa_g',
#  11: 'sasa_v',
#  12: 'sasa_s',
#  13: 'sasa_n',
#  14: 'sasa_l',
#  15: 'sasa_p',
#  16: 'sasa_A',
#  17: 'sasa_b',
#  18: 'sasa_d',
#  19: 'sasa_e',
#  20: 'sasa_f',
#  21: 'sasa_ala',
#  22: 'sasa_cys',
#  23: 'sasa_asp',
#  24: 'sasa_glu',
#  25: 'sasa_phe',
#  26: 'sasa_his',
#  27: 'sasa_ile',
#  28: 'sasa_lys',
#  29: 'sasa_leu',
#  30: 'sasa_met',
#  31: 'sasa_asn',
#  32: 'sasa_gln',
#  33: 'sasa_arg',
#  34: 'sasa_ser',
#  35: 'sasa_thr',
#  36: 'sasa_val',
#  37: 'sasa_trp',
#  38: 'sasa_tyr',
#  39: 'all_sasa_hydrophobic',
#  40: 'all_sasa_hydrophilic',
#  41: 'all_sasa_polar',
#  42: 'all_sasa_aromatic',
#  43: 'all_sasa_aliphatic',
#  44: 'all_sasa_charged',
#  45: 'all_sasa_positive',
#  46: 'all_sasa_negative',
#  47: 'all_sasa_g',
#  48: 'all_sasa_v',
#  49: 'all_sasa_s',
#  50: 'all_sasa_n',
#  51: 'all_sasa_l',
#  52: 'all_sasa_p',
#  53: 'all_sasa_A',
#  54: 'all_sasa_b',
#  55: 'all_sasa_d',
#  56: 'all_sasa_e',
#  57: 'all_sasa_f',
#  58: 'all_sasa_ala',
#  59: 'all_sasa_cys',
#  60: 'all_sasa_asp',
#  61: 'all_sasa_glu',
#  62: 'all_sasa_phe',
#  63: 'all_sasa_his',
#  64: 'all_sasa_ile',
#  65: 'all_sasa_lys',
#  66: 'all_sasa_leu',
#  67: 'all_sasa_met',
#  68: 'all_sasa_asn',
#  69: 'all_sasa_gln',
#  70: 'all_sasa_arg',
#  71: 'all_sasa_ser',
#  72: 'all_sasa_thr',
#  73: 'all_sasa_val',
#  74: 'all_sasa_trp',
#  75: 'all_sasa_tyr',
#  76: 'sasa_back',
#  77: 'all_sasa_back',
#  78: 'sasa_side',
#  79: 'all_sasa_side',
#  80: 'all_sasa_back_with_whole_target',
#  81: 'all_sasa_side_with_whole_target',
#  82: 'sasa_target_ser_thr',
#  83: 'sasa_all_around_target_ser_thr',
#  84: 'sasa_all_with_around_target_ser_thr',
#  85: 'net_charge_all_around_target_ser_thr',
#  86: 'net_charge_all_with_around_target_ser_thr',
#  87: 'net_charge_all_backbone_around_target_ser_thr',
#  88: 'net_charge_all_sidechain_around_target_ser_thr',
#  89: 'net_charge_all_backbone_with_around_target_ser_thr',
#  90: 'net_charge_all_sidechain_with_around_target_ser_thr',
#  91: 'all_atom_positive_charge_all_around_target_ser_thr',
#  92: 'all_atom_positive_charge_all_with_around_target_ser_thr',
#  93: 'all_atom_positive_charge_all_backbone_around_target_ser_thr',
#  94: 'all_atom_positive_charge_all_sidechain_around_target_ser_thr',
#  95: 'all_atom_positive_charge_all_backbone_with_around_target_ser_thr',
#  96: 'all_atom_positive_charge_all_sidechain_with_around_target_ser_thr',
#  97: 'all_atom_negative_charge_all_around_target_ser_thr',
#  98: 'all_atom_negative_charge_all_with_around_target_ser_thr',
#  99: 'all_atom_negative_charge_all_backbone_around_target_ser_thr',
#  100: 'all_atom_negative_charge_all_sidechain_around_target_ser_thr',
#  101: 'all_atom_negative_charge_all_backbone_with_around_target_ser_thr',
#  102: 'all_atom_negative_charge_all_sidechain_with_around_target_ser_thr',
#  103: 'exposed_charge_all_around_target_ser_thr',
#  104: 'exposed_charge_all_with_around_target_ser_thr',
#  105: 'exposed_charge_all_backbone_around_target_ser_thr',
#  106: 'exposed_charge_all_sidechain_around_target_ser_thr',
#  107: 'exposed_charge_all_backbone_with_around_target_ser_thr',
#  108: 'exposed_charge_all_sidechain_with_around_target_ser_thr',
#  109: 'exposed_positive_charge_all_around_target_ser_thr',
#  110: 'exposed_positive_charge_all_with_around_target_ser_thr',
#  111: 'exposed_positive_charge_all_backbone_around_target_ser_thr',
#  112: 'exposed_positive_charge_all_sidechain_around_target_ser_thr',
#  113: 'exposed_positive_charge_all_backbone_with_around_target_ser_thr',
#  114: 'exposed_positive_charge_all_sidechain_with_around_target_ser_thr',
#  115: 'exposed_negative_charge_all_around_target_ser_thr',
#  116: 'exposed_negative_charge_all_with_around_target_ser_thr',
#  117: 'exposed_negative_charge_all_backbone_around_target_ser_thr',
#  118: 'exposed_negative_charge_all_sidechain_around_target_ser_thr',
#  119: 'exposed_negative_charge_all_backbone_with_around_target_ser_thr',
#  120: 'SEQ_S',
#  121: 'SEQ_T',
#  122: 'nS/nT_1',
#  123: 'nS/nT_2',
#  124: 'nS/nT_3',
#  125: 'nS/nT_4',
#  126: 'nS/nT_5',
#  127: 'nS/nT_6',
#  128: 'nS/nT_7',
#  129: 'nS/nT_8',
#  130: 'nS/nT_9',
#  131: 'nS/nT_10',
#  132: 'nS/nT_11',
#  133: 'nS/nT_12',
#  134: 'nS/nT_13',
#  135: 'nS/nT_14',
#  136: 'nS/nT_15',
#  137: 'nAli_0',
#  138: 'nAli_1',
#  139: 'nAli_2',
#  140: 'nAli_3',
#  141: 'nPos_0',
#  142: 'nPos_1',
#  143: 'nPos_2',
#  144: 'nPos_3',
#  145: 'phi_psi_alpha',
#  146: 'phi_psi_beta',
#  147: 'phi_psi_other',
#  148: 'SS_C',
#  149: 'SS_E',
#  150: 'SS_H',
#  151: 'side_-1_cycle',
#  152: 'side_-1_gly',
#  153: 'side_-1_long',
#  154: 'side_-1_normal',
#  155: 'side_-1_pro',
#  156: 'side_-1_small',
#  157: 'side_-1_very_small',
#  158: 'side_1_None',
#  159: 'side_1_cycle',
#  160: 'side_1_gly',
#  161: 'side_1_long',
#  162: 'side_1_normal',
#  163: 'side_1_pro',
#  164: 'side_1_small',
#  165: 'side_1_very_small',
#  166: 'side_2_None',
#  167: 'side_2_cycle',
#  168: 'side_2_gly',
#  169: 'side_2_long',
#  170: 'side_2_normal',
#  171: 'side_2_pro',
#  172: 'side_2_small',
#  173: 'side_2_very_small',
#  174: 'side_3_None',
#  175: 'side_3_cycle',
#  176: 'side_3_gly',
#  177: 'side_3_long',
#  178: 'side_3_normal',
#  179: 'side_3_pro',
#  180: 'side_3_small',
#  181: 'side_3_very_small',
#  182: 'side_4_None',
#  183: 'side_4_cycle',
#  184: 'side_4_gly',
#  185: 'side_4_long',
#  186: 'side_4_normal',
#  187: 'side_4_pro',
#  188: 'side_4_small',
#  189: 'side_4_very_small',
#  190: 'side_5_None',
#  191: 'side_5_cycle',
#  192: 'side_5_gly',
#  193: 'side_5_long',
#  194: 'side_5_normal',
#  195: 'side_5_pro',
#  196: 'side_5_small',
#  197: 'side_5_very_small',
#  198: 'residue_SER_THR_0',
#  199: 'residue_SER_THR_1',
#  200: 'residue_SER_THR_2',
#  201: 'residue_SER_THR_3',
#  202: 'residue_SER_THR_4',
#  203: 'residue_SER_THR_5',
#  204: 'residue_SER_THR_6',
#  205: 'residue_SER_THR_7',
#  206: 'residue_SER_THR_8',
#  207: 'residue_SER_THR_9',
#  208: 'residue_SER_THR_10',
#  209: 'residue_SER_THR_11',
#  210: 'residue_SER_THR_12',
#  211: 'residue_SER_THR_13',
#  212: 'residue_SER_THR_14',
#  213: 'residue_SER_THR_15',
#  214: 'residue_SER_THR_16',
#  215: 'residue_SER_THR_17',
#  216: 'residue_SER_THR_18',
#  217: 'residue_SER_THR_19',
#  218: 'residue_SER_THR_20',
#  219: 'residue_SER_THR_21',
#  220: 'residue_SER_THR_22',
#  221: 'residue_SER_THR_23',
#  222: 'residue_SER_THR_24',
#  223: 'residue_SER_THR_25',
#  224: 'residue_SER_THR_26',
#  225: 'residue_SER_THR_27',
#  226: 'residue_SER_THR_28',
#  227: 'residue_SER_THR_29',
#  228: 'residue_SER_THR_30',
#  229: 'residue_SER_THR_31',
#  230: 'residue_SER_THR_32',
#  231: 'residue_SER_THR_33',
#  232: 'residue_SER_THR_34',
#  233: 'residue_SER_THR_35',
#  234: 'residue_SER_THR_36',
#  235: 'residue_SER_THR_37',
#  236: 'residue_SER_THR_38',
#  237: 'residue_SER_THR_39',
#  238: 'residue_SER_THR_40',
#  239: 'residue_SER_THR_41',
#  240: 'residue_SER_THR_42',
#  241: 'residue_SER_THR_43',
#  242: 'residue_SER_THR_44',
#  243: 'residue_SER_THR_47',
#  244: 'residue_SER_THR_48',
#  245: 'number_of_hydrophobic_0',
#  246: 'number_of_hydrophobic_1',
#  247: 'number_of_hydrophobic_2',
#  248: 'number_of_hydrophobic_3',
#  249: 'number_of_hydrophobic_4',
#  250: 'number_of_hydrophobic_5',
#  251: 'number_of_hydrophobic_6',
#  252: 'number_of_hydrophobic_7',
#  253: 'number_of_hydrophobic_8',
#  254: 'number_of_hydrophobic_9',
#  255: 'number_of_hydrophobic_10',
#  256: 'number_of_hydrophobic_11',
#  257: 'number_of_hydrophobic_12',
#  258: 'number_of_hydrophobic_13',
#  259: 'number_of_hydrophobic_14',
#  260: 'number_of_hydrophobic_15',
#  261: 'number_of_hydrophobic_16',
#  262: 'number_of_hydrophobic_17',
#  263: 'number_of_hydrophobic_18',
#  264: 'number_of_hydrophobic_19',
#  265: 'number_of_hydrophobic_20',
#  266: 'number_of_hydrophobic_21',
#  267: 'number_of_hydrophobic_22',
#  268: 'number_of_hydrophobic_23',
#  269: 'number_of_hydrophobic_24',
#  270: 'number_of_hydrophobic_25',
#  271: 'number_of_hydrophobic_26',
#  272: 'number_of_hydrophobic_27',
#  273: 'number_of_hydrophobic_28',
#  274: 'number_of_hydrophobic_29',
#  275: 'number_of_hydrophobic_30',
#  276: 'number_of_hydrophobic_31',
#  277: 'number_of_hydrophobic_32',
#  278: 'number_of_hydrophobic_33',
#  279: 'number_of_hydrophobic_34',
#  280: 'number_of_hydrophobic_35',
#  281: 'number_of_hydrophobic_36',
#  282: 'number_of_hydrophobic_37',
#  283: 'number_of_hydrophobic_38',
#  284: 'number_of_hydrophobic_39',
#  285: 'number_of_hydrophobic_40',
#  286: 'number_of_hydrophilic_0',
#  287: 'number_of_hydrophilic_1',
#  288: 'number_of_hydrophilic_2',
#  289: 'number_of_hydrophilic_3',
#  290: 'number_of_hydrophilic_4',
#  291: 'number_of_hydrophilic_5',
#  292: 'number_of_hydrophilic_6',
#  293: 'number_of_hydrophilic_7',
#  294: 'number_of_hydrophilic_8',
#  295: 'number_of_hydrophilic_9',
#  296: 'number_of_hydrophilic_10',
#  297: 'number_of_hydrophilic_11',
#  298: 'number_of_hydrophilic_12',
#  299: 'number_of_hydrophilic_13',
#  300: 'number_of_hydrophilic_14',
#  301: 'number_of_hydrophilic_15',
#  302: 'number_of_hydrophilic_16',
#  303: 'number_of_hydrophilic_17',
#  304: 'number_of_hydrophilic_18',
#  305: 'number_of_hydrophilic_19',
#  306: 'number_of_hydrophilic_20',
#  307: 'number_of_hydrophilic_21',
#  308: 'number_of_hydrophilic_22',
#  309: 'number_of_hydrophilic_23',
#  310: 'number_of_hydrophilic_24',
#  311: 'number_of_hydrophilic_25',
#  312: 'number_of_polar_0',
#  313: 'number_of_polar_1',
#  314: 'number_of_polar_2',
#  315: 'number_of_polar_3',
#  316: 'number_of_polar_4',
#  317: 'number_of_polar_5',
#  318: 'number_of_polar_6',
#  319: 'number_of_polar_7',
#  320: 'number_of_polar_8',
#  321: 'number_of_polar_9',
#  322: 'number_of_polar_10',
#  323: 'number_of_polar_11',
#  324: 'number_of_polar_12',
#  325: 'number_of_polar_13',
#  326: 'number_of_polar_14',
#  327: 'number_of_polar_15',
#  328: 'number_of_polar_16',
#  329: 'number_of_polar_17',
#  330: 'number_of_aromatic_0',
#  331: 'number_of_aromatic_1',
#  332: 'number_of_aromatic_2',
#  333: 'number_of_aromatic_3',
#  334: 'number_of_aromatic_4',
#  335: 'number_of_aromatic_5',
#  336: 'number_of_aromatic_6',
#  337: 'number_of_aromatic_7',
#  338: 'number_of_aromatic_8',
#  339: 'number_of_aromatic_9',
#  340: 'number_of_aromatic_10',
#  341: 'number_of_aromatic_11',
#  342: 'number_of_aromatic_12',
#  343: 'number_of_aromatic_13',
#  344: 'number_of_aromatic_14',
#  345: 'number_of_aromatic_15',
#  346: 'number_of_aromatic_16',
#  347: 'number_of_aromatic_17',
#  348: 'number_of_aromatic_18',
#  349: 'number_of_aromatic_19',
#  350: 'number_of_aromatic_20',
#  351: 'number_of_aromatic_21',
#  352: 'number_of_aromatic_22',
#  353: 'number_of_aromatic_23',
#  354: 'number_of_aromatic_24',
#  355: 'number_of_aromatic_25',
#  356: 'number_of_aromatic_26',
#  357: 'number_of_aromatic_27',
#  358: 'number_of_aromatic_28',
#  359: 'number_of_aromatic_29',
#  360: 'number_of_aromatic_30',
#  361: 'number_of_aromatic_31',
#  362: 'number_of_aromatic_32',
#  363: 'number_of_aromatic_33',
#  364: 'number_of_aromatic_34',
#  365: 'number_of_aromatic_35',
#  366: 'number_of_aromatic_36',
#  367: 'number_of_aromatic_37',
#  368: 'number_of_aromatic_38',
#  369: 'number_of_aromatic_39',
#  370: 'number_of_aromatic_40',
#  371: 'number_of_aromatic_44',
#  372: 'number_of_aromatic_45',
#  373: 'number_of_aliphatic_0',
#  374: 'number_of_aliphatic_1',
#  375: 'number_of_aliphatic_2',
#  376: 'number_of_aliphatic_3',
#  377: 'number_of_aliphatic_4',
#  378: 'number_of_aliphatic_5',
#  379: 'number_of_aliphatic_6',
#  380: 'number_of_aliphatic_7',
#  381: 'number_of_aliphatic_8',
#  382: 'number_of_aliphatic_9',
#  383: 'number_of_aliphatic_10',
#  384: 'number_of_aliphatic_11',
#  385: 'number_of_aliphatic_12',
#  386: 'number_of_aliphatic_13',
#  387: 'number_of_aliphatic_14',
#  388: 'number_of_aliphatic_15',
#  389: 'number_of_aliphatic_16',
#  390: 'number_of_aliphatic_17',
#  391: 'number_of_aliphatic_18',
#  392: 'number_of_aliphatic_19',
#  393: 'number_of_aliphatic_20',
#  394: 'number_of_aliphatic_21',
#  395: 'number_of_aliphatic_22',
#  396: 'number_of_aliphatic_23',
#  397: 'number_of_charged_0',
#  398: 'number_of_charged_1',
#  399: 'number_of_charged_2',
#  400: 'number_of_charged_3',
#  401: 'number_of_charged_4',
#  402: 'number_of_charged_5',
#  403: 'number_of_charged_6',
#  404: 'number_of_charged_7',
#  405: 'number_of_charged_8',
#  406: 'number_of_charged_9',
#  407: 'number_of_charged_10',
#  408: 'number_of_charged_11',
#  409: 'number_of_charged_12',
#  410: 'number_of_charged_13',
#  411: 'number_of_charged_14',
#  412: 'number_of_charged_15',
#  413: 'number_of_positive_0',
#  414: 'number_of_positive_1',
#  415: 'number_of_positive_2',
#  416: 'number_of_positive_3',
#  417: 'number_of_positive_4',
#  418: 'number_of_positive_5',
#  419: 'number_of_positive_6',
#  420: 'number_of_positive_7',
#  421: 'number_of_positive_8',
#  422: 'number_of_positive_9',
#  423: 'number_of_positive_10',
#  424: 'number_of_positive_11',
#  425: 'number_of_positive_12',
#  426: 'number_of_negative_0',
#  427: 'number_of_negative_1',
#  428: 'number_of_negative_2',
#  429: 'number_of_negative_3',
#  430: 'number_of_negative_4',
#  431: 'number_of_negative_5',
#  432: 'number_of_negative_6',
#  433: 'number_of_negative_7',
#  434: 'number_of_negative_8',
#  435: 'number_of_negative_9',
#  436: 'number_of_negative_10',
#  437: 'number_of_negative_12',
#  438: 'number_of_negative_14',
#  439: 'number_of_negative_16',
#  440: 'number_of_negative_19',
#  441: 'number_of_g_0',
#  442: 'number_of_g_1',
#  443: 'number_of_g_2',
#  444: 'number_of_g_3',
#  445: 'number_of_g_4',
#  446: 'number_of_g_5',
#  447: 'number_of_g_6',
#  448: 'number_of_g_7',
#  449: 'number_of_g_8',
#  450: 'number_of_g_9',
#  451: 'number_of_g_10',
#  452: 'number_of_g_11',
#  453: 'number_of_g_12',
#  454: 'number_of_g_13',
#  455: 'number_of_g_14',
#  456: 'number_of_g_15',
#  457: 'number_of_g_16',
#  458: 'number_of_g_17',
#  459: 'number_of_g_18',
#  460: 'number_of_g_19',
#  461: 'number_of_g_20',
#  462: 'number_of_g_21',
#  463: 'number_of_g_22',
#  464: 'number_of_g_23',
#  465: 'number_of_g_24',
#  466: 'number_of_g_25',
#  467: 'number_of_g_26',
#  468: 'number_of_g_27',
#  469: 'number_of_v_0',
#  470: 'number_of_v_1',
#  471: 'number_of_v_2',
#  472: 'number_of_v_3',
#  473: 'number_of_v_4',
#  474: 'number_of_v_5',
#  475: 'number_of_v_6',
#  476: 'number_of_v_7',
#  477: 'number_of_v_8',
#  478: 'number_of_v_9',
#  479: 'number_of_v_10',
#  480: 'number_of_v_11',
#  481: 'number_of_v_12',
#  482: 'number_of_v_13',
#  483: 'number_of_v_14',
#  484: 'number_of_v_15',
#  485: 'number_of_v_16',
#  486: 'number_of_v_17',
#  487: 'number_of_v_18',
#  488: 'number_of_v_19',
#  489: 'number_of_v_20',
#  490: 'number_of_v_21',
#  491: 'number_of_v_22',
#  492: 'number_of_v_23',
#  493: 'number_of_v_24',
#  494: 'number_of_v_25',
#  495: 'number_of_v_26',
#  496: 'number_of_v_27',
#  497: 'number_of_v_28',
#  498: 'number_of_v_29',
#  499: 'number_of_v_30',
#  500: 'number_of_v_31',
#  501: 'number_of_v_32',
#  502: 'number_of_v_33',
#  503: 'number_of_v_34',
#  504: 'number_of_s_0',
#  505: 'number_of_s_1',
#  506: 'number_of_s_2',
#  507: 'number_of_s_3',
#  508: 'number_of_s_4',
#  509: 'number_of_s_5',
#  510: 'number_of_s_6',
#  511: 'number_of_s_7',
#  512: 'number_of_s_8',
#  513: 'number_of_s_9',
#  514: 'number_of_s_10',
#  515: 'number_of_s_11',
#  516: 'number_of_s_12',
#  517: 'number_of_s_13',
#  518: 'number_of_s_14',
#  519: 'number_of_s_15',
#  520: 'number_of_s_16',
#  521: 'number_of_s_17',
#  522: 'number_of_s_18',
#  523: 'number_of_s_19',
#  524: 'number_of_s_20',
#  525: 'number_of_s_21',
#  526: 'number_of_n_0',
#  527: 'number_of_n_1',
#  528: 'number_of_n_2',
#  529: 'number_of_n_3',
#  530: 'number_of_n_4',
#  531: 'number_of_n_5',
#  532: 'number_of_n_6',
#  533: 'number_of_n_7',
#  534: 'number_of_n_8',
#  535: 'number_of_n_9',
#  536: 'number_of_n_10',
#  537: 'number_of_n_11',
#  538: 'number_of_n_12',
#  539: 'number_of_l_0',
#  540: 'number_of_l_1',
#  541: 'number_of_l_2',
#  542: 'number_of_l_3',
#  543: 'number_of_l_4',
#  544: 'number_of_l_5',
#  545: 'number_of_l_6',
#  546: 'number_of_l_7',
#  547: 'number_of_l_8',
#  548: 'number_of_l_9',
#  549: 'number_of_l_10',
#  550: 'number_of_p_0',
#  551: 'number_of_p_1',
#  552: 'number_of_p_2',
#  553: 'number_of_p_3',
#  554: 'number_of_p_4',
#  555: 'number_of_p_5',
#  556: 'number_of_p_6',
#  557: 'number_of_p_7',
#  558: 'number_of_p_8',
#  559: 'number_of_p_9',
#  560: 'number_of_p_10',
#  561: 'number_of_p_11',
#  562: 'number_of_p_12',
#  563: 'number_of_p_13',
#  564: 'number_of_p_14',
#  565: 'number_of_p_15',
#  566: 'number_of_p_16',
#  567: 'number_of_p_17',
#  568: 'number_of_p_18',
#  569: 'number_of_p_19',
#  570: 'number_of_A_0',
#  571: 'number_of_A_1',
#  572: 'number_of_A_2',
#  573: 'number_of_A_3',
#  574: 'number_of_A_4',
#  575: 'number_of_A_5',
#  576: 'number_of_A_6',
#  577: 'number_of_A_7',
#  578: 'number_of_A_8',
#  579: 'number_of_A_9',
#  580: 'number_of_A_10',
#  581: 'number_of_A_11',
#  582: 'number_of_A_12',
#  583: 'number_of_A_13',
#  584: 'number_of_A_14',
#  585: 'number_of_b_0',
#  586: 'number_of_b_1',
#  587: 'number_of_b_2',
#  588: 'number_of_b_3',
#  589: 'number_of_b_4',
#  590: 'number_of_b_5',
#  591: 'number_of_b_6',
#  592: 'number_of_b_7',
#  593: 'number_of_b_8',
#  594: 'number_of_b_9',
#  595: 'number_of_b_10',
#  596: 'number_of_b_11',
#  597: 'number_of_b_12',
#  598: 'number_of_d_0',
#  599: 'number_of_d_1',
#  600: 'number_of_d_2',
#  601: 'number_of_d_3',
#  602: 'number_of_d_4',
#  603: 'number_of_d_5',
#  604: 'number_of_d_6',
#  605: 'number_of_d_7',
#  606: 'number_of_d_8',
#  607: 'number_of_d_9',
#  608: 'number_of_e_0',
#  609: 'number_of_e_1',
#  610: 'number_of_e_2',
#  611: 'number_of_e_3',
#  612: 'number_of_e_4',
#  613: 'number_of_e_5',
#  614: 'number_of_e_6',
#  615: 'number_of_e_7',
#  616: 'number_of_e_8',
#  617: 'number_of_e_9',
#  618: 'number_of_e_10',
#  619: 'number_of_e_11',
#  620: 'number_of_e_12',
#  621: 'number_of_e_13',
#  622: 'number_of_e_14',
#  623: 'number_of_e_15',
#  624: 'number_of_e_16',
#  625: 'number_of_e_17',
#  626: 'number_of_f_0',
#  627: 'number_of_f_1',
#  628: 'number_of_f_2',
#  629: 'number_of_f_3',
#  630: 'number_of_f_4',
#  631: 'number_of_f_5',
#  632: 'number_of_f_6',
#  633: 'number_of_f_7',
#  634: 'number_of_f_8',
#  635: 'number_of_f_9',
#  636: 'number_of_f_10',
#  637: 'number_of_f_11',
#  638: 'number_of_f_14',
#  639: 'number_of_ala_0',
#  640: 'number_of_ala_1',
#  641: 'number_of_ala_2',
#  642: 'number_of_ala_3',
#  643: 'number_of_ala_4',
#  644: 'number_of_ala_5',
#  645: 'number_of_ala_6',
#  646: 'number_of_ala_7',
#  647: 'number_of_ala_8',
#  648: 'number_of_cys_0',
#  649: 'number_of_cys_1',
#  650: 'number_of_cys_2',
#  651: 'number_of_cys_3',
#  652: 'number_of_cys_4',
#  653: 'number_of_cys_5',
#  654: 'number_of_cys_6',
#  655: 'number_of_cys_7',
#  656: 'number_of_cys_8',
#  657: 'number_of_cys_9',
#  658: 'number_of_asp_0',
#  659: 'number_of_asp_1',
#  660: 'number_of_asp_2',
#  661: 'number_of_asp_3',
#  662: 'number_of_asp_4',
#  663: 'number_of_asp_5',
#  664: 'number_of_asp_6',
#  665: 'number_of_asp_7',
#  666: 'number_of_asp_8',
#  667: 'number_of_asp_9',
#  668: 'number_of_glu_0',
#  669: 'number_of_glu_1',
#  670: 'number_of_glu_2',
#  671: 'number_of_glu_3',
#  672: 'number_of_glu_4',
#  673: 'number_of_glu_5',
#  674: 'number_of_glu_6',
#  675: 'number_of_glu_7',
#  676: 'number_of_glu_8',
#  677: 'number_of_glu_9',
#  678: 'number_of_glu_10',
#  679: 'number_of_glu_11',
#  680: 'number_of_glu_12',
#  681: 'number_of_phe_0',
#  682: 'number_of_phe_1',
#  683: 'number_of_phe_2',
#  684: 'number_of_phe_3',
#  685: 'number_of_phe_4',
#  686: 'number_of_phe_5',
#  687: 'number_of_phe_6',
#  688: 'number_of_his_0',
#  689: 'number_of_his_1',
#  690: 'number_of_his_2',
#  691: 'number_of_his_3',
#  692: 'number_of_his_4',
#  693: 'number_of_his_5',
#  694: 'number_of_his_6',
#  695: 'number_of_his_7',
#  696: 'number_of_his_8',
#  697: 'number_of_his_9',
#  698: 'number_of_his_10',
#  699: 'number_of_his_11',
#  700: 'number_of_his_12',
#  701: 'number_of_his_13',
#  702: 'number_of_ile_0',
#  703: 'number_of_ile_1',
#  704: 'number_of_ile_2',
#  705: 'number_of_ile_3',
#  706: 'number_of_ile_4',
#  707: 'number_of_ile_5',
#  708: 'number_of_ile_6',
#  709: 'number_of_ile_7',
#  710: 'number_of_ile_10',
#  711: 'number_of_lys_0',
#  712: 'number_of_lys_1',
#  713: 'number_of_lys_2',
#  714: 'number_of_lys_3',
#  715: 'number_of_lys_4',
#  716: 'number_of_lys_5',
#  717: 'number_of_lys_6',
#  718: 'number_of_lys_7',
#  719: 'number_of_lys_8',
#  720: 'number_of_lys_9',
#  721: 'number_of_lys_10',
#  722: 'number_of_lys_11',
#  723: 'number_of_lys_12',
#  724: 'number_of_lys_13',
#  725: 'number_of_lys_14',
#  726: 'number_of_lys_15',
#  727: 'number_of_lys_16',
#  728: 'number_of_lys_17',
#  729: 'number_of_leu_0',
#  730: 'number_of_leu_1',
#  731: 'number_of_leu_2',
#  732: 'number_of_leu_3',
#  733: 'number_of_leu_4',
#  734: 'number_of_leu_5',
#  735: 'number_of_leu_6',
#  736: 'number_of_leu_7',
#  737: 'number_of_leu_8',
#  738: 'number_of_met_0',
#  739: 'number_of_met_1',
#  740: 'number_of_met_2',
#  741: 'number_of_met_3',
#  742: 'number_of_met_4',
#  743: 'number_of_met_5',
#  744: 'number_of_met_6',
#  745: 'number_of_met_7',
#  746: 'number_of_met_8',
#  747: 'number_of_asn_0',
#  748: 'number_of_asn_1',
#  749: 'number_of_asn_2',
#  750: 'number_of_asn_3',
#  751: 'number_of_asn_4',
#  752: 'number_of_asn_5',
#  753: 'number_of_asn_6',
#  754: 'number_of_asn_7',
#  755: 'number_of_asn_8',
#  756: 'number_of_asn_11',
#  757: 'number_of_gln_0',
#  758: 'number_of_gln_1',
#  759: 'number_of_gln_2',
#  760: 'number_of_gln_3',
#  761: 'number_of_gln_4',
#  762: 'number_of_gln_5',
#  763: 'number_of_gln_6',
#  764: 'number_of_gln_7',
#  765: 'number_of_gln_8',
#  766: 'number_of_arg_0',
#  767: 'number_of_arg_1',
#  768: 'number_of_arg_2',
#  769: 'number_of_arg_3',
#  770: 'number_of_arg_4',
#  771: 'number_of_arg_5',
#  772: 'number_of_arg_6',
#  773: 'number_of_arg_7',
#  774: 'number_of_arg_8',
#  775: 'number_of_arg_9',
#  776: 'number_of_arg_10',
#  777: 'number_of_arg_11',
#  778: 'number_of_ser_0',
#  779: 'number_of_ser_1',
#  780: 'number_of_ser_2',
#  781: 'number_of_ser_3',
#  782: 'number_of_ser_4',
#  783: 'number_of_ser_5',
#  784: 'number_of_ser_6',
#  785: 'number_of_ser_7',
#  786: 'number_of_ser_8',
#  787: 'number_of_ser_9',
#  788: 'number_of_ser_10',
#  789: 'number_of_ser_11',
#  790: 'number_of_ser_12',
#  791: 'number_of_ser_13',
#  792: 'number_of_thr_0',
#  793: 'number_of_thr_1',
#  794: 'number_of_thr_2',
#  795: 'number_of_thr_3',
#  796: 'number_of_thr_4',
#  797: 'number_of_thr_5',
#  798: 'number_of_thr_6',
#  799: 'number_of_thr_7',
#  800: 'number_of_thr_8',
#  801: 'number_of_thr_9',
#  802: 'number_of_thr_10',
#  803: 'number_of_thr_11',
#  804: 'number_of_thr_12',
#  805: 'number_of_thr_13',
#  806: 'number_of_thr_14',
#  807: 'number_of_thr_15',
#  808: 'number_of_thr_16',
#  809: 'number_of_thr_17',
#  810: 'number_of_thr_18',
#  811: 'number_of_thr_19',
#  812: 'number_of_thr_20',
#  813: 'number_of_thr_21',
#  814: 'number_of_val_0',
#  815: 'number_of_val_1',
#  816: 'number_of_val_2',
#  817: 'number_of_val_3',
#  818: 'number_of_val_4',
#  819: 'number_of_val_5',
#  820: 'number_of_val_6',
#  821: 'number_of_val_7',
#  822: 'number_of_val_8',
#  823: 'number_of_val_9',
#  824: 'number_of_val_10',
#  825: 'number_of_trp_0',
#  826: 'number_of_trp_1',
#  827: 'number_of_trp_2',
#  828: 'number_of_trp_3',
#  829: 'number_of_trp_4',
#  830: 'number_of_trp_5',
#  831: 'number_of_trp_6',
#  832: 'number_of_trp_7',
#  833: 'number_of_trp_8',
#  834: 'number_of_tyr_0.0',
#  835: 'number_of_tyr_0.3664353191852569',
#  836: 'number_of_tyr_1.1581168174743652',
#  837: 'number_of_tyr_2.0153942108154297',
#  838: 'number_of_tyr_2.959129095077514',
#  839: 'number_of_tyr_4.053408622741699',
#  840: 'number_of_tyr_4.334895133972168',
#  841: 'number_of_tyr_4.659359455108643',
#  842: 'number_of_tyr_5.645819664001465',
#  843: 'number_of_tyr_6.143446922302246',
#  844: 'number_of_tyr_6.514407157897949',
#  845: 'number_of_tyr_6.772017002105713',
#  846: 'number_of_tyr_6.943171501159668',
#  847: 'number_of_tyr_6.962271213531494',
#  848: 'number_of_tyr_7.465932846069336',
#  849: 'number_of_tyr_7.672523975372314',
#  850: 'number_of_tyr_8.251582145690918',
#  851: 'number_of_tyr_8.541111946105957',
#  852: 'number_of_tyr_8.83064079284668',
#  853: 'number_of_tyr_9.699228286743164',
#  854: 'number_of_tyr_11.204425811767578',
#  855: 'number_of_tyr_12.45880126953125',
#  856: 'number_of_tyr_12.64201831817627',
#  857: 'number_of_tyr_13.222586631774902',
#  858: 'number_of_tyr_13.31834316253662',
#  859: 'number_of_tyr_13.46310806274414',
#  860: 'number_of_tyr_13.952691078186035',
#  861: 'number_of_tyr_14.153000831604004',
#  862: 'number_of_tyr_14.502344131469728',
#  863: 'number_of_tyr_15.532036781311035',
#  864: 'number_of_tyr_16.123153686523438',
#  865: 'number_of_tyr_16.358400344848633',
#  866: 'number_of_tyr_17.395877838134766',
#  867: 'number_of_tyr_17.468765258789062',
#  868: 'number_of_tyr_17.864856719970703',
#  869: 'number_of_tyr_18.190073013305664',
#  870: 'number_of_tyr_18.321765899658203',
#  871: 'number_of_tyr_18.688201904296875',
#  872: 'number_of_tyr_19.97072410583496',
#  873: 'number_of_tyr_20.94437026977539',
#  874: 'number_of_tyr_21.341720581054688',
#  875: 'number_of_tyr_21.683019638061523',
#  876: 'number_of_tyr_22.36009979248047',
#  877: 'number_of_tyr_22.728042602539062',
#  878: 'number_of_tyr_22.8046932220459',
#  879: 'number_of_tyr_23.14549827575684',
#  880: 'number_of_tyr_23.25809097290039',
#  881: 'number_of_tyr_23.5735092163086',
#  882: 'number_of_tyr_23.596630096435547',
#  883: 'number_of_tyr_23.780851364135746',
#  884: 'number_of_tyr_23.83740425109864',
#  885: 'number_of_tyr_24.10355758666992',
#  886: 'number_of_tyr_24.238773345947266',
#  887: 'number_of_tyr_24.734384536743164',
#  888: 'number_of_tyr_24.74041748046875',
#  889: 'number_of_tyr_25.54265213012696',
#  890: 'number_of_tyr_25.61328125',
#  891: 'number_of_tyr_25.67561149597168',
#  892: 'number_of_tyr_25.83118438720703',
#  893: 'number_of_tyr_27.684967041015625',
#  894: 'number_of_tyr_28.009685516357425',
#  895: 'number_of_tyr_28.99664688110352',
#  896: 'number_of_tyr_29.62421607971192',
#  897: 'number_of_tyr_29.77123641967773',
#  898: 'number_of_tyr_29.9547119140625',
#  899: 'number_of_tyr_31.542598724365234',
#  900: 'number_of_tyr_32.651954650878906',
#  901: 'number_of_tyr_32.716796875',
#  902: 'number_of_tyr_33.14405822753906',
#  903: 'number_of_tyr_33.55070495605469',
#  904: 'number_of_tyr_33.9457893371582',
#  905: 'number_of_tyr_34.09607696533203',
#  906: 'number_of_tyr_34.307952880859375',
#  907: 'number_of_tyr_34.35871887207031',
#  908: 'number_of_tyr_34.4710578918457',
#  909: 'number_of_tyr_34.50599670410156',
#  910: 'number_of_tyr_35.98028564453125',
#  911: 'number_of_tyr_36.27031707763672',
#  912: 'number_of_tyr_36.59729766845703',
#  913: 'number_of_tyr_36.605079650878906',
#  914: 'number_of_tyr_36.91974258422852',
#  915: 'number_of_tyr_36.94010925292969',
#  916: 'number_of_tyr_37.278900146484375',
#  917: 'number_of_tyr_37.3233757019043',
#  918: 'number_of_tyr_37.50960922241211',
#  919: 'number_of_tyr_37.74058532714844',
#  920: 'number_of_tyr_37.78356170654297',
#  921: 'number_of_tyr_38.17914581298828',
#  922: 'number_of_tyr_38.2668571472168',
#  923: 'number_of_tyr_38.38071441650391',
#  924: 'number_of_tyr_38.81449890136719',
#  925: 'number_of_tyr_39.22266006469727',
#  926: 'number_of_tyr_39.31941986083984',
#  927: 'number_of_tyr_39.52073669433594',
#  928: 'number_of_tyr_39.741397857666016',
#  929: 'number_of_tyr_39.78136444091797',
#  930: 'number_of_tyr_39.850982666015625',
#  931: 'number_of_tyr_40.024898529052734',
#  932: 'number_of_tyr_40.31919479370117',
#  933: 'number_of_tyr_40.48633193969727',
#  934: 'number_of_tyr_40.51423263549805',
#  935: 'number_of_tyr_40.69644927978516',
#  936: 'number_of_tyr_40.83517456054688',
#  937: 'number_of_tyr_41.03145980834961',
#  938: 'number_of_tyr_41.102840423583984',
#  939: 'number_of_tyr_41.305660247802734',
#  940: 'number_of_tyr_41.4466552734375',
#  941: 'number_of_tyr_41.58413314819336',
#  942: 'number_of_tyr_41.97142791748047',
#  943: 'number_of_tyr_42.1810302734375',
#  944: 'number_of_tyr_42.271263122558594',
#  945: 'number_of_tyr_42.54923248291016',
#  946: 'number_of_tyr_42.628395080566406',
#  947: 'number_of_tyr_42.98453140258789',
#  948: 'number_of_tyr_43.01317596435547',
#  949: 'number_of_tyr_43.65054321289063',
#  950: 'number_of_tyr_43.85588455200195',
#  951: 'number_of_tyr_44.115501403808594',
#  952: 'number_of_tyr_44.15470886230469',
#  953: 'number_of_tyr_44.36984252929688',
#  954: 'number_of_tyr_45.12709426879883',
#  955: 'number_of_tyr_45.220584869384766',
#  956: 'number_of_tyr_45.718971252441406',
#  957: 'number_of_tyr_46.193477630615234',
#  958: 'number_of_tyr_46.26787185668945',
#  959: 'number_of_tyr_46.32467269897461',
#  960: 'number_of_tyr_46.355079650878906',
#  961: 'number_of_tyr_46.57247924804688',
#  962: 'number_of_tyr_46.77781677246094',
#  963: 'number_of_tyr_46.86955261230469',
#  964: 'number_of_tyr_46.892669677734375',
#  965: 'number_of_tyr_46.90096282958984',
#  966: 'number_of_tyr_47.24552536010742',
#  967: 'number_of_tyr_47.47826385498047',
#  968: 'number_of_tyr_47.55742645263672',
#  969: 'number_of_tyr_47.77734375',
#  970: 'number_of_tyr_47.77885055541992',
#  971: 'number_of_tyr_47.97915649414063',
#  972: 'number_of_tyr_48.13096237182617',
#  973: 'number_of_tyr_48.455169677734375',
#  974: 'number_of_tyr_48.45743560791016',
#  975: 'number_of_tyr_48.45919418334961',
#  976: 'number_of_tyr_48.55696105957031',
#  977: 'number_of_tyr_48.640655517578125',
#  978: 'number_of_tyr_48.77083969116211',
#  979: 'number_of_tyr_48.82286834716797',
#  980: 'number_of_tyr_49.40544128417969',
#  981: 'number_of_tyr_50.598236083984375',
#  982: 'number_of_tyr_50.88273620605469',
#  983: 'number_of_tyr_50.982521057128906',
#  984: 'number_of_tyr_51.13909530639648',
#  985: 'number_of_tyr_51.15267181396485',
#  986: 'number_of_tyr_51.15795135498047',
#  987: 'number_of_tyr_51.19488525390625',
#  988: 'number_of_tyr_51.30119705200195',
#  989: 'number_of_tyr_51.3627815246582',
#  990: 'number_of_tyr_51.8325080871582',
#  991: 'number_of_tyr_51.84281921386719',
#  992: 'number_of_tyr_51.99687576293945',
#  993: 'number_of_tyr_52.07881164550781',
#  994: 'number_of_tyr_52.50632095336914',
#  995: 'number_of_tyr_52.70813751220703',
#  996: 'number_of_tyr_52.75563430786133',
#  997: 'number_of_tyr_52.90216445922852',
#  998: 'number_of_tyr_53.185150146484375',
#  999: 'number_of_tyr_53.40255355834961',
#  ...}

# %%
augmented_x = list(augmented_data.columns[2:120]) + list(augmented_data.columns[198:-1])
augmented_y = augmented_data.columns[-1]

# %%
both_x = list(augmented_data.columns[:2]) + list(augmented_data.columns[120:198])
both_x = both_x + augmented_x
both_y = 'positivity'

# %% [markdown]
# # ElasticNet model

# %%
from sklearn.linear_model import ElasticNet

def elasticnet(data, x=[], y='', 
               alpha=0.001, l1_ratio=0.5):
    data_x = data[x]
    data_y = data[y]
    
    x_min = data_x.min(0)
    x_max = data_x.max(0)
    data_x_sc = (data_x - x_min) / (x_max - x_min)
    
    elastic_model = ElasticNet(alpha=alpha, l1_ratio=l1_ratio)
    elastic_model.fit(data_x_sc, data_y)
    
    return elastic_model

def elastic_coeff(model, x, rnd=3, disp=False):
    df = pd.DataFrame(
        zip(x, model.coef_, np.abs(model.coef_)
           ), columns = ['features', 'coefficient', 'absolute'] )
    df = df.sort_values(by='absolute', ascending=False).round(rnd)
    if disp:
        display(df.head(disp))
        
    df_important = df[df['absolute']>0]
    print(f'the number of important features: {len(df_important)} out of {len(x)} \n')
    display(dict(zip(df_important['features'], df_important['coefficient'])))
    
    return list(df_important['features'])

# %% [markdown]
# ## original dataset

# %%
data = original_data
x = original_x
y = original_y

alpha = 0.0001
model = elasticnet(data, x, y, alpha)
features = elastic_coeff(model, x)
# Out:
# the number of important features: 48 out of 87
# {'nS/nT_10': 0.017,
#  'flexibility': -0.012,
#  'nS/nT_11': 0.01,
#  'side_2_gly': 0.008,
#  'side_-1_pro': -0.007,
#  'nAli_0': -0.007,
#  'nAli_3': 0.007,
#  'side_2_very_small': 0.007,
#  'side_-1_very_small': 0.007,
#  'Proline': -0.005,
#  'side_4_gly': 0.005,
#  'side_3_long': -0.005,
#  'side_-1_small': 0.005,
#  'nPos_0': -0.004,
#  'SEQ_S': -0.004,
#  'side_4_small': 0.004,
#  'side_3_cycle': -0.004,
#  'side_5_normal': -0.004,
#  'SS_C': 0.004,
#  'side_5_very_small': 0.003,
#  'nS/nT_8': 0.003,
#  'side_3_very_small': 0.003,
#  'nAli_1': -0.003,
#  'nS/nT_12': 0.003,
#  'nS/nT_2': -0.003,
#  'side_1_pro': -0.003,
#  'nS/nT_7': 0.003,
#  'side_1_small': 0.002,
#  'nS/nT_3': -0.002,
#  'side_5_cycle': -0.002,
#  'side_4_long': 0.002,
#  'side_4_normal': -0.002,
#  'side_-1_normal': -0.002,
#  'nPos_1': 0.002,
#  'side_3_gly': 0.002,
#  'side_2_normal': -0.002,
#  'side_1_long': 0.001,
#  'nS/nT_1': -0.001,
#  'nS/nT_4': -0.001,
#  'side_2_long': -0.001,
#  'phi_psi_beta': -0.001,
#  'side_2_cycle': -0.001,
#  'side_2_small': 0.001,
#  'side_1_very_small': 0.001,
#  'nAli_2': 0.001,
#  'phi_psi_alpha': 0.001,
#  'side_5_gly': 0.001,
#  'nS/nT_5': -0.001}

# %% [markdown]
# ## augmented dataset

# %%
data = augmented_data
x = augmented_x
y = augmented_y
alpha = 0.0001

model = elasticnet(data, x, y, alpha)
features = elastic_coeff(model, x)
# Out:
# the number of important features: 407 out of 9227
# C:\Users\honsu\anaconda3\envs\gnn\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.834e-02, tolerance: 1.812e-02
#   model = cd_fast.enet_coordinate_descent(
# {'number_of_tyr_185.0639495849609': 0.613,
#  'number_of_tyr_336.95086669921875': 0.381,
#  'number_of_tyr_280.422119140625': 0.38,
#  'number_of_tyr_490.7499694824219': 0.38,
#  'number_of_tyr_262.17724609375': 0.379,
#  'number_of_tyr_793.8634033203125': 0.377,
#  'number_of_tyr_567.920166015625': 0.376,
#  'number_of_tyr_226.98684692382807': 0.375,
#  'number_of_tyr_375.8166809082031': 0.374,
#  'number_of_tyr_111.88921356201172': 0.373,
#  'number_of_tyr_445.4957885742188': 0.373,
#  'number_of_tyr_251.7066650390625': 0.373,
#  'number_of_tyr_530.521484375': 0.373,
#  'number_of_tyr_399.1080017089844': 0.373,
#  'number_of_tyr_377.1577758789063': 0.372,
#  'number_of_tyr_259.5963134765625': 0.372,
#  'number_of_tyr_365.3014221191406': 0.372,
#  'number_of_tyr_395.9352111816406': 0.372,
#  'number_of_tyr_137.2529296875': 0.372,
#  'number_of_tyr_205.7987060546875': 0.372,
#  'number_of_tyr_361.7418212890625': 0.372,
#  'number_of_tyr_158.60873413085938': 0.371,
#  'number_of_tyr_535.701904296875': 0.371,
#  'number_of_tyr_340.38482666015625': 0.371,
#  'number_of_tyr_183.03497314453125': 0.371,
#  'number_of_tyr_523.3176879882812': 0.37,
#  'number_of_tyr_575.3804931640625': 0.37,
#  'number_of_tyr_306.4789428710937': 0.37,
#  'number_of_tyr_215.04000854492188': 0.37,
#  'number_of_tyr_196.3995513916016': 0.37,
#  'number_of_tyr_326.00634765625': 0.37,
#  'number_of_tyr_258.3505249023437': 0.369,
#  'number_of_tyr_402.0872497558594': 0.368,
#  'number_of_tyr_415.5663757324219': 0.368,
#  'number_of_tyr_298.5131225585937': 0.368,
#  'number_of_tyr_434.14202880859375': 0.368,
#  'number_of_tyr_465.1291198730469': 0.367,
#  'number_of_tyr_259.001220703125': 0.367,
#  'number_of_tyr_77.9828872680664': 0.366,
#  'number_of_tyr_247.37632751464844': 0.366,
#  'number_of_tyr_391.8186645507813': 0.365,
#  'number_of_tyr_500.8352661132813': 0.365,
#  'number_of_tyr_199.3554229736328': 0.365,
#  'number_of_tyr_434.6017150878906': 0.365,
#  'number_of_tyr_674.7830810546875': 0.365,
#  'number_of_tyr_243.63478088378903': 0.364,
#  'number_of_tyr_440.1490173339844': 0.364,
#  'number_of_tyr_109.6916046142578': 0.364,
#  'number_of_tyr_327.4897155761719': 0.364,
#  'number_of_tyr_187.9532165527344': 0.363,
#  'number_of_tyr_264.6497802734375': 0.363,
#  'number_of_tyr_483.3393249511719': 0.363,
#  'number_of_tyr_461.8367004394531': 0.363,
#  'number_of_tyr_71.60871887207031': 0.363,
#  'number_of_tyr_76.18563842773438': 0.363,
#  'number_of_tyr_387.5587463378906': 0.363,
#  'number_of_tyr_468.0686645507813': 0.363,
#  'number_of_tyr_645.2608032226562': 0.362,
#  'number_of_tyr_214.8922271728516': 0.362,
#  'number_of_tyr_149.22088623046875': 0.362,
#  'number_of_tyr_270.90509033203125': 0.361,
#  'number_of_tyr_392.429443359375': 0.361,
#  'number_of_tyr_185.1393280029297': 0.361,
#  'number_of_tyr_137.1895751953125': 0.361,
#  'number_of_tyr_62.90348815917969': 0.361,
#  'number_of_tyr_239.005111694336': 0.361,
#  'number_of_tyr_258.2120361328125': 0.361,
#  'number_of_tyr_410.63427734375': 0.361,
#  'number_of_tyr_112.20035552978516': 0.361,
#  'number_of_tyr_382.5509948730469': 0.36,
#  'number_of_tyr_401.56842041015625': 0.36,
#  'number_of_tyr_335.47540283203125': 0.36,
#  'number_of_tyr_458.6245727539063': 0.36,
#  'number_of_tyr_297.0114440917969': 0.36,
#  'number_of_tyr_302.64190673828125': 0.36,
#  'number_of_tyr_331.94195556640625': 0.36,
#  'number_of_tyr_312.9720153808594': 0.36,
#  'number_of_tyr_656.955078125': 0.359,
#  'number_of_tyr_364.2408142089844': 0.359,
#  'number_of_tyr_237.4202117919922': 0.359,
#  'number_of_tyr_238.228744506836': 0.359,
#  'number_of_tyr_318.7291564941406': 0.359,
#  'number_of_tyr_137.09759521484375': 0.359,
#  'number_of_tyr_268.30810546875': 0.358,
#  'number_of_tyr_126.33928680419922': 0.358,
#  'number_of_tyr_352.9504089355469': 0.358,
#  'number_of_tyr_153.68394470214844': 0.358,
#  'number_of_tyr_216.60726928710932': 0.358,
#  'number_of_tyr_235.86074829101565': 0.358,
#  'number_of_tyr_51.13909530639648': 0.358,
#  'number_of_tyr_338.4369812011719': 0.357,
#  'number_of_tyr_381.9508361816406': 0.357,
#  'number_of_tyr_102.33499908447266': 0.356,
#  'number_of_tyr_207.95034790039065': 0.356,
#  'number_of_tyr_245.5609588623047': 0.356,
#  'number_of_tyr_67.83729553222656': 0.356,
#  'number_of_tyr_259.00347900390625': 0.356,
#  'number_of_tyr_300.49737548828125': 0.356,
#  'number_of_tyr_165.50714111328125': 0.356,
#  'number_of_tyr_553.8082885742188': 0.356,
#  'number_of_tyr_105.53992462158205': 0.356,
#  'number_of_tyr_339.5456237792969': 0.356,
#  'number_of_tyr_351.696533203125': 0.355,
#  'number_of_tyr_212.51744079589844': 0.355,
#  'number_of_tyr_566.6727294921875': 0.355,
#  'number_of_tyr_384.2298278808594': 0.355,
#  'number_of_tyr_317.3710021972656': 0.355,
#  'number_of_tyr_347.8509521484375': 0.355,
#  'number_of_tyr_504.632080078125': 0.355,
#  'number_of_tyr_77.93009948730469': 0.355,
#  'number_of_tyr_183.56930541992188': 0.354,
#  'number_of_tyr_275.1170654296875': 0.354,
#  'number_of_tyr_55.29755783081055': 0.354,
#  'number_of_tyr_220.7187347412109': 0.354,
#  'number_of_tyr_503.28216552734375': 0.354,
#  'number_of_tyr_520.7814331054688': 0.354,
#  'number_of_tyr_328.3668518066406': 0.354,
#  'number_of_tyr_431.03607177734375': 0.354,
#  'number_of_tyr_65.43711853027344': 0.354,
#  'number_of_tyr_86.92310333251953': 0.353,
#  'number_of_tyr_143.73114013671875': 0.353,
#  'number_of_tyr_490.6489562988281': 0.353,
#  'number_of_tyr_112.5087432861328': 0.353,
#  'number_of_tyr_77.46766662597656': 0.353,
#  'number_of_tyr_409.8343811035156': 0.353,
#  'number_of_tyr_125.701904296875': 0.352,
#  'number_of_tyr_173.9532470703125': 0.352,
#  'number_of_tyr_293.1776733398437': 0.352,
#  'number_of_tyr_113.54570770263672': 0.352,
#  'number_of_tyr_33.55070495605469': 0.351,
#  'number_of_tyr_137.75030517578125': 0.351,
#  'number_of_tyr_246.0957946777344': 0.351,
#  'number_of_tyr_189.08367919921875': 0.35,
#  'number_of_tyr_497.74224853515625': 0.349,
#  'number_of_tyr_314.6626892089844': 0.349,
#  'number_of_tyr_144.48988342285156': 0.349,
#  'number_of_tyr_305.5653686523437': 0.348,
#  'number_of_tyr_122.18785095214844': 0.348,
#  'number_of_tyr_373.6827392578125': 0.348,
#  'number_of_tyr_278.757568359375': 0.346,
#  'number_of_tyr_371.28076171875': 0.346,
#  'number_of_tyr_502.224609375': 0.346,
#  'number_of_tyr_358.0963134765625': 0.345,
#  'number_of_tyr_303.9051208496094': 0.345,
#  'number_of_tyr_96.48536682128906': 0.345,
#  'number_of_tyr_289.030517578125': 0.344,
#  'number_of_tyr_207.76255798339844': 0.343,
#  'number_of_tyr_176.1742401123047': 0.343,
#  'number_of_tyr_153.2725372314453': 0.343,
#  'number_of_tyr_163.80667114257812': 0.342,
#  'number_of_tyr_234.32460021972656': 0.342,
#  'number_of_tyr_274.3082580566406': 0.342,
#  'number_of_tyr_298.5362548828125': 0.342,
#  'number_of_tyr_200.95486450195315': 0.342,
#  'number_of_tyr_142.1894989013672': 0.341,
#  'number_of_tyr_172.9152374267578': 0.338,
#  'number_of_tyr_266.09112548828125': 0.337,
#  'number_of_tyr_198.10610961914065': 0.337,
#  'number_of_tyr_331.1824035644531': 0.336,
#  'number_of_tyr_130.21197509765625': 0.336,
#  'number_of_tyr_223.8402557373047': 0.335,
#  'number_of_tyr_168.13427734375': 0.335,
#  'number_of_tyr_513.6859130859375': 0.335,
#  'number_of_tyr_366.347412109375': 0.33,
#  'number_of_tyr_121.12071990966795': 0.329,
#  'number_of_tyr_133.70266723632812': 0.329,
#  'number_of_tyr_292.0899658203125': 0.326,
#  'number_of_tyr_516.8367919921875': 0.321,
#  'number_of_tyr_162.97100830078125': 0.319,
#  'number_of_tyr_151.68113708496094': 0.318,
#  'number_of_tyr_178.63400268554688': 0.31,
#  'number_of_tyr_633.6298828125': 0.3,
#  'number_of_tyr_357.9339904785156': 0.215,
#  'number_of_tyr_122.13230895996094': 0.21,
#  'number_of_tyr_206.62255859375': 0.204,
#  'number_of_tyr_373.5446166992188': 0.19,
#  'number_of_tyr_136.52281188964844': 0.185,
#  'number_of_v_34': 0.167,
#  'number_of_tyr_519.9002685546875': 0.167,
#  'number_of_tyr_139.92755126953125': 0.12,
#  'number_of_lys_14': 0.075,
#  'number_of_A_9': 0.042,
#  'sasa_ala': 0.041,
#  'number_of_p_8': 0.029,
#  'number_of_n_9': 0.021,
#  'sasa_negative': 0.02,
#  'number_of_asn_6': 0.018,
#  'residue_SER_THR_28': 0.018,
#  'number_of_aromatic_37': 0.016,
#  'residue_SER_THR_7': 0.016,
#  'number_of_his_8': 0.015,
#  'number_of_hydrophilic_15': 0.015,
#  'number_of_ile_7': 0.014,
#  'residue_SER_THR_23': 0.014,
#  'number_of_glu_5': 0.013,
#  'number_of_aliphatic_0': 0.012,
#  'number_of_f_5': 0.011,
#  'number_of_s_0': 0.011,
#  'number_of_ser_4': 0.01,
#  'number_of_n_7': -0.01,
#  'number_of_lys_0': 0.009,
#  'number_of_hydrophobic_14': 0.009,
#  'number_of_hydrophobic_8': -0.009,
#  'number_of_aromatic_24': 0.009,
#  'number_of_hydrophobic_1': -0.009,
#  'number_of_hydrophobic_11': 0.009,
#  'sasa_f': 0.008,
#  'number_of_ile_5': 0.008,
#  'number_of_hydrophobic_25': 0.008,
#  'sasa_lys': -0.008,
#  'number_of_aromatic_5': -0.008,
#  'residue_SER_THR_1': 0.008,
#  'number_of_v_10': 0.007,
#  'number_of_aliphatic_5': -0.007,
#  'residue_SER_THR_41': 0.007,
#  'number_of_aliphatic_10': 0.007,
#  'number_of_v_0': -0.007,
#  'number_of_aliphatic_3': -0.007,
#  'number_of_hydrophilic_2': -0.007,
#  'number_of_asn_0': 0.007,
#  'number_of_arg_0': 0.007,
#  'number_of_hydrophilic_0': -0.007,
#  'number_of_hydrophilic_6': 0.006,
#  'number_of_aromatic_21': -0.006,
#  'residue_SER_THR_6': 0.006,
#  'number_of_charged_3': 0.006,
#  'residue_SER_THR_3': 0.006,
#  'exposed_charge_all_with_around_target_ser_thr': -0.006,
#  'number_of_g_2': 0.006,
#  'number_of_hydrophobic_0': 0.005,
#  'number_of_thr_8': 0.005,
#  'number_of_lys_8': 0.005,
#  'number_of_hydrophilic_13': 0.005,
#  'number_of_v_11': 0.005,
#  'number_of_A_1': 0.005,
#  'number_of_g_11': -0.005,
#  'number_of_hydrophobic_18': 0.005,
#  'number_of_l_7': 0.005,
#  'number_of_hydrophilic_14': -0.005,
#  'number_of_v_12': 0.005,
#  'number_of_A_5': -0.005,
#  'number_of_trp_3': -0.005,
#  'number_of_phe_4': 0.005,
#  'number_of_gln_3': 0.005,
#  'number_of_asp_3': -0.005,
#  'number_of_leu_2': -0.005,
#  'number_of_ser_2': 0.005,
#  'number_of_his_5': 0.004,
#  'number_of_ser_0': -0.004,
#  'residue_SER_THR_13': -0.004,
#  'number_of_n_1': 0.004,
#  'number_of_thr_1': 0.004,
#  'number_of_g_3': 0.004,
#  'number_of_charged_2': 0.004,
#  'number_of_aromatic_20': -0.004,
#  'number_of_hydrophilic_7': 0.004,
#  'number_of_aromatic_3': 0.004,
#  'number_of_v_15': 0.004,
#  'number_of_v_17': -0.004,
#  'number_of_charged_8': 0.004,
#  'number_of_leu_0': 0.004,
#  'number_of_hydrophobic_24': -0.004,
#  'number_of_aromatic_16': -0.004,
#  'number_of_s_7': 0.004,
#  'number_of_hydrophobic_4': 0.004,
#  'number_of_l_6': -0.004,
#  'number_of_polar_7': -0.004,
#  'number_of_aromatic_9': -0.004,
#  'number_of_s_2': -0.004,
#  'number_of_aromatic_11': -0.004,
#  'number_of_thr_7': -0.004,
#  'number_of_aromatic_22': 0.004,
#  'exposed_positive_charge_all_with_around_target_ser_thr': -0.004,
#  'number_of_aliphatic_1': 0.004,
#  'number_of_e_7': -0.004,
#  'number_of_glu_1': -0.004,
#  'number_of_glu_3': 0.004,
#  'number_of_p_4': 0.004,
#  'number_of_p_0': -0.004,
#  'number_of_A_6': -0.003,
#  'residue_SER_THR_15': 0.003,
#  'number_of_negative_0': 0.003,
#  'number_of_v_2': -0.003,
#  'number_of_d_4': 0.003,
#  'number_of_aromatic_7': 0.003,
#  'sasa_asp': 0.003,
#  'number_of_aliphatic_7': -0.003,
#  'sasa_met': -0.003,
#  'residue_SER_THR_11': -0.003,
#  'number_of_glu_6': -0.003,
#  'sasa_polar': -0.003,
#  'sasa_e': -0.003,
#  'number_of_f_1': 0.003,
#  'number_of_lys_6': 0.003,
#  'number_of_hydrophobic_22': 0.003,
#  'number_of_ser_6': 0.003,
#  'number_of_polar_0': 0.003,
#  'number_of_p_10': -0.003,
#  'number_of_trp_0': -0.003,
#  'number_of_v_16': 0.003,
#  'number_of_ser_1': -0.003,
#  'number_of_s_14': 0.003,
#  'number_of_hydrophobic_13': 0.003,
#  'number_of_leu_1': 0.003,
#  'number_of_ala_1': -0.003,
#  'number_of_asp_5': 0.003,
#  'number_of_aromatic_19': -0.003,
#  'number_of_aromatic_4': -0.003,
#  'number_of_l_1': 0.003,
#  'number_of_f_2': -0.003,
#  'number_of_negative_4': -0.003,
#  'number_of_hydrophobic_2': -0.002,
#  'number_of_f_6': -0.002,
#  'number_of_thr_3': -0.002,
#  'number_of_aliphatic_9': 0.002,
#  'number_of_hydrophilic_4': 0.002,
#  'number_of_aromatic_10': 0.002,
#  'number_of_v_18': 0.002,
#  'number_of_s_8': 0.002,
#  'number_of_p_3': -0.002,
#  'number_of_positive_2': 0.002,
#  'number_of_aromatic_2': 0.002,
#  'residue_SER_THR_38': 0.002,
#  'number_of_aliphatic_4': -0.002,
#  'number_of_positive_6': 0.002,
#  'number_of_cys_3': -0.002,
#  'number_of_b_6': 0.002,
#  'residue_SER_THR_2': -0.002,
#  'number_of_met_3': 0.002,
#  'number_of_aromatic_14': -0.002,
#  'number_of_e_0': 0.002,
#  'number_of_val_0': 0.002,
#  'number_of_hydrophilic_5': 0.002,
#  'number_of_b_2': 0.002,
#  'number_of_hydrophobic_5': -0.002,
#  'number_of_v_6': 0.002,
#  'residue_SER_THR_20': -0.002,
#  'number_of_d_1': -0.002,
#  'number_of_hydrophobic_23': 0.002,
#  'number_of_ile_3': -0.002,
#  'number_of_thr_0': -0.002,
#  'number_of_charged_6': -0.002,
#  'number_of_lys_12': 0.002,
#  'number_of_ile_0': 0.002,
#  'number_of_arg_4': 0.002,
#  'number_of_e_2': 0.002,
#  'number_of_v_5': -0.002,
#  'number_of_charged_10': -0.002,
#  'number_of_asp_2': -0.002,
#  'number_of_aromatic_1': 0.002,
#  'number_of_v_4': 0.002,
#  'number_of_charged_5': -0.002,
#  'number_of_hydrophobic_12': 0.002,
#  'number_of_v_3': -0.002,
#  'number_of_n_4': -0.002,
#  'number_of_hydrophobic_10': -0.002,
#  'number_of_f_3': -0.002,
#  'residue_SER_THR_19': 0.002,
#  'number_of_ile_1': -0.002,
#  'number_of_aliphatic_12': -0.002,
#  'number_of_negative_1': -0.002,
#  'number_of_negative_7': -0.002,
#  'number_of_cys_0': 0.001,
#  'number_of_polar_3': -0.001,
#  'number_of_p_1': -0.001,
#  'number_of_phe_2': -0.001,
#  'number_of_s_6': -0.001,
#  'number_of_v_8': 0.001,
#  'number_of_p_2': 0.001,
#  'number_of_g_8': 0.001,
#  'number_of_n_6': 0.001,
#  'number_of_charged_1': 0.001,
#  'number_of_l_4': -0.001,
#  'number_of_positive_7': -0.001,
#  'number_of_b_7': -0.001,
#  'number_of_gln_4': 0.001,
#  'number_of_polar_9': -0.001,
#  'number_of_e_9': -0.001,
#  'number_of_thr_6': 0.001,
#  'number_of_his_2': -0.001,
#  'number_of_polar_2': 0.001,
#  'number_of_thr_4': 0.001,
#  'number_of_lys_9': -0.001,
#  'number_of_e_11': 0.001,
#  'number_of_polar_11': 0.001,
#  'number_of_negative_3': -0.001,
#  'number_of_polar_4': -0.001,
#  'number_of_e_5': 0.001,
#  'number_of_met_0': -0.001,
#  'residue_SER_THR_4': 0.001,
#  'number_of_polar_5': 0.001,
#  'number_of_phe_1': 0.001,
#  'number_of_g_1': -0.001,
#  'number_of_aliphatic_8': 0.001,
#  'number_of_e_3': -0.001,
#  'number_of_b_3': 0.001,
#  'number_of_his_7': -0.001,
#  'number_of_ala_4': 0.001,
#  'number_of_his_3': -0.001,
#  'number_of_e_4': -0.001,
#  'number_of_his_1': 0.001,
#  'number_of_leu_3': -0.001,
#  'number_of_arg_6': -0.001,
#  'number_of_aromatic_18': 0.001,
#  'number_of_hydrophilic_10': -0.001,
#  'number_of_p_6': 0.001,
#  'number_of_negative_6': 0.001}

# %% [markdown]
# ## both dataset

# %%
data = augmented_data
x = both_x
y = both_y
alpha = 0.0001

model = elasticnet(data, x, y, alpha)
features = elastic_coeff(model, x)
# Out:
# the number of important features: 474 out of 9307
# C:\Users\honsu\anaconda3\envs\gnn\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.019e-02, tolerance: 1.812e-02
#   model = cd_fast.enet_coordinate_descent(
# {'number_of_tyr_185.0639495849609': 0.621,
#  'nS/nT_15': 0.602,
#  'number_of_tyr_793.8634033203125': 0.384,
#  'number_of_tyr_336.95086669921875': 0.383,
#  'number_of_tyr_402.0872497558594': 0.382,
#  'number_of_tyr_280.422119140625': 0.377,
#  'number_of_tyr_567.920166015625': 0.377,
#  'number_of_tyr_575.3804931640625': 0.377,
#  'number_of_tyr_326.00634765625': 0.376,
#  'number_of_tyr_262.17724609375': 0.376,
#  'number_of_tyr_226.98684692382807': 0.376,
#  'number_of_tyr_461.8367004394531': 0.375,
#  'number_of_tyr_259.001220703125': 0.373,
#  'number_of_tyr_183.03497314453125': 0.372,
#  'number_of_tyr_490.7499694824219': 0.372,
#  'number_of_tyr_375.8166809082031': 0.372,
#  'number_of_tyr_535.701904296875': 0.372,
#  'number_of_tyr_77.9828872680664': 0.371,
#  'number_of_tyr_111.88921356201172': 0.37,
#  'number_of_tyr_523.3176879882812': 0.37,
#  'number_of_tyr_391.8186645507813': 0.37,
#  'number_of_tyr_500.8352661132813': 0.369,
#  'number_of_tyr_440.1490173339844': 0.368,
#  'number_of_tyr_327.4897155761719': 0.367,
#  'number_of_tyr_243.63478088378903': 0.366,
#  'number_of_tyr_158.60873413085938': 0.366,
#  'number_of_tyr_270.90509033203125': 0.366,
#  'number_of_tyr_153.68394470214844': 0.366,
#  'number_of_tyr_187.9532165527344': 0.366,
#  'number_of_tyr_399.1080017089844': 0.366,
#  'number_of_tyr_137.2529296875': 0.366,
#  'number_of_tyr_382.5509948730469': 0.365,
#  'number_of_tyr_205.7987060546875': 0.365,
#  'number_of_tyr_340.38482666015625': 0.364,
#  'number_of_tyr_149.22088623046875': 0.364,
#  'number_of_tyr_377.1577758789063': 0.364,
#  'number_of_tyr_318.7291564941406': 0.364,
#  'number_of_tyr_530.521484375': 0.364,
#  'number_of_tyr_258.2120361328125': 0.363,
#  'number_of_tyr_215.04000854492188': 0.363,
#  'number_of_tyr_445.4957885742188': 0.362,
#  'number_of_tyr_109.6916046142578': 0.362,
#  'number_of_tyr_674.7830810546875': 0.362,
#  'number_of_tyr_112.20035552978516': 0.362,
#  'number_of_tyr_566.6727294921875': 0.362,
#  'number_of_tyr_298.5131225585937': 0.361,
#  'number_of_tyr_251.7066650390625': 0.361,
#  'number_of_tyr_259.5963134765625': 0.361,
#  'number_of_tyr_365.3014221191406': 0.36,
#  'number_of_tyr_306.4789428710937': 0.36,
#  'number_of_tyr_62.90348815917969': 0.36,
#  'number_of_tyr_361.7418212890625': 0.36,
#  'number_of_tyr_77.93009948730469': 0.36,
#  'number_of_tyr_71.60871887207031': 0.36,
#  'number_of_tyr_143.73114013671875': 0.36,
#  'number_of_tyr_458.6245727539063': 0.36,
#  'number_of_tyr_352.9504089355469': 0.36,
#  'number_of_tyr_183.56930541992188': 0.36,
#  'number_of_tyr_214.8922271728516': 0.36,
#  'number_of_tyr_384.2298278808594': 0.36,
#  'number_of_tyr_392.429443359375': 0.359,
#  'number_of_tyr_76.18563842773438': 0.359,
#  'number_of_tyr_137.1895751953125': 0.359,
#  'number_of_tyr_216.60726928710932': 0.358,
#  'number_of_tyr_465.1291198730469': 0.358,
#  'number_of_tyr_239.005111694336': 0.358,
#  'number_of_tyr_235.86074829101565': 0.357,
#  'number_of_tyr_483.3393249511719': 0.357,
#  'number_of_tyr_258.3505249023437': 0.357,
#  'number_of_tyr_67.83729553222656': 0.357,
#  'number_of_tyr_434.6017150878906': 0.356,
#  'number_of_tyr_246.0957946777344': 0.356,
#  'number_of_tyr_395.9352111816406': 0.356,
#  'number_of_tyr_520.7814331054688': 0.356,
#  'number_of_tyr_173.9532470703125': 0.356,
#  'number_of_tyr_238.228744506836': 0.356,
#  'number_of_tyr_137.09759521484375': 0.355,
#  'number_of_tyr_245.5609588623047': 0.355,
#  'number_of_tyr_300.49737548828125': 0.355,
#  'number_of_tyr_415.5663757324219': 0.355,
#  'number_of_tyr_207.95034790039065': 0.355,
#  'number_of_tyr_645.2608032226562': 0.354,
#  'number_of_tyr_212.51744079589844': 0.354,
#  'number_of_tyr_317.3710021972656': 0.354,
#  'number_of_tyr_410.63427734375': 0.354,
#  'number_of_tyr_126.33928680419922': 0.353,
#  'number_of_tyr_312.9720153808594': 0.353,
#  'number_of_tyr_335.47540283203125': 0.353,
#  'number_of_tyr_86.92310333251953': 0.353,
#  'number_of_tyr_503.28216552734375': 0.353,
#  'number_of_tyr_275.1170654296875': 0.352,
#  'number_of_tyr_364.2408142089844': 0.352,
#  'number_of_tyr_247.37632751464844': 0.352,
#  'number_of_tyr_51.13909530639648': 0.352,
#  'number_of_tyr_302.64190673828125': 0.352,
#  'number_of_tyr_264.6497802734375': 0.352,
#  'number_of_tyr_468.0686645507813': 0.352,
#  'number_of_tyr_33.55070495605469': 0.351,
#  'number_of_tyr_268.30810546875': 0.351,
#  'number_of_tyr_237.4202117919922': 0.351,
#  'number_of_tyr_259.00347900390625': 0.351,
#  'number_of_tyr_199.3554229736328': 0.351,
#  'number_of_tyr_165.50714111328125': 0.351,
#  'number_of_tyr_122.18785095214844': 0.351,
#  'number_of_tyr_381.9508361816406': 0.351,
#  'number_of_tyr_297.0114440917969': 0.35,
#  'number_of_tyr_196.3995513916016': 0.35,
#  'number_of_tyr_331.94195556640625': 0.35,
#  'number_of_tyr_314.6626892089844': 0.35,
#  'number_of_tyr_409.8343811035156': 0.35,
#  'number_of_tyr_434.14202880859375': 0.35,
#  'number_of_tyr_553.8082885742188': 0.349,
#  'number_of_tyr_220.7187347412109': 0.349,
#  'number_of_tyr_113.54570770263672': 0.349,
#  'number_of_tyr_96.48536682128906': 0.349,
#  'number_of_tyr_278.757568359375': 0.349,
#  'number_of_tyr_401.56842041015625': 0.348,
#  'number_of_tyr_137.75030517578125': 0.348,
#  'number_of_tyr_338.4369812011719': 0.347,
#  'number_of_tyr_144.48988342285156': 0.347,
#  'number_of_tyr_371.28076171875': 0.347,
#  'number_of_tyr_347.8509521484375': 0.347,
#  'number_of_tyr_656.955078125': 0.347,
#  'number_of_tyr_504.632080078125': 0.346,
#  'number_of_tyr_387.5587463378906': 0.346,
#  'number_of_tyr_185.1393280029297': 0.346,
#  'number_of_tyr_102.33499908447266': 0.346,
#  'number_of_tyr_351.696533203125': 0.345,
#  'number_of_tyr_339.5456237792969': 0.345,
#  'number_of_tyr_125.701904296875': 0.345,
#  'number_of_tyr_502.224609375': 0.344,
#  'number_of_tyr_55.29755783081055': 0.344,
#  'number_of_tyr_207.76255798339844': 0.343,
#  'number_of_tyr_274.3082580566406': 0.343,
#  'number_of_tyr_77.46766662597656': 0.342,
#  'number_of_tyr_189.08367919921875': 0.342,
#  'number_of_tyr_168.13427734375': 0.341,
#  'number_of_tyr_112.5087432861328': 0.341,
#  'number_of_tyr_497.74224853515625': 0.341,
#  'number_of_tyr_305.5653686523437': 0.341,
#  'number_of_tyr_105.53992462158205': 0.341,
#  'number_of_tyr_234.32460021972656': 0.34,
#  'number_of_tyr_303.9051208496094': 0.34,
#  'number_of_tyr_130.21197509765625': 0.34,
#  'number_of_tyr_153.2725372314453': 0.34,
#  'number_of_tyr_298.5362548828125': 0.34,
#  'number_of_tyr_373.6827392578125': 0.34,
#  'number_of_tyr_431.03607177734375': 0.338,
#  'number_of_tyr_293.1776733398437': 0.338,
#  'number_of_tyr_200.95486450195315': 0.338,
#  'number_of_tyr_358.0963134765625': 0.337,
#  'number_of_tyr_172.9152374267578': 0.336,
#  'number_of_tyr_490.6489562988281': 0.336,
#  'number_of_tyr_289.030517578125': 0.335,
#  'number_of_tyr_163.80667114257812': 0.334,
#  'number_of_tyr_292.0899658203125': 0.334,
#  'number_of_tyr_142.1894989013672': 0.333,
#  'number_of_tyr_266.09112548828125': 0.332,
#  'number_of_tyr_366.347412109375': 0.331,
#  'number_of_tyr_331.1824035644531': 0.33,
#  'number_of_tyr_513.6859130859375': 0.33,
#  'number_of_tyr_176.1742401123047': 0.329,
#  'number_of_tyr_133.70266723632812': 0.328,
#  'number_of_tyr_198.10610961914065': 0.325,
#  'number_of_tyr_223.8402557373047': 0.322,
#  'number_of_tyr_162.97100830078125': 0.316,
#  'number_of_tyr_151.68113708496094': 0.315,
#  'number_of_tyr_121.12071990966795': 0.313,
#  'number_of_tyr_516.8367919921875': 0.313,
#  'number_of_tyr_178.63400268554688': 0.306,
#  'number_of_tyr_633.6298828125': 0.299,
#  'number_of_tyr_122.13230895996094': 0.213,
#  'number_of_tyr_357.9339904785156': 0.21,
#  'number_of_tyr_206.62255859375': 0.206,
#  'number_of_tyr_136.52281188964844': 0.186,
#  'number_of_tyr_373.5446166992188': 0.186,
#  'number_of_v_34': 0.171,
#  'number_of_tyr_519.9002685546875': 0.171,
#  'number_of_tyr_139.92755126953125': 0.115,
#  'number_of_lys_14': 0.075,
#  'sasa_ala': 0.044,
#  'number_of_A_9': 0.042,
#  'number_of_p_8': 0.029,
#  'number_of_n_9': 0.026,
#  'nS/nT_11': 0.02,
#  'number_of_asn_6': 0.019,
#  'residue_SER_THR_28': 0.019,
#  'sasa_negative': 0.017,
#  'residue_SER_THR_7': 0.016,
#  'sasa_l': 0.015,
#  'side_-1_pro': -0.015,
#  'residue_SER_THR_23': 0.014,
#  'number_of_hydrophilic_15': 0.014,
#  'number_of_ile_7': 0.013,
#  'number_of_aromatic_37': 0.013,
#  'number_of_glu_5': 0.012,
#  'number_of_his_8': 0.012,
#  'number_of_s_0': 0.011,
#  'number_of_hydrophobic_14': 0.01,
#  'number_of_hydrophobic_1': -0.01,
#  'number_of_ser_4': 0.01,
#  'number_of_f_5': 0.01,
#  'number_of_hydrophobic_8': -0.01,
#  'side_4_gly': 0.01,
#  'number_of_lys_0': 0.009,
#  'nS/nT_8': 0.009,
#  'side_2_gly': 0.009,
#  'number_of_hydrophobic_25': 0.009,
#  'number_of_hydrophobic_11': 0.009,
#  'number_of_aromatic_24': 0.009,
#  'number_of_aromatic_5': -0.009,
#  'number_of_n_7': -0.008,
#  'sasa_lys': -0.008,
#  'number_of_aliphatic_3': -0.008,
#  'number_of_aliphatic_5': -0.008,
#  'number_of_ile_5': 0.008,
#  'number_of_l_7': 0.007,
#  'number_of_aliphatic_0': 0.007,
#  'Proline': -0.007,
#  'sasa_asp': 0.007,
#  'number_of_arg_0': 0.007,
#  'nAli_3': 0.007,
#  'sasa_v': -0.007,
#  'exposed_charge_all_with_around_target_ser_thr': -0.007,
#  'residue_SER_THR_6': 0.007,
#  'number_of_thr_8': 0.007,
#  'number_of_aliphatic_10': 0.007,
#  'number_of_v_10': 0.007,
#  'residue_SER_THR_1': 0.007,
#  'nAli_0': -0.006,
#  'residue_SER_THR_3': 0.006,
#  'number_of_charged_3': 0.006,
#  'number_of_hydrophilic_2': -0.006,
#  'number_of_g_2': 0.006,
#  'number_of_thr_7': -0.006,
#  'number_of_hydrophilic_0': -0.006,
#  'side_2_pro': -0.006,
#  'number_of_hydrophilic_13': 0.006,
#  'number_of_gln_3': 0.005,
#  'number_of_aromatic_21': -0.005,
#  'number_of_negative_0': 0.005,
#  'number_of_A_5': -0.005,
#  'number_of_A_1': 0.005,
#  'number_of_asn_0': 0.005,
#  'number_of_asp_3': -0.005,
#  'number_of_thr_1': 0.005,
#  'number_of_v_15': 0.005,
#  'number_of_hydrophilic_6': 0.005,
#  'number_of_trp_3': -0.005,
#  'flexibility': -0.005,
#  'side_-1_very_small': 0.005,
#  'side_1_pro': -0.005,
#  'number_of_aromatic_20': -0.005,
#  'number_of_ser_2': 0.005,
#  'number_of_v_18': 0.005,
#  'number_of_hydrophobic_18': 0.005,
#  'number_of_ser_0': -0.005,
#  'number_of_phe_4': 0.005,
#  'number_of_f_6': -0.005,
#  'number_of_leu_2': -0.005,
#  'number_of_hydrophobic_24': -0.005,
#  'number_of_v_12': 0.005,
#  'side_4_very_small': -0.005,
#  'number_of_n_1': 0.004,
#  'number_of_p_10': -0.004,
#  'side_3_very_small': 0.004,
#  'number_of_aromatic_22': 0.004,
#  'nS/nT_5': -0.004,
#  'side_3_small': 0.004,
#  'number_of_charged_2': 0.004,
#  'SS_E': -0.004,
#  'number_of_aromatic_19': -0.004,
#  'residue_SER_THR_15': 0.004,
#  'number_of_hydrophilic_14': -0.004,
#  'number_of_v_0': -0.004,
#  'number_of_p_4': 0.004,
#  'number_of_aromatic_11': -0.004,
#  'side_5_normal': -0.004,
#  'number_of_g_11': -0.004,
#  'number_of_s_7': 0.004,
#  'number_of_l_6': -0.004,
#  'number_of_charged_8': 0.004,
#  'number_of_aromatic_16': -0.004,
#  'number_of_hydrophilic_7': 0.004,
#  'number_of_his_5': 0.004,
#  'number_of_hydrophobic_0': 0.004,
#  'side_5_very_small': 0.004,
#  'number_of_charged_10': -0.004,
#  'number_of_g_3': 0.004,
#  'number_of_A_6': -0.004,
#  'side_-1_small': 0.004,
#  'residue_SER_THR_41': 0.004,
#  'number_of_ser_6': 0.004,
#  'number_of_polar_7': -0.004,
#  'number_of_glu_6': -0.004,
#  'number_of_aliphatic_7': -0.004,
#  'number_of_s_2': -0.004,
#  'number_of_e_7': -0.004,
#  'number_of_aromatic_4': -0.004,
#  'side_2_cycle': -0.004,
#  'residue_SER_THR_19': 0.004,
#  'number_of_glu_3': 0.003,
#  'number_of_s_14': 0.003,
#  'residue_SER_THR_38': 0.003,
#  'number_of_f_1': 0.003,
#  'number_of_d_4': 0.003,
#  'number_of_asp_5': 0.003,
#  'residue_SER_THR_13': -0.003,
#  'number_of_aromatic_9': -0.003,
#  'number_of_aromatic_10': 0.003,
#  'number_of_v_11': 0.003,
#  'number_of_hydrophobic_13': 0.003,
#  'side_3_long': -0.003,
#  'number_of_hydrophobic_4': 0.003,
#  'number_of_lys_8': 0.003,
#  'number_of_glu_1': -0.003,
#  'side_4_normal': -0.003,
#  'number_of_v_2': -0.003,
#  'number_of_trp_0': -0.003,
#  'number_of_aliphatic_4': -0.003,
#  'side_1_cycle': -0.003,
#  'number_of_aromatic_7': 0.003,
#  'residue_SER_THR_11': -0.003,
#  'number_of_aromatic_29': 0.003,
#  'number_of_ser_1': -0.003,
#  'number_of_aromatic_3': 0.003,
#  'number_of_ala_1': -0.003,
#  'side_1_normal': -0.003,
#  'number_of_hydrophobic_2': -0.003,
#  'side_-1_long': -0.003,
#  'number_of_v_5': -0.003,
#  'number_of_aliphatic_9': 0.003,
#  'number_of_his_7': -0.003,
#  'number_of_polar_0': 0.003,
#  'number_of_f_2': -0.003,
#  'number_of_aromatic_25': -0.003,
#  'number_of_v_16': 0.002,
#  'number_of_v_3': -0.002,
#  'number_of_hydrophobic_5': -0.002,
#  'number_of_negative_7': -0.002,
#  'nS/nT_10': -0.002,
#  'number_of_positive_2': 0.002,
#  'number_of_e_0': 0.002,
#  'nAli_1': -0.002,
#  'nS/nT_1': -0.002,
#  'side_3_gly': -0.002,
#  'number_of_l_1': 0.002,
#  'number_of_phe_2': -0.002,
#  'number_of_s_8': 0.002,
#  'number_of_b_2': 0.002,
#  'number_of_negative_4': -0.002,
#  'number_of_lys_9': -0.002,
#  'number_of_hydrophilic_5': 0.002,
#  'number_of_v_17': -0.002,
#  'side_5_pro': 0.002,
#  'number_of_ile_3': -0.002,
#  'number_of_p_2': 0.002,
#  'residue_SER_THR_2': -0.002,
#  'number_of_hydrophobic_23': 0.002,
#  'number_of_n_6': 0.002,
#  'nPos_2': -0.002,
#  'number_of_b_6': 0.002,
#  'number_of_g_8': 0.002,
#  'number_of_aromatic_2': 0.002,
#  'number_of_aromatic_14': -0.002,
#  'number_of_arg_6': -0.002,
#  'number_of_p_0': -0.002,
#  'number_of_n_4': -0.002,
#  'number_of_positive_6': 0.002,
#  'exposed_positive_charge_all_with_around_target_ser_thr': -0.002,
#  'number_of_leu_4': -0.002,
#  'phi_psi_beta': -0.002,
#  'number_of_hydrophilic_4': 0.002,
#  'number_of_thr_3': -0.002,
#  'number_of_aliphatic_2': -0.002,
#  'number_of_val_0': 0.002,
#  'number_of_e_2': 0.002,
#  'number_of_leu_0': 0.002,
#  'number_of_f_3': -0.002,
#  'side_3_normal': 0.002,
#  'number_of_positive_7': -0.002,
#  'number_of_b_7': -0.002,
#  'number_of_hydrophobic_12': 0.002,
#  'nS/nT_4': 0.002,
#  'number_of_met_3': 0.002,
#  'number_of_aromatic_1': 0.002,
#  'number_of_asp_2': -0.002,
#  'number_of_g_0': 0.002,
#  'number_of_ile_1': -0.002,
#  'net_charge_all_around_target_ser_thr': 0.002,
#  'number_of_cys_3': -0.002,
#  'number_of_aromatic_18': 0.002,
#  'number_of_met_0': -0.001,
#  'residue_SER_THR_4': 0.001,
#  'number_of_hydrophobic_22': 0.001,
#  'number_of_d_1': -0.001,
#  'side_4_pro': -0.001,
#  'number_of_arg_4': 0.001,
#  'number_of_polar_9': -0.001,
#  'number_of_e_9': -0.001,
#  'number_of_hydrophobic_10': -0.001,
#  'number_of_polar_2': 0.001,
#  'number_of_cys_5': 0.001,
#  'residue_SER_THR_26': 0.001,
#  'side_-1_normal': -0.001,
#  'side_5_small': 0.001,
#  'number_of_gln_4': 0.001,
#  'number_of_polar_3': -0.001,
#  'number_of_v_6': 0.001,
#  'number_of_thr_4': 0.001,
#  'number_of_leu_1': 0.001,
#  'number_of_lys_6': 0.001,
#  'number_of_ile_0': 0.001,
#  'number_of_p_3': -0.001,
#  'number_of_his_1': 0.001,
#  'number_of_lys_5': -0.001,
#  'number_of_aliphatic_1': 0.001,
#  'number_of_s_12': 0.001,
#  'number_of_aliphatic_13': 0.001,
#  'nPos_1': 0.001,
#  'number_of_leu_3': -0.001,
#  'side_1_very_small': 0.001,
#  'number_of_v_4': 0.001,
#  'number_of_cys_0': 0.001,
#  'number_of_charged_1': 0.001,
#  'residue_SER_THR_9': -0.001,
#  'number_of_aliphatic_12': -0.001,
#  'SS_H': 0.001,
#  'residue_SER_THR_8': 0.001,
#  'number_of_s_6': -0.001,
#  'residue_SER_THR_20': -0.001,
#  'number_of_e_3': -0.001,
#  'number_of_charged_6': -0.001,
#  'number_of_e_11': 0.001,
#  'number_of_polar_11': 0.001,
#  'number_of_v_22': -0.001,
#  'number_of_l_3': 0.001,
#  'number_of_asn_4': -0.001,
#  'number_of_his_2': -0.001,
#  'number_of_b_3': 0.001,
#  'nS/nT_6': 0.001,
#  'number_of_l_4': -0.001,
#  'side_4_small': 0.001,
#  'number_of_lys_7': -0.001,
#  'nAli_2': 0.001,
#  'number_of_polar_5': 0.001,
#  'number_of_negative_2': 0.001,
#  'side_5_long': -0.001,
#  'side_3_cycle': -0.001,
#  'residue_SER_THR_5': 0.001,
#  'number_of_v_7': -0.001,
#  'number_of_e_5': 0.001,
#  'number_of_charged_5': -0.001,
#  'number_of_hydrophilic_10': -0.001,
#  'side_2_very_small': 0.001,
#  'number_of_hydrophilic_11': -0.001,
#  'number_of_aromatic_8': 0.001,
#  'number_of_thr_6': 0.001,
#  'number_of_g_6': -0.001,
#  'number_of_arg_5': -0.001,
#  'side_1_small': 0.001,
#  'number_of_ile_4': -0.001,
#  'nS/nT_3': -0.001,
#  'number_of_phe_1': 0.001,
#  'sasa_s': 0.001,
#  'side_-1_gly': 0.001,
#  'side_2_small': 0.001,
#  'number_of_asn_3': 0.001,
#  'number_of_g_5': -0.001,
#  'number_of_l_5': -0.001,
#  'number_of_v_1': 0.001,
#  'number_of_d_0': 0.001,
#  'number_of_his_3': -0.001,
#  'number_of_e_4': -0.001}

# %% [markdown]
# # ANOVA model

# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm

def anova(data, x=[], y='',
          disp=False, rnd=4):
    data = data[x + [y]]

    f_num = [f"f{num}" for num in range(len(x))]
    data.columns =  f_num + [y]

    n_not = len(f_num) # the number of not important features (initialize to the number of features)
    i = 1
    while n_not > 0:
        print(f'{i}th iteration')
        fs = '+'.join(f_num) 
        model = smf.ols(
            y + '~' + fs,
            data).fit()

        result = sm.stats.anova_lm(model, typ=2).round(rnd)
        n_not = len(result[result['PR(>F)'] > 0.05])
        f_num = [fn for fn in result[result['PR(>F)'] <= 0.05].index]

        i += 1

    result = result.sort_values(by='PR(>F)')
    print(f'the number of important features: {len(f_num)} out of {len(x)}')

    if disp:
        n = 10
        i = 0
        while i < len(result):
            print(result.iloc[i:i+n, :])
            i += n

    x_idx = [int(x.removeprefix('f')) for x in result.index[:-1]]
    x_names = [x[idx] for idx in x_idx]

    print('\norder variables by their importance')
    display(dict(zip(x_idx, x_names)))
    
    return x_names

# %% [markdown]
# ## original dataset

# %%
data = original_data
x = original_x
y = original_y

features = anova(data, x, y)
# Out:
# 1th iteration
# 2th iteration
# the number of important features: 1 out of 87
#
# order variables by their importance
# {1: 'flexibility'}

# %% [markdown]
# ## augmented dataset

# %%
data = augmented_data
x = augmented_x
y = augmented_y

features = anova(data, x, y)
# Out:
# 1th iteration

# %% [markdown]
# ## both dataset

# %%
data = augmented_data
x = both_x
y = both_y

features = anova(data, x, y)

# %% [markdown]
# # Random Forest model

# %%
from sklearn.ensemble import RandomForestClassifier

def randomforest(data, x=[], y='',
                 n_estimators=500, rs=1):
    model = RandomForestClassifier(n_estimators = n_estimators, n_jobs=-1, random_state=rs)
    model.fit(data[x], data[y])
    
    return model

def FI(model, threshold= 0.95, rnd=3, disp=False):
    df = pd.DataFrame(zip(x, model.feature_importances_), columns = ['features', 'score'])
    df = df.sort_values(by='score', ascending=False)

    score_sum = []
    s = 1
    for score in df.score:
        s -= score
        score_sum.append(s)
    df['sum'] = np.array(score_sum)
    df = df.round(rnd)
    
    if disp:
        display(df.head(disp))

    
    df_important = df[df['sum']>= 1-threshold]

    print(f'the number of important features (threshold={threshold}): {len(df_important)} out of {len(df)}')
    display(dict(
        zip(df_important.index, zip(df_important['features'].values, df_important['score'].values, df_important['sum'].values))
    ))
    
    return list(df_important['features'])

# %% [markdown]
# ## original dataset

# %%
data = original_data
x = original_x
y = original_y

model = randomforest(data, x, y)
features = FI(model)

# %% [markdown]
# ## augmented dataset

# %%
data = augmented_data
x = augmented_x
y = augmented_y

model = randomforest(data, x, y)
features = FI(model)

# %% [markdown]
# ## both dataset

# %%
data = augmented_data
x = both_x
y = both_y

model = randomforest(data, x, y)
features = FI(model)

# %% [markdown]
# # Result of finding important variables

# %% [markdown]
# ## original dataset

# %%
data = original_data
x = original_x
y = original_y

# ElasticNet
alpha = 0.0001
model = elasticnet(data, x, y, alpha)
EN_features = elastic_coeff(model, x)

# ANOVA
AN_features = anova(data, x, y)

# RandomForest
threshold = 0.95
model = randomforest(data, x, y)
RF_features = FI(model, threshold=threshold)

# %%
importance = pd.DataFrame(np.zeros((len(x), 3)), columns=['ElasticNet', 'ANOVA', 'RandomForest'], index=x)
for feature in EN_features:
    importance.loc[feature,'ElasticNet'] = 1
for feature in AN_features:
    importance.loc[feature,'ANOVA'] = 1
for feature in RF_features:
    importance.loc[feature,'RandomForest'] = 1
    
importance['Score'] = importance.sum(axis=1)
save_path = './result/important_variables_original_cts_cat_v2.csv'
if not exists(save_path):
    importance.to_csv(save_path)
importance_original = importance
importance_original

# %% [markdown]
# ## augmented dataset

# %%
data = augmented_data
x = augmented_x
y = augmented_y

# ElasticNet
alpha = 0.0001
model = elasticnet(data, x, y, alpha)
EN_features = elastic_coeff(model, x)

# ANOVA
AN_features = anova(data, x, y)

# RandomForest
threshold = 0.95
model = randomforest(data, x, y)
RF_features = FI(model, threshold=threshold)

# %%
importance = pd.DataFrame(np.zeros((len(x), 3)), columns=['ElasticNet', 'ANOVA', 'RandomForest'], index=x)
for feature in EN_features:
    importance.loc[feature,'ElasticNet'] = 1
for feature in AN_features:
    importance.loc[feature,'ANOVA'] = 1
for feature in RF_features:
    importance.loc[feature,'RandomForest'] = 1
    
importance['Score'] = importance.sum(axis=1)
save_path = './result/important_variables_augmented_cts_cat_v2.csv'
if not exists(save_path):
    importance.to_csv(save_path)
importance_augmented = importance
importance_augmented

# %% [markdown]
# ## both dataset

# %%
data = augmented_data
x = both_x
y = both_y

# ElasticNet
alpha = 0.0001
model = elasticnet(data, x, y, alpha)
EN_features = elastic_coeff(model, x)

# ANOVA
AN_features = anova(data, x, y)

# RandomForest
threshold = 0.95
model = randomforest(data, x, y)
RF_features = FI(model, threshold=threshold)

# %%
importance = pd.DataFrame(np.zeros((len(x), 3)), columns=['ElasticNet', 'ANOVA', 'RandomForest'], index=x)
for feature in EN_features:
    importance.loc[feature,'ElasticNet'] = 1
for feature in AN_features:
    importance.loc[feature,'ANOVA'] = 1
for feature in RF_features:
    importance.loc[feature,'RandomForest'] = 1
    
importance['Score'] = importance.sum(axis=1)
save_path = './result/important_variables_both_cts_cat_v2.csv'
if not exists(save_path):
    importance.to_csv(save_path)
importance_both = importance
importance_both
